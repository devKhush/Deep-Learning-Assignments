# %% [markdown]
# # Khushdev Pandit
# # Roll no: 2020211

# %%
import gdown
url = 'https://drive.google.com/drive/folders/1eMPLhew1XrMo6mLHO8ySTv-n4Xydlui-?usp=sharing'
gdown.download_folder(url, quiet=True, use_cookies=False)
# Out:
# ['c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\t10k-images-idx3-ubyte',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\t10k-images-idx3-ubyte.gz',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\t10k-labels-idx1-ubyte',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\t10k-labels-idx1-ubyte.gz',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\train-images-idx3-ubyte',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\train-images-idx3-ubyte.gz',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\train-labels-idx1-ubyte',
#  'c:\\Users\\khush\\OneDrive\\Desktop\\DL Assignments\\Assignment-1\\data\\MNIST\\raw\\train-labels-idx1-ubyte.gz']

# %% [markdown]
# # Question 1

# %%
import os
import torch
import struct
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.datasets import MNIST

# %%
data = MNIST(root='data/', download=True, train=True, transform=None)
data.data.shape, data.targets.shape
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 107350057.82it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 100862359.55it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 32069832.26it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 5013297.04it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# (torch.Size([60000, 28, 28]), torch.Size([60000]))

# %% [markdown]
# ### Class for custom MNIST Dataset inherited from torch.utils.data.Dataset

# %%
class MNISTCustomDataset(Dataset):
    def __init__(self, root:str, train=True, transform=None, target_transform=None):
        self.root = root
        self.transform = transform
        self.target_transform = target_transform
        images_path = 'train-images-idx3-ubyte' if train else 't10k-images-idx3-ubyte'
        labels_path = 'train-labels-idx1-ubyte' if train else 't10k-labels-idx1-ubyte'
        images_path = os.path.join(self.root, images_path)
        labels_path = os.path.join(self.root, labels_path)
        f_image = open(images_path, 'rb')
        f_label = open(labels_path, 'rb')

        magic_number, size, row, column = struct.unpack(">IIII", f_image.read(16))
        image_data = np.fromfile(f_image, dtype=np.uint8)
        magic_number, size = struct.unpack(">II", f_label.read(8))
        image_label = np.fromfile(f_label, dtype=np.uint8)

        self.images = torch.tensor(image_data, dtype=torch.float32).reshape((size, 1, row, column))
        self.labels = torch.tensor(image_label, dtype=torch.int64)
        self.length = size
        print('MNIST Custom Dataset Initialized...')
        print('MNIST Custom Dataset length: {}'.format(self.length))
        print('Dataset image shape: {}'.format(self.images.shape))
        print('Dataset label shape: {}\n'.format(self.labels.shape))

    def __getitem__(self, index):
        image, label = self.images[index], self.labels[index]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

    def __len__(self):
        return self.length

# %%
# root = os.path.join(os.getcwd(), 'data', 'MNIST', 'raw')
root = './data/MNIST/raw/'

transform = transforms.Compose([
    transforms.Normalize((0.5,), (0.5,)),
    transforms.RandomHorizontalFlip(0.5),
])
# mnist_custom_dataset = MNIST(root='data/', download=True, train=True, transform=transform)
mnist_custom_dataset = MNISTCustomDataset(root=root, train=True, transform=transform)
print(mnist_custom_dataset.images.shape, mnist_custom_dataset.labels.shape)

custom_dataloader = DataLoader(mnist_custom_dataset, batch_size=4, shuffle=True)
for images, labels in custom_dataloader:
    print(images.shape, labels.shape)
    print(type(images), type(labels))
    print(images.dtype, labels.dtype)
    print(labels[0])
    plt.imshow(images[0].reshape((28, 28)), cmap='gray');plt.show()
    print(labels[1])
    plt.imshow(images[1].reshape((28, 28)), cmap='gray');plt.show()
    break
# Out:
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# torch.Size([60000, 1, 28, 28]) torch.Size([60000])
# torch.Size([4, 1, 28, 28]) torch.Size([4])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.float32 torch.int64
# tensor(7)
# tensor(7)

# %% [markdown]
# ### Class for Scratch MNIST Dataset & Dataloader

# %%
class MNISTScratchDataset:
    def __init__(self, root:str, train=True):
        self.root = root
        images_path = 'train-images-idx3-ubyte' if train else 't10k-images-idx3-ubyte'
        labels_path = 'train-labels-idx1-ubyte' if train else 't10k-labels-idx1-ubyte'
        images_path = os.path.join(self.root, images_path)
        labels_path = os.path.join(self.root, labels_path)
        f_image = open(images_path, 'rb')
        f_label = open(labels_path, 'rb')

        magic_number, size, row, column = struct.unpack(">IIII", f_image.read(16))
        image_data = np.fromfile(f_image, dtype=np.uint8)
        magic_number, size = struct.unpack(">II", f_label.read(8))
        image_label = np.fromfile(f_label, dtype=np.uint8)

        self.images = torch.tensor(image_data, dtype=torch.float32).reshape((size, 1, row, column))
        self.labels = torch.tensor(image_label, dtype=torch.int64)
        self.length = size
        print('MNIST Scratch Dataset Initialized...')
        print('MNIST Scratch Dataset length: {}'.format(self.length))
        print('Dataset image shape: {}'.format(self.images.shape))
        print('Dataset label shape: {}\n'.format(self.labels.shape))

    def __getitem__(self, index):
        image, label = self.images[index], self.labels[index]
        return image, label

    def __len__(self):
        return self.length

# %%
class MNISTLoader:
    def __init__(self, data, batch_size, shuffle=False):
        self.data = data
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.n = len(self.data)
        self.shuffle_data()

    def shuffle_data(self):
        self.i = 0
        self.indices = torch.randperm(self.n) if self.shuffle else torch.arange(self.n)

    def __has_next__(self):
        return self.i < self.n

    def __iter__(self):
        self.shuffle_data()
        return self

    def __next__(self):
        if not self.__has_next__():
            raise StopIteration
        else:
            batch_indices = self.indices[self.i : self.i + self.batch_size]
            # Method-1
            # batch_images = []
            # batch_labels = []
            # for i in batch_indices:
            #     image, label = self.data[i]
            #     batch_images.append(image)
            #     batch_labels.append(label)
            # Method-2 (Applies same transform to all images in batch)
            # batch_images, batch_labels = self.data[batch_indices]
            # self.i += self.batch_size
            # return batch_images, batch_labels
            # Method-3
            batch_images, batch_labels = zip(*[self.data[i] for i in batch_indices])
            self.i += self.batch_size
            return torch.stack(batch_images), torch.stack(batch_labels)

# %%
root = './data/MNIST/raw/'
mnist_scratch_dataset = MNISTScratchDataset(root=root, train=True)
print(mnist_scratch_dataset.images.shape, mnist_scratch_dataset.labels.shape)
# print(mnist_scratch_dataset[0][1]); plt.imshow(mnist_scratch_dataset[0][0], cmap='gray'); plt.show()

# scratch_loader = DataLoader(mnist_scratch_dataset, batch_size=64, shuffle=True)
scratch_loader = MNISTLoader(mnist_scratch_dataset, batch_size=64, shuffle=True)

for images, labels in scratch_loader:
    print(images.shape, labels.shape)
    print(labels[0])
    plt.imshow(images[0][0], cmap='gray'); plt.show()
    print(labels[1])
    plt.imshow(images[1][0], cmap='gray'); plt.show()
    break

print(type(scratch_loader))
for i in range(10):
    for images, labels in scratch_loader:
        print(scratch_loader.indices)
        break
# Out:
# MNIST Scratch Dataset Initialized...
# MNIST Scratch Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# torch.Size([60000, 1, 28, 28]) torch.Size([60000])
# torch.Size([64, 1, 28, 28]) torch.Size([64])
# tensor(8)
# tensor(2)
# <class '__main__.MNISTLoader'>
# tensor([31314, 40399, 30745,  ...,  2498,  4565, 15549])
# tensor([31245, 42343, 20710,  ..., 57813, 29138, 52818])
# tensor([12848, 47363, 52176,  ..., 13781,  2592,  9123])
# tensor([19632,  6601,  7344,  ..., 28283, 43710, 24373])
# tensor([35949, 39758, 20514,  ..., 20616, 52194, 27741])
# tensor([37131, 31264, 32461,  ..., 34093, 54136,  2208])
# tensor([55926, 51833, 49190,  ..., 44622, 23258, 13809])
# tensor([  297, 24189, 46166,  ..., 19441, 22063,  1307])
# tensor([  584,  4783, 44160,  ..., 43616, 27060, 56581])
# tensor([23941, 51838,  3840,  ..., 21546, 43337,  8946])

# %% [markdown]
# ### Custom DataLoader performance

# %%
def get_custom_loader_timings(data, batch_size=64, shuffle=False):
    import time
    custom_dataloader = DataLoader(data, batch_size=batch_size, shuffle=shuffle)
    batch_loading_time = []
    print(f'Calculating loading time for Batch-size={batch_size} and Shuffle={shuffle}')
    start_time = time.time()
    prev_time = start_time
    for img, label in custom_dataloader:
        curr_time = time.time()
        batch_loading_time.append(curr_time - prev_time)
        prev_time = curr_time

    total_loading_time = time.time() - start_time
    return batch_loading_time, total_loading_time

transform = transforms.Compose([
    transforms.Normalize((0.5,), (0.5,)),
    transforms.RandomHorizontalFlip(),
])
mnist_dataset = MNISTCustomDataset(root=root, train=True, transform=None, target_transform=None)

cL_batchLoadingTime_b128, cL_totalLoadingTime_b128 = get_custom_loader_timings(mnist_dataset, batch_size=128)
cL_batchLoadingTime_b256, cL_totalLoadingTime_b256 = get_custom_loader_timings(mnist_dataset, batch_size=256)
cL_batchLoadingTime_b512, cL_totalLoadingTime_b512 = get_custom_loader_timings(mnist_dataset, batch_size=512)
cL_batchLoadingTime_b1024, cL_totalLoadingTime_b1024  = get_custom_loader_timings(mnist_dataset, batch_size=1024)

print('\nMean Batch Loading time for custom DataLoaders: ')
print(f'for batch Size 128: {np.mean(cL_batchLoadingTime_b128)}s')
print(f'for batch Size 256: {np.mean(cL_batchLoadingTime_b256)}s')
print(f'for batch Size 512: {np.mean(cL_batchLoadingTime_b512)}s')
print(f'for batch Size 1024: {np.mean(cL_batchLoadingTime_b1024)}s')

print('\nMedian Batch Loading time for custom DataLoaders: ')
print(f'for batch Size 128: {np.median(cL_batchLoadingTime_b128)}s')
print(f'for batch Size 256: {np.median(cL_batchLoadingTime_b256)}s')
print(f'for batch Size 512: {np.median(cL_batchLoadingTime_b512)}s')
print(f'for batch Size 1024: {np.median(cL_batchLoadingTime_b1024)}s')

print('\nStandard Deviation of Batch Loading time for custom DataLoaders: ')
print(f'for batch Size 128: {np.std(cL_batchLoadingTime_b128)}s')
print(f'for batch Size 256: {np.std(cL_batchLoadingTime_b256)}s')
print(f'for batch Size 512: {np.std(cL_batchLoadingTime_b512)}s')
print(f'for batch Size 1024: {np.std(cL_batchLoadingTime_b1024)}s')

print('\nTotal Loading time for custom DataLoaders: ')
print(f'for batch Size 128: {cL_totalLoadingTime_b128}s')
print(f'for batch Size 256: {cL_totalLoadingTime_b256}s')
print(f'for batch Size 512: {cL_totalLoadingTime_b512}s')
print(f'for batch Size 1024: {cL_totalLoadingTime_b1024}s')
# Out:
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# Calculating loading time for Batch-size=128 and Shuffle=False
# Calculating loading time for Batch-size=256 and Shuffle=False
# Calculating loading time for Batch-size=512 and Shuffle=False
# Calculating loading time for Batch-size=1024 and Shuffle=False
#
# Mean Batch Loading time for custom DataLoaders:
# for batch Size 128: 0.0008399481458196253s
# for batch Size 256: 0.0016771539728692238s
# for batch Size 512: 0.004626019526336153s
# for batch Size 1024: 0.006417488647719561s
#
# Median Batch Loading time for custom DataLoaders:
# for batch Size 128: 0.0007965564727783203s
# for batch Size 256: 0.0015935897827148438s
# for batch Size 512: 0.0031644105911254883s
# for batch Size 1024: 0.006246089935302734s
#
# Standard Deviation of Batch Loading time for custom DataLoaders:
# for batch Size 128: 0.00020230442562127324s
# for batch Size 256: 0.000332358300082902s
# for batch Size 512: 0.013921124175179971s
# for batch Size 1024: 0.0007233158007022243s
#
# Total Loading time for custom DataLoaders:
# for batch Size 128: 0.3939659595489502s
# for batch Size 256: 0.3941636085510254s
# for batch Size 512: 0.5459063053131104s
# for batch Size 1024: 0.3786759376525879s

# %% [markdown]
# ### Scratch DataLoader performance

# %%
def get_scratch_loader_timings(data, batch_size=64, shuffle=False):
    import time
    scratch_loader = MNISTLoader(data, batch_size=batch_size, shuffle=shuffle)
    batch_loading_time = []
    print(f'Calculating loading time for Batch-size={batch_size} and Shuffle={shuffle}')
    start_time = time.time()
    prev_time = start_time
    for img, label in scratch_loader:
        curr_time = time.time()
        batch_loading_time.append(curr_time - prev_time)
        prev_time = curr_time

    total_loading_time = time.time() - start_time
    return batch_loading_time, total_loading_time

mnist_dataset = MNISTScratchDataset(root=root, train=True)

sL_batchLoadingTime_b128, sL_totalLoadingTime_b128 = get_scratch_loader_timings(mnist_dataset, 128)
sL_batchLoadingTime_b256, sL_totalLoadingTime_b256 = get_scratch_loader_timings(mnist_dataset, 256)
sL_batchLoadingTime_b512, sL_totalLoadingTime_b512 = get_scratch_loader_timings(mnist_dataset, 512)
sL_batchLoadingTime_b1024, sL_totalLoadingTime_b1024 = get_scratch_loader_timings(mnist_dataset, 1024)

print('\nMean Batch Loading time for scratch DataLoaders: ')
print(f'for batch Size 128: {np.mean(sL_batchLoadingTime_b128)}s')
print(f'for batch Size 256: {np.mean(sL_batchLoadingTime_b256)}s')
print(f'for batch Size 512: {np.mean(sL_batchLoadingTime_b512)}s')
print(f'for batch Size 1024: {np.mean(sL_batchLoadingTime_b1024)}s')

print('\nMedian Batch Loading time for scratch DataLoaders: ')
print(f'for batch Size 128: {np.median(sL_batchLoadingTime_b128)}s')
print(f'for batch Size 256: {np.median(sL_batchLoadingTime_b256)}s')
print(f'for batch Size 512: {np.median(sL_batchLoadingTime_b512)}s')
print(f'for batch Size 1024: {np.median(sL_batchLoadingTime_b1024)}s')

print('\nStandard Deviation of Batch Loading time for scratch DataLoaders: ')
print(f'for batch Size 128: {np.std(sL_batchLoadingTime_b128)}s')
print(f'for batch Size 256: {np.std(sL_batchLoadingTime_b256)}s')
print(f'for batch Size 512: {np.std(sL_batchLoadingTime_b512)}s')
print(f'for batch Size 1024: {np.std(sL_batchLoadingTime_b1024)}s')

print('\nTotal Loading time for scratch DataLoaders: ')
print(f'for batch Size 128: {sL_totalLoadingTime_b128}s')
print(f'for batch Size 256: {sL_totalLoadingTime_b256}s')
print(f'for batch Size 512: {sL_totalLoadingTime_b512}s')
print(f'for batch Size 1024: {sL_totalLoadingTime_b1024}s')
# Out:
# MNIST Scratch Dataset Initialized...
# MNIST Scratch Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# Calculating loading time for Batch-size=128 and Shuffle=False
# Calculating loading time for Batch-size=256 and Shuffle=False
# Calculating loading time for Batch-size=512 and Shuffle=False
# Calculating loading time for Batch-size=1024 and Shuffle=False
#
# Mean Batch Loading time for scratch DataLoaders:
# for batch Size 128: 0.0010889156032472785s
# for batch Size 256: 0.002158319189193401s
# for batch Size 512: 0.005508544081348484s
# for batch Size 1024: 0.008498232243424756s
#
# Median Batch Loading time for scratch DataLoaders:
# for batch Size 128: 0.0010237693786621094s
# for batch Size 256: 0.002084493637084961s
# for batch Size 512: 0.004175662994384766s
# for batch Size 1024: 0.00829315185546875s
#
# Standard Deviation of Batch Loading time for scratch DataLoaders:
# for batch Size 128: 0.00021396604920232608s
# for batch Size 256: 0.0003037179592658344s
# for batch Size 512: 0.012658825265276822s
# for batch Size 1024: 0.0007112158438403313s
#
# Total Loading time for scratch DataLoaders:
# for batch Size 128: 0.5107083320617676s
# for batch Size 256: 0.5072112083435059s
# for batch Size 512: 0.6500139236450195s
# for batch Size 1024: 0.5014066696166992s

# %% [markdown]
# ### Comparing Performance of Loading time v/s Batch size on Custom DataLoader and Scratch DataLoader without shuffling

# %%
batch_sizes = [128, 256, 512, 1024]
cL_meanBatchLoadingTime = [np.mean(cL_batchLoadingTime_b128), np.mean(cL_batchLoadingTime_b256),
                            np.mean(cL_batchLoadingTime_b512), np.mean(cL_batchLoadingTime_b1024)]
sL_meanBatchLoadingTime = [np.mean(sL_batchLoadingTime_b128), np.mean(sL_batchLoadingTime_b256),
                            np.mean(sL_batchLoadingTime_b512), np.mean(sL_batchLoadingTime_b1024)]
cL_totalLoadingTime = [cL_totalLoadingTime_b128, cL_totalLoadingTime_b256,
                        cL_totalLoadingTime_b512, cL_totalLoadingTime_b1024]
sL_totalLoadingTime = [sL_totalLoadingTime_b128, sL_totalLoadingTime_b256,
                        sL_totalLoadingTime_b512, sL_totalLoadingTime_b1024]

fig = plt.figure(figsize=(8, 10))
has = ['left', 'left', 'left', 'right']
vas = ['bottom', 'bottom', 'bottom', 'bottom']

ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(batch_sizes, cL_meanBatchLoadingTime, label='Custom Dataloader', marker='o')
ax1.plot(batch_sizes, sL_meanBatchLoadingTime, label='Scratch Dataloader', marker='o')
# ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xticks(batch_sizes)
for x, y in zip(batch_sizes, cL_meanBatchLoadingTime):
    ax1.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
for x, y in zip(batch_sizes, sL_meanBatchLoadingTime):
    ax1.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
ax1.set_xlabel('Batch Size')
ax1.set_ylabel('Mean Batch Loading Time')
ax1.legend()

ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(batch_sizes, cL_totalLoadingTime, label='Custom Dataloader', marker='o')
ax2.plot(batch_sizes, sL_totalLoadingTime, label='Scratch Dataloader', marker='o')
# ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xticks(batch_sizes)
for x, y in zip(batch_sizes, cL_totalLoadingTime):
    ax2.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
for x, y in zip(batch_sizes, sL_totalLoadingTime):
    ax2.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
ax2.set_xlabel('Batch Size')
ax2.set_ylabel('Total Loading Time')
ax2.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparing Performance of Loading time v/s Batch size on Custom DataLoader and Scratch DataLoader with shuffling

# %%
transform = transforms.Compose([
    transforms.Normalize((0.5,), (0.5,)),
    transforms.RandomHorizontalFlip()
])
# mnist_custom_dataset = MNIST(root='data/', download=True, train=True, transform=transform)
mnist_custom_dataset = MNISTCustomDataset(root=root, train=True, transform=None)

cL_batchLoadingTime_b128, cL_totalLoadingTime_b128 = get_custom_loader_timings(mnist_custom_dataset, batch_size=128, shuffle=True)
cL_batchLoadingTime_b256, cL_totalLoadingTime_b256 = get_custom_loader_timings(mnist_custom_dataset, batch_size=256, shuffle=True)
cL_batchLoadingTime_b512, cL_totalLoadingTime_b512 = get_custom_loader_timings(mnist_custom_dataset, batch_size=512, shuffle=True)
cL_batchLoadingTime_b1024, cL_totalLoadingTime_b1024  = get_custom_loader_timings(mnist_custom_dataset, batch_size=1024, shuffle=True)
print()

mnist_scratch_dataset = MNISTScratchDataset(root=root, train=True)
sL_batchLoadingTime_b128, sL_totalLoadingTime_b128 = get_scratch_loader_timings(mnist_scratch_dataset, batch_size=128, shuffle=True)
sL_batchLoadingTime_b256, sL_totalLoadingTime_b256 = get_scratch_loader_timings(mnist_scratch_dataset, batch_size=256, shuffle=True)
sL_batchLoadingTime_b512, sL_totalLoadingTime_b512 = get_scratch_loader_timings(mnist_scratch_dataset, batch_size=512, shuffle=True)
sL_batchLoadingTime_b1024, sL_totalLoadingTime_b1024 = get_scratch_loader_timings(mnist_scratch_dataset, batch_size=1024, shuffle=True)


batch_sizes = [128, 256, 512, 1024]
cL_meanBatchLoadingTime = [np.mean(cL_batchLoadingTime_b128), np.mean(cL_batchLoadingTime_b256),
                            np.mean(cL_batchLoadingTime_b512), np.mean(cL_batchLoadingTime_b1024)]
sL_meanBatchLoadingTime = [np.mean(sL_batchLoadingTime_b128), np.mean(sL_batchLoadingTime_b256),
                            np.mean(sL_batchLoadingTime_b512), np.mean(sL_batchLoadingTime_b1024)]
cL_totalLoadingTime = [cL_totalLoadingTime_b128, cL_totalLoadingTime_b256,
                        cL_totalLoadingTime_b512, cL_totalLoadingTime_b1024]
sL_totalLoadingTime = [sL_totalLoadingTime_b128, sL_totalLoadingTime_b256,
                        sL_totalLoadingTime_b512, sL_totalLoadingTime_b1024]

fig = plt.figure(figsize=(8, 10))
has = ['left', 'left', 'left', 'right']
vas = ['bottom', 'bottom', 'bottom', 'bottom']

ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(batch_sizes, cL_meanBatchLoadingTime, label='Custom Dataloader', marker='o')
ax1.plot(batch_sizes, sL_meanBatchLoadingTime, label='Scratch Dataloader', marker='o')
# ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xticks(batch_sizes)
for x, y in zip(batch_sizes, cL_meanBatchLoadingTime):
    ax1.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
for x, y in zip(batch_sizes, sL_meanBatchLoadingTime):
    ax1.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
ax1.set_xlabel('Batch Size')
ax1.set_ylabel('Mean Batch Loading Time')
ax1.legend()

ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(batch_sizes, cL_totalLoadingTime, label='Custom Dataloader', marker='o')
ax2.plot(batch_sizes, sL_totalLoadingTime, label='Scratch Dataloader', marker='o')
# ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xticks(batch_sizes)
for x, y in zip(batch_sizes, cL_totalLoadingTime):
    ax2.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
for x, y in zip(batch_sizes, sL_totalLoadingTime):
    ax2.text(x, y, '({}, {:.5f})'.format(x, y), ha=has[batch_sizes.index(x)], va=vas[batch_sizes.index(x)])
ax2.set_xlabel('Batch Size')
ax2.set_ylabel('Total Loading Time')
ax2.legend()
plt.tight_layout()
plt.show()
# Out:
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# Calculating loading time for Batch-size=128 and Shuffle=True
# Calculating loading time for Batch-size=256 and Shuffle=True
# Calculating loading time for Batch-size=512 and Shuffle=True
# Calculating loading time for Batch-size=1024 and Shuffle=True
#
# MNIST Scratch Dataset Initialized...
# MNIST Scratch Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# Calculating loading time for Batch-size=128 and Shuffle=True
# Calculating loading time for Batch-size=256 and Shuffle=True
# Calculating loading time for Batch-size=512 and Shuffle=True
# Calculating loading time for Batch-size=1024 and Shuffle=True

# %% [markdown]
# # Question-2

# %% [markdown]
# ### Network architecture

# %%
import torch
import time
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt


class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(in_features=28*28, out_features=512, bias=True)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(in_features=512, out_features=256, bias=True)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(in_features=256, out_features=128, bias=True)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(in_features=128, out_features=64, bias=True)
        self.relu4 = nn.ReLU()
        self.fc5 = nn.Linear(in_features=64, out_features=10, bias=True)
        self.relu5 = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.flatten(x)
        x = self.relu1(self.fc1(x))
        x = self.relu2(self.fc2(x))
        x = self.relu3(self.fc3(x))
        x = self.relu4(self.fc4(x))
        logits = self.fc5(x)
        # probas = self.softmax(logits)
        return logits

# %% [markdown]
# ### Initialize Dataset and DataLoaders

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# Creating training and test datasets
root = './data/MNIST/raw/'
train_dataset = MNISTCustomDataset(root=root, train=True, transform=None)
test_dataset = MNISTCustomDataset(root=root, train=False, transform=None)

# splitting of training and validation set
batch_size = 128
valid_size = 0.1
num_train = len(train_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_index, valid_index = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_index)
valid_sampler = SubsetRandomSampler(valid_index)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, shuffle=False)
valid_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=valid_sampler, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print('Train Dataset Length: {}'.format(len(train_sampler)))
print('Validation Dataset Length: {}'.format(len(valid_sampler)))
print('Test Dataset Length: {}'.format(len(test_dataset)))

for images, labels in train_loader:
    print(images.shape, labels.shape)
    print(type(images), type(labels))
    print(images.dtype, labels.dtype)
    print(labels[0])
    plt.imshow(images[0][0], cmap='gray');plt.show()
    print(labels[1])
    plt.imshow(images[1][0], cmap='gray');plt.show()
    break
# Out:
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 10000
# Dataset image shape: torch.Size([10000, 1, 28, 28])
# Dataset label shape: torch.Size([10000])
#
# Train Dataset Length: 54000
# Validation Dataset Length: 6000
# Test Dataset Length: 10000
# torch.Size([128, 1, 28, 28]) torch.Size([128])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.float32 torch.int64
# tensor(7)
# tensor(2)

# %% [markdown]
# ### Initialize the model and other parameters

# %%
# Initialize the model
model = MLP()

# Define the loss function and optimizer
optimizer = optim.SGD(model.parameters(), lr=0.0003)
criterion = nn.CrossEntropyLoss()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### Training of the model

# %%
# Training loop
def train(model:nn.Module, train_loader:DataLoader, optimizer, criterion):
    model.train()
    model = model.to(device)
    train_loss = 0.0
    correct = 0
    total = 0
    batch = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        batch_correct = (predicted == labels).sum().item()
        correct += batch_correct

        if (batch + 1) % 10 == 0:
            loss, current = loss.item(), (batch + 1) * len(images)
            print(f"Batch Loss: {loss:>7f},  Batch Accuracy: {100*batch_correct/len(images):.2f}   [{current:>5d}/{len(train_sampler):>5d}]")
        batch += 1

    accuracy = 100 * correct / total
    train_loss = train_loss / len(train_loader)
    print(f"Training performance: \n Accuracy: {accuracy:>0.1f}%, Loss: {train_loss:>8f}")
    return train_loss, accuracy


# Validation loop
def validate(model:nn.Module, valid_loader:DataLoader, loss_fn):
    model.eval()
    model = model.to(device)
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in valid_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            val_loss += loss_fn(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    val_loss = val_loss / len(valid_loader)
    print(f"Validation performance: \n Accuracy: {accuracy:>0.1f}%, Loss: {val_loss:>8f}")
    return val_loss, accuracy


# Testing loop
def test(model:nn.Module, test_loader:DataLoader, loss_fn):
    model.eval()
    model = model.to(device)
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            test_loss += loss_fn(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    accuracy = 100 * correct / total
    test_loss = test_loss / len(test_loader)
    print(f"Test performance: \n Accuracy: {accuracy:>0.1f}%, Loss: {test_loss:>8f} \n")
    return test_loss, accuracy


# Training, Validation and Testing of the model
num_epochs = 60
train_losses, train_accuracies = [], []
val_losses, val_accuracies = [], []
test_losses, test_accuracies = [], []
start_time = time.time()

for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}\n-------------------------------")
    train_loss, train_accuracy = train(model, train_loader, optimizer, criterion)
    val_loss, val_accuracy = validate(model, valid_loader, criterion)
    test_loss, test_accuracy = test(model, test_loader, criterion)

    train_losses.append(train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(val_loss)
    val_accuracies.append(val_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

end_time = time.time()
print(f"Time taken to train the model: {(end_time - start_time) / 60} minutes")
# Out:
# Epoch 1
# -------------------------------
# Batch Loss: 2.304017,  Batch Accuracy: 13.28   [ 1280/54000]
# Batch Loss: 2.197892,  Batch Accuracy: 21.09   [ 2560/54000]
# Batch Loss: 2.051607,  Batch Accuracy: 23.44   [ 3840/54000]
# Batch Loss: 1.904137,  Batch Accuracy: 38.28   [ 5120/54000]
# Batch Loss: 1.855838,  Batch Accuracy: 39.06   [ 6400/54000]
# Batch Loss: 1.888506,  Batch Accuracy: 39.06   [ 7680/54000]
# Batch Loss: 1.725474,  Batch Accuracy: 47.66   [ 8960/54000]
# Batch Loss: 1.579623,  Batch Accuracy: 53.12   [10240/54000]
# Batch Loss: 1.624859,  Batch Accuracy: 53.12   [11520/54000]
# Batch Loss: 1.628568,  Batch Accuracy: 50.00   [12800/54000]
# Batch Loss: 1.468058,  Batch Accuracy: 57.03   [14080/54000]
# Batch Loss: 1.463526,  Batch Accuracy: 56.25   [15360/54000]
# Batch Loss: 1.434462,  Batch Accuracy: 60.94   [16640/54000]
# Batch Loss: 1.340013,  Batch Accuracy: 59.38   [17920/54000]
# Batch Loss: 1.350013,  Batch Accuracy: 64.84   [19200/54000]
# Batch Loss: 1.144915,  Batch Accuracy: 73.44   [20480/54000]
# Batch Loss: 1.149991,  Batch Accuracy: 70.31   [21760/54000]
# Batch Loss: 1.239317,  Batch Accuracy: 64.84   [23040/54000]
# Batch Loss: 1.031096,  Batch Accuracy: 76.56   [24320/54000]
# Batch Loss: 0.938470,  Batch Accuracy: 73.44   [25600/54000]
# Batch Loss: 0.988163,  Batch Accuracy: 70.31   [26880/54000]
# Batch Loss: 0.936750,  Batch Accuracy: 76.56   [28160/54000]
# Batch Loss: 0.947988,  Batch Accuracy: 78.12   [29440/54000]
# Batch Loss: 0.809860,  Batch Accuracy: 79.69   [30720/54000]
# Batch Loss: 0.833963,  Batch Accuracy: 79.69   [32000/54000]
# Batch Loss: 1.056737,  Batch Accuracy: 70.31   [33280/54000]
# Batch Loss: 0.890912,  Batch Accuracy: 74.22   [34560/54000]
# Batch Loss: 0.842592,  Batch Accuracy: 77.34   [35840/54000]
# Batch Loss: 0.776580,  Batch Accuracy: 78.91   [37120/54000]
# Batch Loss: 0.908813,  Batch Accuracy: 72.66   [38400/54000]
# Batch Loss: 0.683266,  Batch Accuracy: 85.94   [39680/54000]
# Batch Loss: 0.836203,  Batch Accuracy: 74.22   [40960/54000]
# Batch Loss: 0.683306,  Batch Accuracy: 79.69   [42240/54000]
# Batch Loss: 0.845736,  Batch Accuracy: 74.22   [43520/54000]
# Batch Loss: 0.822237,  Batch Accuracy: 71.88   [44800/54000]
# Batch Loss: 0.634338,  Batch Accuracy: 82.81   [46080/54000]
# Batch Loss: 0.713451,  Batch Accuracy: 81.25   [47360/54000]
# Batch Loss: 0.699427,  Batch Accuracy: 78.91   [48640/54000]
# Batch Loss: 0.666718,  Batch Accuracy: 82.81   [49920/54000]
# Batch Loss: 0.607219,  Batch Accuracy: 81.25   [51200/54000]
# Batch Loss: 0.575715,  Batch Accuracy: 82.03   [52480/54000]
# Batch Loss: 0.726247,  Batch Accuracy: 76.56   [53760/54000]
# Training performance:
#  Accuracy: 65.2%, Loss: 1.175704
# Validation performance:
#  Accuracy: 82.5%, Loss: 0.617071
# Test performance:
#  Accuracy: 83.0%, Loss: 0.596409
#
# Epoch 2
# -------------------------------
# Batch Loss: 0.696680,  Batch Accuracy: 79.69   [ 1280/54000]
# Batch Loss: 0.626489,  Batch Accuracy: 82.81   [ 2560/54000]
# Batch Loss: 0.566215,  Batch Accuracy: 88.28   [ 3840/54000]
# Batch Loss: 0.511988,  Batch Accuracy: 85.94   [ 5120/54000]
# Batch Loss: 0.560567,  Batch Accuracy: 82.81   [ 6400/54000]
# Batch Loss: 0.480549,  Batch Accuracy: 85.16   [ 7680/54000]
# Batch Loss: 0.514785,  Batch Accuracy: 85.94   [ 8960/54000]
# Batch Loss: 0.570718,  Batch Accuracy: 84.38   [10240/54000]
# Batch Loss: 0.433331,  Batch Accuracy: 90.62   [11520/54000]
# Batch Loss: 0.504349,  Batch Accuracy: 86.72   [12800/54000]
# Batch Loss: 0.533300,  Batch Accuracy: 85.16   [14080/54000]
# Batch Loss: 0.480380,  Batch Accuracy: 86.72   [15360/54000]
# Batch Loss: 0.575095,  Batch Accuracy: 82.03   [16640/54000]
# Batch Loss: 0.541933,  Batch Accuracy: 87.50   [17920/54000]
# Batch Loss: 0.460192,  Batch Accuracy: 88.28   [19200/54000]
# Batch Loss: 0.553991,  Batch Accuracy: 82.03   [20480/54000]
# Batch Loss: 0.506849,  Batch Accuracy: 83.59   [21760/54000]
# Batch Loss: 0.401853,  Batch Accuracy: 93.75   [23040/54000]
# Batch Loss: 0.462500,  Batch Accuracy: 87.50   [24320/54000]
# Batch Loss: 0.448958,  Batch Accuracy: 89.06   [25600/54000]
# Batch Loss: 0.562652,  Batch Accuracy: 85.94   [26880/54000]
# Batch Loss: 0.441075,  Batch Accuracy: 87.50   [28160/54000]
# Batch Loss: 0.631330,  Batch Accuracy: 82.03   [29440/54000]
# Batch Loss: 0.444700,  Batch Accuracy: 86.72   [30720/54000]
# Batch Loss: 0.556760,  Batch Accuracy: 82.03   [32000/54000]
# Batch Loss: 0.505871,  Batch Accuracy: 86.72   [33280/54000]
# Batch Loss: 0.425377,  Batch Accuracy: 87.50   [34560/54000]
# Batch Loss: 0.544792,  Batch Accuracy: 86.72   [35840/54000]
# Batch Loss: 0.420149,  Batch Accuracy: 86.72   [37120/54000]
# Batch Loss: 0.523798,  Batch Accuracy: 88.28   [38400/54000]
# Batch Loss: 0.398273,  Batch Accuracy: 91.41   [39680/54000]
# Batch Loss: 0.499913,  Batch Accuracy: 89.06   [40960/54000]
# Batch Loss: 0.446777,  Batch Accuracy: 84.38   [42240/54000]
# Batch Loss: 0.459657,  Batch Accuracy: 87.50   [43520/54000]
# Batch Loss: 0.447705,  Batch Accuracy: 88.28   [44800/54000]
# Batch Loss: 0.331508,  Batch Accuracy: 90.62   [46080/54000]
# Batch Loss: 0.369739,  Batch Accuracy: 90.62   [47360/54000]
# Batch Loss: 0.583129,  Batch Accuracy: 85.16   [48640/54000]
# Batch Loss: 0.626300,  Batch Accuracy: 85.94   [49920/54000]
# Batch Loss: 0.352155,  Batch Accuracy: 90.62   [51200/54000]
# Batch Loss: 0.365342,  Batch Accuracy: 91.41   [52480/54000]
# Batch Loss: 0.464497,  Batch Accuracy: 89.06   [53760/54000]
# Training performance:
#  Accuracy: 85.8%, Loss: 0.500929
# Validation performance:
#  Accuracy: 87.5%, Loss: 0.421245
# Test performance:
#  Accuracy: 88.0%, Loss: 0.404711
#
# Epoch 3
# -------------------------------
# Batch Loss: 0.353039,  Batch Accuracy: 92.19   [ 1280/54000]
# Batch Loss: 0.379464,  Batch Accuracy: 89.06   [ 2560/54000]
# Batch Loss: 0.312959,  Batch Accuracy: 89.84   [ 3840/54000]
# Batch Loss: 0.383769,  Batch Accuracy: 89.06   [ 5120/54000]
# Batch Loss: 0.429512,  Batch Accuracy: 86.72   [ 6400/54000]
# Batch Loss: 0.551583,  Batch Accuracy: 85.16   [ 7680/54000]
# Batch Loss: 0.347731,  Batch Accuracy: 88.28   [ 8960/54000]
# Batch Loss: 0.450276,  Batch Accuracy: 89.06   [10240/54000]
# Batch Loss: 0.341481,  Batch Accuracy: 88.28   [11520/54000]
# Batch Loss: 0.573133,  Batch Accuracy: 85.94   [12800/54000]
# Batch Loss: 0.423412,  Batch Accuracy: 89.06   [14080/54000]
# Batch Loss: 0.457798,  Batch Accuracy: 87.50   [15360/54000]
# Batch Loss: 0.432419,  Batch Accuracy: 88.28   [16640/54000]
# Batch Loss: 0.262785,  Batch Accuracy: 92.19   [17920/54000]
# Batch Loss: 0.325230,  Batch Accuracy: 92.97   [19200/54000]
# Batch Loss: 0.411073,  Batch Accuracy: 86.72   [20480/54000]
# Batch Loss: 0.288835,  Batch Accuracy: 92.97   [21760/54000]
# Batch Loss: 0.288327,  Batch Accuracy: 93.75   [23040/54000]
# Batch Loss: 0.315825,  Batch Accuracy: 92.19   [24320/54000]
# Batch Loss: 0.303515,  Batch Accuracy: 93.75   [25600/54000]
# Batch Loss: 0.415409,  Batch Accuracy: 83.59   [26880/54000]
# Batch Loss: 0.407624,  Batch Accuracy: 88.28   [28160/54000]
# Batch Loss: 0.490526,  Batch Accuracy: 83.59   [29440/54000]
# Batch Loss: 0.262777,  Batch Accuracy: 95.31   [30720/54000]
# Batch Loss: 0.335323,  Batch Accuracy: 91.41   [32000/54000]
# Batch Loss: 0.212565,  Batch Accuracy: 94.53   [33280/54000]
# Batch Loss: 0.476298,  Batch Accuracy: 84.38   [34560/54000]
# Batch Loss: 0.364954,  Batch Accuracy: 88.28   [35840/54000]
# Batch Loss: 0.422533,  Batch Accuracy: 89.06   [37120/54000]
# Batch Loss: 0.389110,  Batch Accuracy: 88.28   [38400/54000]
# Batch Loss: 0.363287,  Batch Accuracy: 86.72   [39680/54000]
# Batch Loss: 0.330822,  Batch Accuracy: 89.84   [40960/54000]
# Batch Loss: 0.425942,  Batch Accuracy: 89.06   [42240/54000]
# Batch Loss: 0.380242,  Batch Accuracy: 89.84   [43520/54000]
# Batch Loss: 0.373597,  Batch Accuracy: 87.50   [44800/54000]
# Batch Loss: 0.435651,  Batch Accuracy: 85.94   [46080/54000]
# Batch Loss: 0.373995,  Batch Accuracy: 86.72   [47360/54000]
# Batch Loss: 0.367314,  Batch Accuracy: 91.41   [48640/54000]
# Batch Loss: 0.426311,  Batch Accuracy: 89.06   [49920/54000]
# Batch Loss: 0.409304,  Batch Accuracy: 86.72   [51200/54000]
# Batch Loss: 0.250601,  Batch Accuracy: 93.75   [52480/54000]
# Batch Loss: 0.371369,  Batch Accuracy: 85.16   [53760/54000]
# Training performance:
#  Accuracy: 89.0%, Loss: 0.384999
# Validation performance:
#  Accuracy: 89.4%, Loss: 0.354761
# Test performance:
#  Accuracy: 89.8%, Loss: 0.338032
#
# Epoch 4
# -------------------------------
# Batch Loss: 0.344454,  Batch Accuracy: 89.84   [ 1280/54000]
# Batch Loss: 0.284091,  Batch Accuracy: 92.19   [ 2560/54000]
# Batch Loss: 0.389134,  Batch Accuracy: 87.50   [ 3840/54000]
# Batch Loss: 0.311685,  Batch Accuracy: 90.62   [ 5120/54000]
# Batch Loss: 0.377047,  Batch Accuracy: 85.94   [ 6400/54000]
# Batch Loss: 0.403922,  Batch Accuracy: 86.72   [ 7680/54000]
# Batch Loss: 0.457753,  Batch Accuracy: 88.28   [ 8960/54000]
# Batch Loss: 0.291317,  Batch Accuracy: 92.97   [10240/54000]
# Batch Loss: 0.247518,  Batch Accuracy: 92.19   [11520/54000]
# Batch Loss: 0.318936,  Batch Accuracy: 92.97   [12800/54000]
# Batch Loss: 0.260606,  Batch Accuracy: 92.19   [14080/54000]
# Batch Loss: 0.342174,  Batch Accuracy: 89.06   [15360/54000]
# Batch Loss: 0.352947,  Batch Accuracy: 90.62   [16640/54000]
# Batch Loss: 0.316452,  Batch Accuracy: 89.06   [17920/54000]
# Batch Loss: 0.325603,  Batch Accuracy: 89.84   [19200/54000]
# Batch Loss: 0.278023,  Batch Accuracy: 90.62   [20480/54000]
# Batch Loss: 0.399577,  Batch Accuracy: 89.84   [21760/54000]
# Batch Loss: 0.356434,  Batch Accuracy: 92.19   [23040/54000]
# Batch Loss: 0.323091,  Batch Accuracy: 90.62   [24320/54000]
# Batch Loss: 0.302705,  Batch Accuracy: 90.62   [25600/54000]
# Batch Loss: 0.319130,  Batch Accuracy: 92.19   [26880/54000]
# Batch Loss: 0.392118,  Batch Accuracy: 91.41   [28160/54000]
# Batch Loss: 0.445476,  Batch Accuracy: 84.38   [29440/54000]
# Batch Loss: 0.198317,  Batch Accuracy: 95.31   [30720/54000]
# Batch Loss: 0.295825,  Batch Accuracy: 89.84   [32000/54000]
# Batch Loss: 0.364236,  Batch Accuracy: 89.84   [33280/54000]
# Batch Loss: 0.391196,  Batch Accuracy: 89.06   [34560/54000]
# Batch Loss: 0.318739,  Batch Accuracy: 90.62   [35840/54000]
# Batch Loss: 0.464157,  Batch Accuracy: 88.28   [37120/54000]
# Batch Loss: 0.261449,  Batch Accuracy: 94.53   [38400/54000]
# Batch Loss: 0.382605,  Batch Accuracy: 88.28   [39680/54000]
# Batch Loss: 0.460084,  Batch Accuracy: 88.28   [40960/54000]
# Batch Loss: 0.358477,  Batch Accuracy: 89.06   [42240/54000]
# Batch Loss: 0.299328,  Batch Accuracy: 89.84   [43520/54000]
# Batch Loss: 0.345566,  Batch Accuracy: 92.19   [44800/54000]
# Batch Loss: 0.486312,  Batch Accuracy: 83.59   [46080/54000]
# Batch Loss: 0.177359,  Batch Accuracy: 95.31   [47360/54000]
# Batch Loss: 0.331181,  Batch Accuracy: 90.62   [48640/54000]
# Batch Loss: 0.348972,  Batch Accuracy: 88.28   [49920/54000]
# Batch Loss: 0.294605,  Batch Accuracy: 93.75   [51200/54000]
# Batch Loss: 0.222907,  Batch Accuracy: 94.53   [52480/54000]
# Batch Loss: 0.335078,  Batch Accuracy: 89.84   [53760/54000]
# Training performance:
#  Accuracy: 90.4%, Loss: 0.332547
# Validation performance:
#  Accuracy: 90.7%, Loss: 0.313974
# Test performance:
#  Accuracy: 90.9%, Loss: 0.299692
#
# Epoch 5
# -------------------------------
# Batch Loss: 0.564789,  Batch Accuracy: 85.16   [ 1280/54000]
# Batch Loss: 0.173667,  Batch Accuracy: 92.97   [ 2560/54000]
# Batch Loss: 0.297557,  Batch Accuracy: 91.41   [ 3840/54000]
# Batch Loss: 0.345809,  Batch Accuracy: 90.62   [ 5120/54000]
# Batch Loss: 0.320467,  Batch Accuracy: 89.06   [ 6400/54000]
# Batch Loss: 0.216896,  Batch Accuracy: 95.31   [ 7680/54000]
# Batch Loss: 0.420605,  Batch Accuracy: 86.72   [ 8960/54000]
# Batch Loss: 0.365213,  Batch Accuracy: 89.84   [10240/54000]
# Batch Loss: 0.344450,  Batch Accuracy: 89.84   [11520/54000]
# Batch Loss: 0.386456,  Batch Accuracy: 89.84   [12800/54000]
# Batch Loss: 0.257980,  Batch Accuracy: 89.84   [14080/54000]
# Batch Loss: 0.279276,  Batch Accuracy: 90.62   [15360/54000]
# Batch Loss: 0.275588,  Batch Accuracy: 92.19   [16640/54000]
# Batch Loss: 0.313146,  Batch Accuracy: 92.19   [17920/54000]
# Batch Loss: 0.156257,  Batch Accuracy: 97.66   [19200/54000]
# Batch Loss: 0.465546,  Batch Accuracy: 85.16   [20480/54000]
# Batch Loss: 0.218028,  Batch Accuracy: 92.19   [21760/54000]
# Batch Loss: 0.278853,  Batch Accuracy: 93.75   [23040/54000]
# Batch Loss: 0.282669,  Batch Accuracy: 94.53   [24320/54000]
# Batch Loss: 0.354731,  Batch Accuracy: 88.28   [25600/54000]
# Batch Loss: 0.333570,  Batch Accuracy: 93.75   [26880/54000]
# Batch Loss: 0.257303,  Batch Accuracy: 93.75   [28160/54000]
# Batch Loss: 0.280117,  Batch Accuracy: 93.75   [29440/54000]
# Batch Loss: 0.435329,  Batch Accuracy: 87.50   [30720/54000]
# Batch Loss: 0.206063,  Batch Accuracy: 93.75   [32000/54000]
# Batch Loss: 0.204686,  Batch Accuracy: 94.53   [33280/54000]
# Batch Loss: 0.245837,  Batch Accuracy: 92.19   [34560/54000]
# Batch Loss: 0.462210,  Batch Accuracy: 85.16   [35840/54000]
# Batch Loss: 0.327536,  Batch Accuracy: 89.84   [37120/54000]
# Batch Loss: 0.295205,  Batch Accuracy: 93.75   [38400/54000]
# Batch Loss: 0.305648,  Batch Accuracy: 88.28   [39680/54000]
# Batch Loss: 0.287268,  Batch Accuracy: 92.19   [40960/54000]
# Batch Loss: 0.208936,  Batch Accuracy: 94.53   [42240/54000]
# Batch Loss: 0.283558,  Batch Accuracy: 92.19   [43520/54000]
# Batch Loss: 0.295085,  Batch Accuracy: 90.62   [44800/54000]
# Batch Loss: 0.295561,  Batch Accuracy: 91.41   [46080/54000]
# Batch Loss: 0.362945,  Batch Accuracy: 89.84   [47360/54000]
# Batch Loss: 0.242071,  Batch Accuracy: 93.75   [48640/54000]
# Batch Loss: 0.346293,  Batch Accuracy: 90.62   [49920/54000]
# Batch Loss: 0.185802,  Batch Accuracy: 92.97   [51200/54000]
# Batch Loss: 0.376592,  Batch Accuracy: 92.19   [52480/54000]
# Batch Loss: 0.302532,  Batch Accuracy: 90.62   [53760/54000]
# Training performance:
#  Accuracy: 91.4%, Loss: 0.299577
# Validation performance:
#  Accuracy: 91.3%, Loss: 0.288468
# Test performance:
#  Accuracy: 91.9%, Loss: 0.275024
#
# Epoch 6
# -------------------------------
# Batch Loss: 0.174928,  Batch Accuracy: 92.97   [ 1280/54000]
# Batch Loss: 0.399277,  Batch Accuracy: 89.06   [ 2560/54000]
# Batch Loss: 0.279854,  Batch Accuracy: 92.97   [ 3840/54000]
# Batch Loss: 0.306984,  Batch Accuracy: 89.06   [ 5120/54000]
# Batch Loss: 0.265644,  Batch Accuracy: 92.19   [ 6400/54000]
# Batch Loss: 0.325701,  Batch Accuracy: 91.41   [ 7680/54000]
# Batch Loss: 0.372139,  Batch Accuracy: 90.62   [ 8960/54000]
# Batch Loss: 0.332723,  Batch Accuracy: 92.19   [10240/54000]
# Batch Loss: 0.215774,  Batch Accuracy: 93.75   [11520/54000]
# Batch Loss: 0.275454,  Batch Accuracy: 92.19   [12800/54000]
# Batch Loss: 0.359457,  Batch Accuracy: 92.97   [14080/54000]
# Batch Loss: 0.353861,  Batch Accuracy: 90.62   [15360/54000]
# Batch Loss: 0.205193,  Batch Accuracy: 94.53   [16640/54000]
# Batch Loss: 0.290064,  Batch Accuracy: 90.62   [17920/54000]
# Batch Loss: 0.319685,  Batch Accuracy: 89.84   [19200/54000]
# Batch Loss: 0.426087,  Batch Accuracy: 90.62   [20480/54000]
# Batch Loss: 0.372686,  Batch Accuracy: 89.84   [21760/54000]
# Batch Loss: 0.205516,  Batch Accuracy: 94.53   [23040/54000]
# Batch Loss: 0.150632,  Batch Accuracy: 95.31   [24320/54000]
# Batch Loss: 0.351645,  Batch Accuracy: 88.28   [25600/54000]
# Batch Loss: 0.241083,  Batch Accuracy: 92.19   [26880/54000]
# Batch Loss: 0.377027,  Batch Accuracy: 89.06   [28160/54000]
# Batch Loss: 0.235789,  Batch Accuracy: 94.53   [29440/54000]
# Batch Loss: 0.266187,  Batch Accuracy: 92.19   [30720/54000]
# Batch Loss: 0.324755,  Batch Accuracy: 89.06   [32000/54000]
# Batch Loss: 0.231615,  Batch Accuracy: 94.53   [33280/54000]
# Batch Loss: 0.254374,  Batch Accuracy: 95.31   [34560/54000]
# Batch Loss: 0.259602,  Batch Accuracy: 90.62   [35840/54000]
# Batch Loss: 0.262597,  Batch Accuracy: 92.97   [37120/54000]
# Batch Loss: 0.288755,  Batch Accuracy: 92.97   [38400/54000]
# Batch Loss: 0.341422,  Batch Accuracy: 92.97   [39680/54000]
# Batch Loss: 0.212824,  Batch Accuracy: 92.97   [40960/54000]
# Batch Loss: 0.322015,  Batch Accuracy: 92.97   [42240/54000]
# Batch Loss: 0.178122,  Batch Accuracy: 96.88   [43520/54000]
# Batch Loss: 0.262090,  Batch Accuracy: 92.19   [44800/54000]
# Batch Loss: 0.219505,  Batch Accuracy: 94.53   [46080/54000]
# Batch Loss: 0.227825,  Batch Accuracy: 95.31   [47360/54000]
# Batch Loss: 0.373453,  Batch Accuracy: 88.28   [48640/54000]
# Batch Loss: 0.254895,  Batch Accuracy: 93.75   [49920/54000]
# Batch Loss: 0.371954,  Batch Accuracy: 90.62   [51200/54000]
# Batch Loss: 0.249418,  Batch Accuracy: 90.62   [52480/54000]
# Batch Loss: 0.285743,  Batch Accuracy: 89.06   [53760/54000]
# Training performance:
#  Accuracy: 92.0%, Loss: 0.275819
# Validation performance:
#  Accuracy: 91.9%, Loss: 0.267574
# Test performance:
#  Accuracy: 92.3%, Loss: 0.256235
#
# Epoch 7
# -------------------------------
# Batch Loss: 0.222744,  Batch Accuracy: 93.75   [ 1280/54000]
# Batch Loss: 0.262831,  Batch Accuracy: 92.19   [ 2560/54000]
# Batch Loss: 0.210692,  Batch Accuracy: 95.31   [ 3840/54000]
# Batch Loss: 0.249527,  Batch Accuracy: 93.75   [ 5120/54000]
# Batch Loss: 0.265198,  Batch Accuracy: 90.62   [ 6400/54000]
# Batch Loss: 0.273943,  Batch Accuracy: 92.19   [ 7680/54000]
# Batch Loss: 0.252892,  Batch Accuracy: 95.31   [ 8960/54000]
# Batch Loss: 0.159650,  Batch Accuracy: 97.66   [10240/54000]
# Batch Loss: 0.276536,  Batch Accuracy: 89.84   [11520/54000]
# Batch Loss: 0.198398,  Batch Accuracy: 92.97   [12800/54000]
# Batch Loss: 0.236589,  Batch Accuracy: 92.97   [14080/54000]
# Batch Loss: 0.156133,  Batch Accuracy: 95.31   [15360/54000]
# Batch Loss: 0.391614,  Batch Accuracy: 89.84   [16640/54000]
# Batch Loss: 0.288474,  Batch Accuracy: 89.06   [17920/54000]
# Batch Loss: 0.258202,  Batch Accuracy: 92.19   [19200/54000]
# Batch Loss: 0.358427,  Batch Accuracy: 92.19   [20480/54000]
# Batch Loss: 0.336420,  Batch Accuracy: 90.62   [21760/54000]
# Batch Loss: 0.184530,  Batch Accuracy: 95.31   [23040/54000]
# Batch Loss: 0.376591,  Batch Accuracy: 87.50   [24320/54000]
# Batch Loss: 0.236882,  Batch Accuracy: 94.53   [25600/54000]
# Batch Loss: 0.323329,  Batch Accuracy: 92.97   [26880/54000]
# Batch Loss: 0.215595,  Batch Accuracy: 95.31   [28160/54000]
# Batch Loss: 0.283836,  Batch Accuracy: 91.41   [29440/54000]
# Batch Loss: 0.170856,  Batch Accuracy: 95.31   [30720/54000]
# Batch Loss: 0.245125,  Batch Accuracy: 90.62   [32000/54000]
# Batch Loss: 0.219573,  Batch Accuracy: 93.75   [33280/54000]
# Batch Loss: 0.363399,  Batch Accuracy: 92.97   [34560/54000]
# Batch Loss: 0.215168,  Batch Accuracy: 95.31   [35840/54000]
# Batch Loss: 0.209563,  Batch Accuracy: 95.31   [37120/54000]
# Batch Loss: 0.272307,  Batch Accuracy: 94.53   [38400/54000]
# Batch Loss: 0.228727,  Batch Accuracy: 93.75   [39680/54000]
# Batch Loss: 0.320086,  Batch Accuracy: 93.75   [40960/54000]
# Batch Loss: 0.186973,  Batch Accuracy: 96.09   [42240/54000]
# Batch Loss: 0.297362,  Batch Accuracy: 92.97   [43520/54000]
# Batch Loss: 0.330651,  Batch Accuracy: 89.84   [44800/54000]
# Batch Loss: 0.195976,  Batch Accuracy: 92.19   [46080/54000]
# Batch Loss: 0.363305,  Batch Accuracy: 89.06   [47360/54000]
# Batch Loss: 0.219181,  Batch Accuracy: 92.19   [48640/54000]
# Batch Loss: 0.231688,  Batch Accuracy: 92.97   [49920/54000]
# Batch Loss: 0.248732,  Batch Accuracy: 91.41   [51200/54000]
# Batch Loss: 0.322368,  Batch Accuracy: 89.84   [52480/54000]
# Batch Loss: 0.323822,  Batch Accuracy: 93.75   [53760/54000]
# Training performance:
#  Accuracy: 92.6%, Loss: 0.257298
# Validation performance:
#  Accuracy: 92.2%, Loss: 0.253587
# Test performance:
#  Accuracy: 92.8%, Loss: 0.242174
#
# Epoch 8
# -------------------------------
# Batch Loss: 0.278103,  Batch Accuracy: 92.97   [ 1280/54000]
# Batch Loss: 0.292639,  Batch Accuracy: 92.19   [ 2560/54000]
# Batch Loss: 0.298009,  Batch Accuracy: 89.84   [ 3840/54000]
# Batch Loss: 0.267042,  Batch Accuracy: 93.75   [ 5120/54000]
# Batch Loss: 0.372346,  Batch Accuracy: 90.62   [ 6400/54000]
# Batch Loss: 0.287493,  Batch Accuracy: 91.41   [ 7680/54000]
# Batch Loss: 0.196279,  Batch Accuracy: 93.75   [ 8960/54000]
# Batch Loss: 0.258744,  Batch Accuracy: 90.62   [10240/54000]
# Batch Loss: 0.244326,  Batch Accuracy: 93.75   [11520/54000]
# Batch Loss: 0.456022,  Batch Accuracy: 89.84   [12800/54000]
# Batch Loss: 0.238002,  Batch Accuracy: 93.75   [14080/54000]
# Batch Loss: 0.341832,  Batch Accuracy: 91.41   [15360/54000]
# Batch Loss: 0.230665,  Batch Accuracy: 92.19   [16640/54000]
# Batch Loss: 0.229571,  Batch Accuracy: 92.97   [17920/54000]
# Batch Loss: 0.234170,  Batch Accuracy: 92.19   [19200/54000]
# Batch Loss: 0.230523,  Batch Accuracy: 92.97   [20480/54000]
# Batch Loss: 0.215913,  Batch Accuracy: 93.75   [21760/54000]
# Batch Loss: 0.271484,  Batch Accuracy: 92.19   [23040/54000]
# Batch Loss: 0.316351,  Batch Accuracy: 89.84   [24320/54000]
# Batch Loss: 0.276902,  Batch Accuracy: 89.06   [25600/54000]
# Batch Loss: 0.257053,  Batch Accuracy: 92.97   [26880/54000]
# Batch Loss: 0.263033,  Batch Accuracy: 89.84   [28160/54000]
# Batch Loss: 0.168764,  Batch Accuracy: 95.31   [29440/54000]
# Batch Loss: 0.221834,  Batch Accuracy: 91.41   [30720/54000]
# Batch Loss: 0.352980,  Batch Accuracy: 90.62   [32000/54000]
# Batch Loss: 0.223070,  Batch Accuracy: 92.19   [33280/54000]
# Batch Loss: 0.247240,  Batch Accuracy: 93.75   [34560/54000]
# Batch Loss: 0.337787,  Batch Accuracy: 90.62   [35840/54000]
# Batch Loss: 0.245756,  Batch Accuracy: 94.53   [37120/54000]
# Batch Loss: 0.236496,  Batch Accuracy: 92.19   [38400/54000]
# Batch Loss: 0.188454,  Batch Accuracy: 94.53   [39680/54000]
# Batch Loss: 0.278518,  Batch Accuracy: 94.53   [40960/54000]
# Batch Loss: 0.277712,  Batch Accuracy: 92.97   [42240/54000]
# Batch Loss: 0.325998,  Batch Accuracy: 88.28   [43520/54000]
# Batch Loss: 0.279583,  Batch Accuracy: 90.62   [44800/54000]
# Batch Loss: 0.146210,  Batch Accuracy: 96.09   [46080/54000]
# Batch Loss: 0.296055,  Batch Accuracy: 89.84   [47360/54000]
# Batch Loss: 0.224297,  Batch Accuracy: 93.75   [48640/54000]
# Batch Loss: 0.157004,  Batch Accuracy: 95.31   [49920/54000]
# Batch Loss: 0.236165,  Batch Accuracy: 93.75   [51200/54000]
# Batch Loss: 0.253626,  Batch Accuracy: 91.41   [52480/54000]
# Batch Loss: 0.143756,  Batch Accuracy: 94.53   [53760/54000]
# Training performance:
#  Accuracy: 93.1%, Loss: 0.241730
# Validation performance:
#  Accuracy: 92.6%, Loss: 0.240266
# Test performance:
#  Accuracy: 93.3%, Loss: 0.231059
#
# Epoch 9
# -------------------------------
# Batch Loss: 0.225083,  Batch Accuracy: 94.53   [ 1280/54000]
# Batch Loss: 0.242910,  Batch Accuracy: 95.31   [ 2560/54000]
# Batch Loss: 0.224479,  Batch Accuracy: 95.31   [ 3840/54000]
# Batch Loss: 0.190133,  Batch Accuracy: 92.97   [ 5120/54000]
# Batch Loss: 0.221184,  Batch Accuracy: 89.84   [ 6400/54000]
# Batch Loss: 0.243124,  Batch Accuracy: 92.97   [ 7680/54000]
# Batch Loss: 0.195662,  Batch Accuracy: 95.31   [ 8960/54000]
# Batch Loss: 0.131020,  Batch Accuracy: 96.88   [10240/54000]
# Batch Loss: 0.143320,  Batch Accuracy: 96.09   [11520/54000]
# Batch Loss: 0.186763,  Batch Accuracy: 94.53   [12800/54000]
# Batch Loss: 0.188508,  Batch Accuracy: 94.53   [14080/54000]
# Batch Loss: 0.209669,  Batch Accuracy: 93.75   [15360/54000]
# Batch Loss: 0.220756,  Batch Accuracy: 91.41   [16640/54000]
# Batch Loss: 0.258064,  Batch Accuracy: 92.97   [17920/54000]
# Batch Loss: 0.264419,  Batch Accuracy: 91.41   [19200/54000]
# Batch Loss: 0.240029,  Batch Accuracy: 92.19   [20480/54000]
# Batch Loss: 0.284754,  Batch Accuracy: 92.97   [21760/54000]
# Batch Loss: 0.189267,  Batch Accuracy: 95.31   [23040/54000]
# Batch Loss: 0.231224,  Batch Accuracy: 95.31   [24320/54000]
# Batch Loss: 0.228562,  Batch Accuracy: 93.75   [25600/54000]
# Batch Loss: 0.231653,  Batch Accuracy: 95.31   [26880/54000]
# Batch Loss: 0.249089,  Batch Accuracy: 92.19   [28160/54000]
# Batch Loss: 0.178110,  Batch Accuracy: 96.09   [29440/54000]
# Batch Loss: 0.217460,  Batch Accuracy: 92.19   [30720/54000]
# Batch Loss: 0.175970,  Batch Accuracy: 94.53   [32000/54000]
# Batch Loss: 0.280786,  Batch Accuracy: 92.19   [33280/54000]
# Batch Loss: 0.184804,  Batch Accuracy: 94.53   [34560/54000]
# Batch Loss: 0.182640,  Batch Accuracy: 93.75   [35840/54000]
# Batch Loss: 0.235881,  Batch Accuracy: 92.97   [37120/54000]
# Batch Loss: 0.289305,  Batch Accuracy: 91.41   [38400/54000]
# Batch Loss: 0.150510,  Batch Accuracy: 96.09   [39680/54000]
# Batch Loss: 0.195606,  Batch Accuracy: 96.09   [40960/54000]
# Batch Loss: 0.314097,  Batch Accuracy: 92.97   [42240/54000]
# Batch Loss: 0.263967,  Batch Accuracy: 92.19   [43520/54000]
# Batch Loss: 0.213597,  Batch Accuracy: 92.19   [44800/54000]
# Batch Loss: 0.329140,  Batch Accuracy: 91.41   [46080/54000]
# Batch Loss: 0.272971,  Batch Accuracy: 92.97   [47360/54000]
# Batch Loss: 0.236358,  Batch Accuracy: 92.19   [48640/54000]
# Batch Loss: 0.183658,  Batch Accuracy: 94.53   [49920/54000]
# Batch Loss: 0.265350,  Batch Accuracy: 90.62   [51200/54000]
# Batch Loss: 0.247097,  Batch Accuracy: 94.53   [52480/54000]
# Batch Loss: 0.212938,  Batch Accuracy: 92.97   [53760/54000]
# Training performance:
#  Accuracy: 93.4%, Loss: 0.228933
# Validation performance:
#  Accuracy: 93.0%, Loss: 0.229701
# Test performance:
#  Accuracy: 93.3%, Loss: 0.221218
#
# Epoch 10
# -------------------------------
# Batch Loss: 0.225330,  Batch Accuracy: 92.19   [ 1280/54000]
# Batch Loss: 0.239604,  Batch Accuracy: 92.97   [ 2560/54000]
# Batch Loss: 0.216717,  Batch Accuracy: 92.97   [ 3840/54000]
# Batch Loss: 0.289733,  Batch Accuracy: 91.41   [ 5120/54000]
# Batch Loss: 0.318022,  Batch Accuracy: 93.75   [ 6400/54000]
# Batch Loss: 0.217887,  Batch Accuracy: 92.19   [ 7680/54000]
# Batch Loss: 0.146158,  Batch Accuracy: 96.09   [ 8960/54000]
# Batch Loss: 0.180982,  Batch Accuracy: 95.31   [10240/54000]
# Batch Loss: 0.189963,  Batch Accuracy: 94.53   [11520/54000]
# Batch Loss: 0.097755,  Batch Accuracy: 96.88   [12800/54000]
# Batch Loss: 0.229854,  Batch Accuracy: 92.97   [14080/54000]
# Batch Loss: 0.335983,  Batch Accuracy: 92.97   [15360/54000]
# Batch Loss: 0.267566,  Batch Accuracy: 89.84   [16640/54000]
# Batch Loss: 0.181983,  Batch Accuracy: 95.31   [17920/54000]
# Batch Loss: 0.175831,  Batch Accuracy: 96.09   [19200/54000]
# Batch Loss: 0.254600,  Batch Accuracy: 92.19   [20480/54000]
# Batch Loss: 0.319683,  Batch Accuracy: 91.41   [21760/54000]
# Batch Loss: 0.206144,  Batch Accuracy: 94.53   [23040/54000]
# Batch Loss: 0.246397,  Batch Accuracy: 91.41   [24320/54000]
# Batch Loss: 0.202319,  Batch Accuracy: 93.75   [25600/54000]
# Batch Loss: 0.307322,  Batch Accuracy: 90.62   [26880/54000]
# Batch Loss: 0.244501,  Batch Accuracy: 93.75   [28160/54000]
# Batch Loss: 0.174210,  Batch Accuracy: 93.75   [29440/54000]
# Batch Loss: 0.294864,  Batch Accuracy: 92.19   [30720/54000]
# Batch Loss: 0.291880,  Batch Accuracy: 92.19   [32000/54000]
# Batch Loss: 0.190097,  Batch Accuracy: 93.75   [33280/54000]
# Batch Loss: 0.120712,  Batch Accuracy: 97.66   [34560/54000]
# Batch Loss: 0.265358,  Batch Accuracy: 92.97   [35840/54000]
# Batch Loss: 0.181380,  Batch Accuracy: 92.97   [37120/54000]
# Batch Loss: 0.130197,  Batch Accuracy: 96.88   [38400/54000]
# Batch Loss: 0.198816,  Batch Accuracy: 92.19   [39680/54000]
# Batch Loss: 0.185502,  Batch Accuracy: 96.09   [40960/54000]
# Batch Loss: 0.430051,  Batch Accuracy: 89.84   [42240/54000]
# Batch Loss: 0.227688,  Batch Accuracy: 94.53   [43520/54000]
# Batch Loss: 0.150787,  Batch Accuracy: 96.09   [44800/54000]
# Batch Loss: 0.242817,  Batch Accuracy: 93.75   [46080/54000]
# Batch Loss: 0.230221,  Batch Accuracy: 93.75   [47360/54000]
# Batch Loss: 0.240356,  Batch Accuracy: 95.31   [48640/54000]
# Batch Loss: 0.238787,  Batch Accuracy: 94.53   [49920/54000]
# Batch Loss: 0.132853,  Batch Accuracy: 96.09   [51200/54000]
# Batch Loss: 0.269048,  Batch Accuracy: 91.41   [52480/54000]
# Batch Loss: 0.267683,  Batch Accuracy: 93.75   [53760/54000]
# Training performance:
#  Accuracy: 93.7%, Loss: 0.217697
# Validation performance:
#  Accuracy: 93.4%, Loss: 0.219922
# Test performance:
#  Accuracy: 93.7%, Loss: 0.210959
#
# Epoch 11
# -------------------------------
# Batch Loss: 0.266816,  Batch Accuracy: 92.19   [ 1280/54000]
# Batch Loss: 0.253451,  Batch Accuracy: 93.75   [ 2560/54000]
# Batch Loss: 0.212046,  Batch Accuracy: 92.19   [ 3840/54000]
# Batch Loss: 0.174434,  Batch Accuracy: 92.97   [ 5120/54000]
# Batch Loss: 0.241563,  Batch Accuracy: 94.53   [ 6400/54000]
# Batch Loss: 0.127833,  Batch Accuracy: 97.66   [ 7680/54000]
# Batch Loss: 0.310243,  Batch Accuracy: 90.62   [ 8960/54000]
# Batch Loss: 0.274441,  Batch Accuracy: 91.41   [10240/54000]
# Batch Loss: 0.288478,  Batch Accuracy: 93.75   [11520/54000]
# Batch Loss: 0.167297,  Batch Accuracy: 92.97   [12800/54000]
# Batch Loss: 0.277045,  Batch Accuracy: 93.75   [14080/54000]
# Batch Loss: 0.194166,  Batch Accuracy: 94.53   [15360/54000]
# Batch Loss: 0.210827,  Batch Accuracy: 95.31   [16640/54000]
# Batch Loss: 0.293234,  Batch Accuracy: 91.41   [17920/54000]
# Batch Loss: 0.229794,  Batch Accuracy: 92.19   [19200/54000]
# Batch Loss: 0.092353,  Batch Accuracy: 97.66   [20480/54000]
# Batch Loss: 0.128535,  Batch Accuracy: 96.88   [21760/54000]
# Batch Loss: 0.252407,  Batch Accuracy: 93.75   [23040/54000]
# Batch Loss: 0.213191,  Batch Accuracy: 93.75   [24320/54000]
# Batch Loss: 0.180288,  Batch Accuracy: 95.31   [25600/54000]
# Batch Loss: 0.209428,  Batch Accuracy: 92.19   [26880/54000]
# Batch Loss: 0.149549,  Batch Accuracy: 96.88   [28160/54000]
# Batch Loss: 0.303100,  Batch Accuracy: 92.97   [29440/54000]
# Batch Loss: 0.146220,  Batch Accuracy: 95.31   [30720/54000]
# Batch Loss: 0.258324,  Batch Accuracy: 94.53   [32000/54000]
# Batch Loss: 0.219924,  Batch Accuracy: 92.19   [33280/54000]
# Batch Loss: 0.125828,  Batch Accuracy: 96.88   [34560/54000]
# Batch Loss: 0.203196,  Batch Accuracy: 92.19   [35840/54000]
# Batch Loss: 0.171214,  Batch Accuracy: 95.31   [37120/54000]
# Batch Loss: 0.248188,  Batch Accuracy: 92.97   [38400/54000]
# Batch Loss: 0.221891,  Batch Accuracy: 91.41   [39680/54000]
# Batch Loss: 0.218329,  Batch Accuracy: 93.75   [40960/54000]
# Batch Loss: 0.184596,  Batch Accuracy: 93.75   [42240/54000]
# Batch Loss: 0.171792,  Batch Accuracy: 93.75   [43520/54000]
# Batch Loss: 0.278148,  Batch Accuracy: 95.31   [44800/54000]
# Batch Loss: 0.249800,  Batch Accuracy: 92.97   [46080/54000]
# Batch Loss: 0.130348,  Batch Accuracy: 97.66   [47360/54000]
# Batch Loss: 0.262756,  Batch Accuracy: 92.19   [48640/54000]
# Batch Loss: 0.248248,  Batch Accuracy: 94.53   [49920/54000]
# Batch Loss: 0.198522,  Batch Accuracy: 92.19   [51200/54000]
# Batch Loss: 0.142313,  Batch Accuracy: 93.75   [52480/54000]
# Batch Loss: 0.128911,  Batch Accuracy: 94.53   [53760/54000]
# Training performance:
#  Accuracy: 94.0%, Loss: 0.207960
# Validation performance:
#  Accuracy: 93.7%, Loss: 0.211236
# Test performance:
#  Accuracy: 93.9%, Loss: 0.203246
#
# Epoch 12
# -------------------------------
# Batch Loss: 0.158248,  Batch Accuracy: 97.66   [ 1280/54000]
# Batch Loss: 0.149788,  Batch Accuracy: 93.75   [ 2560/54000]
# Batch Loss: 0.209393,  Batch Accuracy: 92.19   [ 3840/54000]
# Batch Loss: 0.159217,  Batch Accuracy: 95.31   [ 5120/54000]
# Batch Loss: 0.216023,  Batch Accuracy: 92.19   [ 6400/54000]
# Batch Loss: 0.133025,  Batch Accuracy: 95.31   [ 7680/54000]
# Batch Loss: 0.189666,  Batch Accuracy: 94.53   [ 8960/54000]
# Batch Loss: 0.244868,  Batch Accuracy: 91.41   [10240/54000]
# Batch Loss: 0.167138,  Batch Accuracy: 96.09   [11520/54000]
# Batch Loss: 0.219871,  Batch Accuracy: 90.62   [12800/54000]
# Batch Loss: 0.233465,  Batch Accuracy: 92.97   [14080/54000]
# Batch Loss: 0.189958,  Batch Accuracy: 94.53   [15360/54000]
# Batch Loss: 0.181966,  Batch Accuracy: 95.31   [16640/54000]
# Batch Loss: 0.183494,  Batch Accuracy: 94.53   [17920/54000]
# Batch Loss: 0.091347,  Batch Accuracy: 97.66   [19200/54000]
# Batch Loss: 0.176514,  Batch Accuracy: 96.09   [20480/54000]
# Batch Loss: 0.307495,  Batch Accuracy: 90.62   [21760/54000]
# Batch Loss: 0.145824,  Batch Accuracy: 96.88   [23040/54000]
# Batch Loss: 0.219440,  Batch Accuracy: 95.31   [24320/54000]
# Batch Loss: 0.145650,  Batch Accuracy: 97.66   [25600/54000]
# Batch Loss: 0.192322,  Batch Accuracy: 93.75   [26880/54000]
# Batch Loss: 0.230378,  Batch Accuracy: 90.62   [28160/54000]
# Batch Loss: 0.165428,  Batch Accuracy: 96.88   [29440/54000]
# Batch Loss: 0.164386,  Batch Accuracy: 94.53   [30720/54000]
# Batch Loss: 0.151243,  Batch Accuracy: 96.09   [32000/54000]
# Batch Loss: 0.333251,  Batch Accuracy: 91.41   [33280/54000]
# Batch Loss: 0.171536,  Batch Accuracy: 96.09   [34560/54000]
# Batch Loss: 0.211818,  Batch Accuracy: 93.75   [35840/54000]
# Batch Loss: 0.225319,  Batch Accuracy: 95.31   [37120/54000]
# Batch Loss: 0.177735,  Batch Accuracy: 95.31   [38400/54000]
# Batch Loss: 0.225284,  Batch Accuracy: 92.97   [39680/54000]
# Batch Loss: 0.178602,  Batch Accuracy: 93.75   [40960/54000]
# Batch Loss: 0.242301,  Batch Accuracy: 93.75   [42240/54000]
# Batch Loss: 0.134194,  Batch Accuracy: 93.75   [43520/54000]
# Batch Loss: 0.287016,  Batch Accuracy: 92.19   [44800/54000]
# Batch Loss: 0.178213,  Batch Accuracy: 94.53   [46080/54000]
# Batch Loss: 0.173498,  Batch Accuracy: 95.31   [47360/54000]
# Batch Loss: 0.195071,  Batch Accuracy: 95.31   [48640/54000]
# Batch Loss: 0.292022,  Batch Accuracy: 94.53   [49920/54000]
# Batch Loss: 0.143712,  Batch Accuracy: 95.31   [51200/54000]
# Batch Loss: 0.247540,  Batch Accuracy: 92.97   [52480/54000]
# Batch Loss: 0.291418,  Batch Accuracy: 90.62   [53760/54000]
# Training performance:
#  Accuracy: 94.2%, Loss: 0.198934
# Validation performance:
#  Accuracy: 93.9%, Loss: 0.205688
# Test performance:
#  Accuracy: 94.0%, Loss: 0.197704
#
# Epoch 13
# -------------------------------
# Batch Loss: 0.194974,  Batch Accuracy: 93.75   [ 1280/54000]
# Batch Loss: 0.295198,  Batch Accuracy: 92.97   [ 2560/54000]
# Batch Loss: 0.225282,  Batch Accuracy: 92.19   [ 3840/54000]
# Batch Loss: 0.202555,  Batch Accuracy: 93.75   [ 5120/54000]
# Batch Loss: 0.167412,  Batch Accuracy: 92.97   [ 6400/54000]
# Batch Loss: 0.092257,  Batch Accuracy: 97.66   [ 7680/54000]
# Batch Loss: 0.194674,  Batch Accuracy: 96.09   [ 8960/54000]
# Batch Loss: 0.128201,  Batch Accuracy: 96.09   [10240/54000]
# Batch Loss: 0.182501,  Batch Accuracy: 95.31   [11520/54000]
# Batch Loss: 0.176741,  Batch Accuracy: 94.53   [12800/54000]
# Batch Loss: 0.302628,  Batch Accuracy: 91.41   [14080/54000]
# Batch Loss: 0.186567,  Batch Accuracy: 93.75   [15360/54000]
# Batch Loss: 0.193631,  Batch Accuracy: 95.31   [16640/54000]
# Batch Loss: 0.116561,  Batch Accuracy: 96.88   [17920/54000]
# Batch Loss: 0.192425,  Batch Accuracy: 94.53   [19200/54000]
# Batch Loss: 0.181170,  Batch Accuracy: 92.97   [20480/54000]
# Batch Loss: 0.200538,  Batch Accuracy: 94.53   [21760/54000]
# Batch Loss: 0.218036,  Batch Accuracy: 92.19   [23040/54000]
# Batch Loss: 0.206106,  Batch Accuracy: 90.62   [24320/54000]
# Batch Loss: 0.236669,  Batch Accuracy: 90.62   [25600/54000]
# Batch Loss: 0.188314,  Batch Accuracy: 93.75   [26880/54000]
# Batch Loss: 0.202041,  Batch Accuracy: 91.41   [28160/54000]
# Batch Loss: 0.343857,  Batch Accuracy: 89.06   [29440/54000]
# Batch Loss: 0.282818,  Batch Accuracy: 90.62   [30720/54000]
# Batch Loss: 0.319284,  Batch Accuracy: 93.75   [32000/54000]
# Batch Loss: 0.209519,  Batch Accuracy: 94.53   [33280/54000]
# Batch Loss: 0.115114,  Batch Accuracy: 95.31   [34560/54000]
# Batch Loss: 0.265854,  Batch Accuracy: 93.75   [35840/54000]
# Batch Loss: 0.180442,  Batch Accuracy: 94.53   [37120/54000]
# Batch Loss: 0.266106,  Batch Accuracy: 89.84   [38400/54000]
# Batch Loss: 0.201058,  Batch Accuracy: 94.53   [39680/54000]
# Batch Loss: 0.231539,  Batch Accuracy: 90.62   [40960/54000]
# Batch Loss: 0.265504,  Batch Accuracy: 92.19   [42240/54000]
# Batch Loss: 0.205701,  Batch Accuracy: 93.75   [43520/54000]
# Batch Loss: 0.207780,  Batch Accuracy: 92.97   [44800/54000]
# Batch Loss: 0.202426,  Batch Accuracy: 92.19   [46080/54000]
# Batch Loss: 0.117584,  Batch Accuracy: 95.31   [47360/54000]
# Batch Loss: 0.251804,  Batch Accuracy: 92.97   [48640/54000]
# Batch Loss: 0.177818,  Batch Accuracy: 94.53   [49920/54000]
# Batch Loss: 0.112839,  Batch Accuracy: 94.53   [51200/54000]
# Batch Loss: 0.126244,  Batch Accuracy: 96.88   [52480/54000]
# Batch Loss: 0.219748,  Batch Accuracy: 92.97   [53760/54000]
# Training performance:
#  Accuracy: 94.5%, Loss: 0.190997
# Validation performance:
#  Accuracy: 94.3%, Loss: 0.196937
# Test performance:
#  Accuracy: 94.2%, Loss: 0.190370
#
# Epoch 14
# -------------------------------
# Batch Loss: 0.163770,  Batch Accuracy: 93.75   [ 1280/54000]
# Batch Loss: 0.125870,  Batch Accuracy: 96.88   [ 2560/54000]
# Batch Loss: 0.260409,  Batch Accuracy: 92.19   [ 3840/54000]
# Batch Loss: 0.287212,  Batch Accuracy: 92.19   [ 5120/54000]
# Batch Loss: 0.475606,  Batch Accuracy: 87.50   [ 6400/54000]
# Batch Loss: 0.184445,  Batch Accuracy: 92.19   [ 7680/54000]
# Batch Loss: 0.172368,  Batch Accuracy: 94.53   [ 8960/54000]
# Batch Loss: 0.139355,  Batch Accuracy: 93.75   [10240/54000]
# Batch Loss: 0.159922,  Batch Accuracy: 96.88   [11520/54000]
# Batch Loss: 0.311715,  Batch Accuracy: 92.19   [12800/54000]
# Batch Loss: 0.181684,  Batch Accuracy: 93.75   [14080/54000]
# Batch Loss: 0.222907,  Batch Accuracy: 95.31   [15360/54000]
# Batch Loss: 0.181672,  Batch Accuracy: 93.75   [16640/54000]
# Batch Loss: 0.119522,  Batch Accuracy: 97.66   [17920/54000]
# Batch Loss: 0.161756,  Batch Accuracy: 94.53   [19200/54000]
# Batch Loss: 0.210607,  Batch Accuracy: 92.97   [20480/54000]
# Batch Loss: 0.199146,  Batch Accuracy: 96.88   [21760/54000]
# Batch Loss: 0.149806,  Batch Accuracy: 96.09   [23040/54000]
# Batch Loss: 0.093915,  Batch Accuracy: 96.88   [24320/54000]
# Batch Loss: 0.139876,  Batch Accuracy: 95.31   [25600/54000]
# Batch Loss: 0.157677,  Batch Accuracy: 96.88   [26880/54000]
# Batch Loss: 0.135428,  Batch Accuracy: 96.88   [28160/54000]
# Batch Loss: 0.111846,  Batch Accuracy: 97.66   [29440/54000]
# Batch Loss: 0.195200,  Batch Accuracy: 92.19   [30720/54000]
# Batch Loss: 0.174232,  Batch Accuracy: 96.09   [32000/54000]
# Batch Loss: 0.168012,  Batch Accuracy: 95.31   [33280/54000]
# Batch Loss: 0.210327,  Batch Accuracy: 92.97   [34560/54000]
# Batch Loss: 0.268583,  Batch Accuracy: 91.41   [35840/54000]
# Batch Loss: 0.196688,  Batch Accuracy: 96.09   [37120/54000]
# Batch Loss: 0.257358,  Batch Accuracy: 92.19   [38400/54000]
# Batch Loss: 0.133123,  Batch Accuracy: 96.88   [39680/54000]
# Batch Loss: 0.180227,  Batch Accuracy: 94.53   [40960/54000]
# Batch Loss: 0.244009,  Batch Accuracy: 94.53   [42240/54000]
# Batch Loss: 0.158031,  Batch Accuracy: 95.31   [43520/54000]
# Batch Loss: 0.185164,  Batch Accuracy: 94.53   [44800/54000]
# Batch Loss: 0.168520,  Batch Accuracy: 93.75   [46080/54000]
# Batch Loss: 0.288878,  Batch Accuracy: 89.84   [47360/54000]
# Batch Loss: 0.190148,  Batch Accuracy: 94.53   [48640/54000]
# Batch Loss: 0.160584,  Batch Accuracy: 95.31   [49920/54000]
# Batch Loss: 0.171451,  Batch Accuracy: 92.97   [51200/54000]
# Batch Loss: 0.120988,  Batch Accuracy: 94.53   [52480/54000]
# Batch Loss: 0.135744,  Batch Accuracy: 97.66   [53760/54000]
# Training performance:
#  Accuracy: 94.7%, Loss: 0.183617
# Validation performance:
#  Accuracy: 94.2%, Loss: 0.194510
# Test performance:
#  Accuracy: 94.3%, Loss: 0.187177
#
# Epoch 15
# -------------------------------
# Batch Loss: 0.128063,  Batch Accuracy: 95.31   [ 1280/54000]
# Batch Loss: 0.171359,  Batch Accuracy: 96.88   [ 2560/54000]
# Batch Loss: 0.126806,  Batch Accuracy: 96.88   [ 3840/54000]
# Batch Loss: 0.154783,  Batch Accuracy: 96.09   [ 5120/54000]
# Batch Loss: 0.217358,  Batch Accuracy: 89.84   [ 6400/54000]
# Batch Loss: 0.218666,  Batch Accuracy: 92.97   [ 7680/54000]
# Batch Loss: 0.191067,  Batch Accuracy: 96.09   [ 8960/54000]
# Batch Loss: 0.197389,  Batch Accuracy: 93.75   [10240/54000]
# Batch Loss: 0.150868,  Batch Accuracy: 96.09   [11520/54000]
# Batch Loss: 0.285312,  Batch Accuracy: 88.28   [12800/54000]
# Batch Loss: 0.161899,  Batch Accuracy: 96.09   [14080/54000]
# Batch Loss: 0.124528,  Batch Accuracy: 95.31   [15360/54000]
# Batch Loss: 0.153740,  Batch Accuracy: 94.53   [16640/54000]
# Batch Loss: 0.265283,  Batch Accuracy: 92.97   [17920/54000]
# Batch Loss: 0.141435,  Batch Accuracy: 96.09   [19200/54000]
# Batch Loss: 0.317464,  Batch Accuracy: 89.06   [20480/54000]
# Batch Loss: 0.175371,  Batch Accuracy: 96.09   [21760/54000]
# Batch Loss: 0.215344,  Batch Accuracy: 92.97   [23040/54000]
# Batch Loss: 0.153198,  Batch Accuracy: 92.97   [24320/54000]
# Batch Loss: 0.197825,  Batch Accuracy: 96.09   [25600/54000]
# Batch Loss: 0.152853,  Batch Accuracy: 96.88   [26880/54000]
# Batch Loss: 0.131844,  Batch Accuracy: 94.53   [28160/54000]
# Batch Loss: 0.146604,  Batch Accuracy: 95.31   [29440/54000]
# Batch Loss: 0.148129,  Batch Accuracy: 95.31   [30720/54000]
# Batch Loss: 0.314710,  Batch Accuracy: 91.41   [32000/54000]
# Batch Loss: 0.190756,  Batch Accuracy: 92.97   [33280/54000]
# Batch Loss: 0.268293,  Batch Accuracy: 94.53   [34560/54000]
# Batch Loss: 0.137640,  Batch Accuracy: 95.31   [35840/54000]
# Batch Loss: 0.147683,  Batch Accuracy: 96.88   [37120/54000]
# Batch Loss: 0.183003,  Batch Accuracy: 96.09   [38400/54000]
# Batch Loss: 0.148739,  Batch Accuracy: 93.75   [39680/54000]
# Batch Loss: 0.103011,  Batch Accuracy: 97.66   [40960/54000]
# Batch Loss: 0.212771,  Batch Accuracy: 94.53   [42240/54000]
# Batch Loss: 0.139935,  Batch Accuracy: 95.31   [43520/54000]
# Batch Loss: 0.204037,  Batch Accuracy: 96.09   [44800/54000]
# Batch Loss: 0.130707,  Batch Accuracy: 96.09   [46080/54000]
# Batch Loss: 0.145741,  Batch Accuracy: 96.09   [47360/54000]
# Batch Loss: 0.118099,  Batch Accuracy: 96.09   [48640/54000]
# Batch Loss: 0.156873,  Batch Accuracy: 94.53   [49920/54000]
# Batch Loss: 0.156745,  Batch Accuracy: 94.53   [51200/54000]
# Batch Loss: 0.187302,  Batch Accuracy: 92.19   [52480/54000]
# Batch Loss: 0.114765,  Batch Accuracy: 96.88   [53760/54000]
# Training performance:
#  Accuracy: 94.9%, Loss: 0.177201
# Validation performance:
#  Accuracy: 94.5%, Loss: 0.185551
# Test performance:
#  Accuracy: 94.6%, Loss: 0.179871
#
# Epoch 16
# -------------------------------
# Batch Loss: 0.171107,  Batch Accuracy: 94.53   [ 1280/54000]
# Batch Loss: 0.161618,  Batch Accuracy: 96.88   [ 2560/54000]
# Batch Loss: 0.131006,  Batch Accuracy: 96.09   [ 3840/54000]
# Batch Loss: 0.264218,  Batch Accuracy: 92.97   [ 5120/54000]
# Batch Loss: 0.196427,  Batch Accuracy: 93.75   [ 6400/54000]
# Batch Loss: 0.268178,  Batch Accuracy: 92.97   [ 7680/54000]
# Batch Loss: 0.188560,  Batch Accuracy: 94.53   [ 8960/54000]
# Batch Loss: 0.128443,  Batch Accuracy: 97.66   [10240/54000]
# Batch Loss: 0.252698,  Batch Accuracy: 92.97   [11520/54000]
# Batch Loss: 0.234029,  Batch Accuracy: 90.62   [12800/54000]
# Batch Loss: 0.205784,  Batch Accuracy: 92.97   [14080/54000]
# Batch Loss: 0.177521,  Batch Accuracy: 94.53   [15360/54000]
# Batch Loss: 0.242500,  Batch Accuracy: 90.62   [16640/54000]
# Batch Loss: 0.207361,  Batch Accuracy: 96.09   [17920/54000]
# Batch Loss: 0.245848,  Batch Accuracy: 92.19   [19200/54000]
# Batch Loss: 0.139139,  Batch Accuracy: 94.53   [20480/54000]
# Batch Loss: 0.152819,  Batch Accuracy: 96.09   [21760/54000]
# Batch Loss: 0.139325,  Batch Accuracy: 95.31   [23040/54000]
# Batch Loss: 0.237078,  Batch Accuracy: 91.41   [24320/54000]
# Batch Loss: 0.229628,  Batch Accuracy: 96.09   [25600/54000]
# Batch Loss: 0.172596,  Batch Accuracy: 95.31   [26880/54000]
# Batch Loss: 0.179649,  Batch Accuracy: 95.31   [28160/54000]
# Batch Loss: 0.158180,  Batch Accuracy: 95.31   [29440/54000]
# Batch Loss: 0.158939,  Batch Accuracy: 95.31   [30720/54000]
# Batch Loss: 0.197986,  Batch Accuracy: 95.31   [32000/54000]
# Batch Loss: 0.169820,  Batch Accuracy: 95.31   [33280/54000]
# Batch Loss: 0.189807,  Batch Accuracy: 96.88   [34560/54000]
# Batch Loss: 0.271493,  Batch Accuracy: 92.97   [35840/54000]
# Batch Loss: 0.304934,  Batch Accuracy: 89.84   [37120/54000]
# Batch Loss: 0.098579,  Batch Accuracy: 97.66   [38400/54000]
# Batch Loss: 0.125228,  Batch Accuracy: 96.88   [39680/54000]
# Batch Loss: 0.168832,  Batch Accuracy: 94.53   [40960/54000]
# Batch Loss: 0.249991,  Batch Accuracy: 92.19   [42240/54000]
# Batch Loss: 0.225691,  Batch Accuracy: 94.53   [43520/54000]
# Batch Loss: 0.169496,  Batch Accuracy: 93.75   [44800/54000]
# Batch Loss: 0.115351,  Batch Accuracy: 96.09   [46080/54000]
# Batch Loss: 0.238912,  Batch Accuracy: 94.53   [47360/54000]
# Batch Loss: 0.088859,  Batch Accuracy: 97.66   [48640/54000]
# Batch Loss: 0.136073,  Batch Accuracy: 97.66   [49920/54000]
# Batch Loss: 0.185838,  Batch Accuracy: 93.75   [51200/54000]
# Batch Loss: 0.219725,  Batch Accuracy: 93.75   [52480/54000]
# Batch Loss: 0.139031,  Batch Accuracy: 96.88   [53760/54000]
# Training performance:
#  Accuracy: 95.1%, Loss: 0.170966
# Validation performance:
#  Accuracy: 94.8%, Loss: 0.181722
# Test performance:
#  Accuracy: 94.5%, Loss: 0.175610
#
# Epoch 17
# -------------------------------
# Batch Loss: 0.274300,  Batch Accuracy: 92.97   [ 1280/54000]
# Batch Loss: 0.244635,  Batch Accuracy: 93.75   [ 2560/54000]
# Batch Loss: 0.157692,  Batch Accuracy: 94.53   [ 3840/54000]
# Batch Loss: 0.162516,  Batch Accuracy: 96.88   [ 5120/54000]
# Batch Loss: 0.127849,  Batch Accuracy: 96.09   [ 6400/54000]
# Batch Loss: 0.123129,  Batch Accuracy: 94.53   [ 7680/54000]
# Batch Loss: 0.272734,  Batch Accuracy: 91.41   [ 8960/54000]
# Batch Loss: 0.141279,  Batch Accuracy: 94.53   [10240/54000]
# Batch Loss: 0.110367,  Batch Accuracy: 96.09   [11520/54000]
# Batch Loss: 0.114657,  Batch Accuracy: 96.88   [12800/54000]
# Batch Loss: 0.144899,  Batch Accuracy: 96.88   [14080/54000]
# Batch Loss: 0.126311,  Batch Accuracy: 96.88   [15360/54000]
# Batch Loss: 0.089477,  Batch Accuracy: 96.88   [16640/54000]
# Batch Loss: 0.108632,  Batch Accuracy: 96.09   [17920/54000]
# Batch Loss: 0.103555,  Batch Accuracy: 96.09   [19200/54000]
# Batch Loss: 0.205993,  Batch Accuracy: 95.31   [20480/54000]
# Batch Loss: 0.336419,  Batch Accuracy: 89.84   [21760/54000]
# Batch Loss: 0.192608,  Batch Accuracy: 93.75   [23040/54000]
# Batch Loss: 0.147843,  Batch Accuracy: 94.53   [24320/54000]
# Batch Loss: 0.133801,  Batch Accuracy: 96.88   [25600/54000]
# Batch Loss: 0.118441,  Batch Accuracy: 95.31   [26880/54000]
# Batch Loss: 0.150419,  Batch Accuracy: 96.88   [28160/54000]
# Batch Loss: 0.268312,  Batch Accuracy: 93.75   [29440/54000]
# Batch Loss: 0.092327,  Batch Accuracy: 97.66   [30720/54000]
# Batch Loss: 0.183336,  Batch Accuracy: 95.31   [32000/54000]
# Batch Loss: 0.176210,  Batch Accuracy: 93.75   [33280/54000]
# Batch Loss: 0.195794,  Batch Accuracy: 93.75   [34560/54000]
# Batch Loss: 0.207488,  Batch Accuracy: 92.97   [35840/54000]
# Batch Loss: 0.130386,  Batch Accuracy: 97.66   [37120/54000]
# Batch Loss: 0.139426,  Batch Accuracy: 96.09   [38400/54000]
# Batch Loss: 0.172188,  Batch Accuracy: 96.09   [39680/54000]
# Batch Loss: 0.134062,  Batch Accuracy: 94.53   [40960/54000]
# Batch Loss: 0.121027,  Batch Accuracy: 96.09   [42240/54000]
# Batch Loss: 0.101187,  Batch Accuracy: 98.44   [43520/54000]
# Batch Loss: 0.142513,  Batch Accuracy: 96.09   [44800/54000]
# Batch Loss: 0.160499,  Batch Accuracy: 96.09   [46080/54000]
# Batch Loss: 0.092835,  Batch Accuracy: 98.44   [47360/54000]
# Batch Loss: 0.305156,  Batch Accuracy: 92.97   [48640/54000]
# Batch Loss: 0.138195,  Batch Accuracy: 95.31   [49920/54000]
# Batch Loss: 0.209146,  Batch Accuracy: 94.53   [51200/54000]
# Batch Loss: 0.167306,  Batch Accuracy: 95.31   [52480/54000]
# Batch Loss: 0.086860,  Batch Accuracy: 96.88   [53760/54000]
# Training performance:
#  Accuracy: 95.2%, Loss: 0.165014
# Validation performance:
#  Accuracy: 94.8%, Loss: 0.177176
# Test performance:
#  Accuracy: 94.8%, Loss: 0.171953
#
# Epoch 18
# -------------------------------
# Batch Loss: 0.095446,  Batch Accuracy: 96.09   [ 1280/54000]
# Batch Loss: 0.137263,  Batch Accuracy: 96.88   [ 2560/54000]
# Batch Loss: 0.103484,  Batch Accuracy: 98.44   [ 3840/54000]
# Batch Loss: 0.210322,  Batch Accuracy: 92.19   [ 5120/54000]
# Batch Loss: 0.214981,  Batch Accuracy: 96.09   [ 6400/54000]
# Batch Loss: 0.115042,  Batch Accuracy: 97.66   [ 7680/54000]
# Batch Loss: 0.073122,  Batch Accuracy: 97.66   [ 8960/54000]
# Batch Loss: 0.163791,  Batch Accuracy: 94.53   [10240/54000]
# Batch Loss: 0.112018,  Batch Accuracy: 96.88   [11520/54000]
# Batch Loss: 0.094043,  Batch Accuracy: 97.66   [12800/54000]
# Batch Loss: 0.131950,  Batch Accuracy: 96.09   [14080/54000]
# Batch Loss: 0.249054,  Batch Accuracy: 93.75   [15360/54000]
# Batch Loss: 0.217923,  Batch Accuracy: 92.97   [16640/54000]
# Batch Loss: 0.158541,  Batch Accuracy: 94.53   [17920/54000]
# ...
# Batch Loss: 0.089589,  Batch Accuracy: 97.66   [15360/54000]
# Batch Loss: 0.052105,  Batch Accuracy: 98.44   [16640/54000]
# Batch Loss: 0.112372,  Batch Accuracy: 96.88   [17920/54000]
# Batch Loss: 0.049035,  Batch Accuracy: 98.44   [19200/54000]
# Batch Loss: 0.073979,  Batch Accuracy: 98.44   [20480/54000]
# Batch Loss: 0.058366,  Batch Accuracy: 98.44   [21760/54000]
# Batch Loss: 0.076521,  Batch Accuracy: 98.44   [23040/54000]
# Batch Loss: 0.042064,  Batch Accuracy: 98.44   [24320/54000]
# Batch Loss: 0.083677,  Batch Accuracy: 97.66   [25600/54000]
# Batch Loss: 0.061292,  Batch Accuracy: 98.44   [26880/54000]
# Batch Loss: 0.108013,  Batch Accuracy: 96.88   [28160/54000]
# Batch Loss: 0.101053,  Batch Accuracy: 97.66   [29440/54000]
# Batch Loss: 0.033348,  Batch Accuracy: 98.44   [30720/54000]
# Batch Loss: 0.037939,  Batch Accuracy: 99.22   [32000/54000]
# Batch Loss: 0.056070,  Batch Accuracy: 97.66   [33280/54000]
# Batch Loss: 0.022973,  Batch Accuracy: 100.00   [34560/54000]
# Batch Loss: 0.110342,  Batch Accuracy: 95.31   [35840/54000]
# Batch Loss: 0.054094,  Batch Accuracy: 98.44   [37120/54000]
# Batch Loss: 0.067266,  Batch Accuracy: 98.44   [38400/54000]
# Batch Loss: 0.063794,  Batch Accuracy: 99.22   [39680/54000]
# Batch Loss: 0.053918,  Batch Accuracy: 98.44   [40960/54000]
# Batch Loss: 0.021083,  Batch Accuracy: 100.00   [42240/54000]
# Batch Loss: 0.046782,  Batch Accuracy: 99.22   [43520/54000]
# Batch Loss: 0.046422,  Batch Accuracy: 99.22   [44800/54000]
# Batch Loss: 0.033881,  Batch Accuracy: 100.00   [46080/54000]
# Batch Loss: 0.112348,  Batch Accuracy: 98.44   [47360/54000]
# Batch Loss: 0.045816,  Batch Accuracy: 99.22   [48640/54000]
# Batch Loss: 0.071705,  Batch Accuracy: 98.44   [49920/54000]
# Batch Loss: 0.055577,  Batch Accuracy: 99.22   [51200/54000]
# Batch Loss: 0.056669,  Batch Accuracy: 99.22   [52480/54000]
# Batch Loss: 0.084195,  Batch Accuracy: 96.88   [53760/54000]
# Training performance:
#  Accuracy: 98.2%, Loss: 0.067602
# Validation performance:
#  Accuracy: 96.8%, Loss: 0.105885
# Test performance:
#  Accuracy: 96.7%, Loss: 0.105102
#
# Epoch 56
# -------------------------------
# Batch Loss: 0.047892,  Batch Accuracy: 99.22   [ 1280/54000]
# Batch Loss: 0.066436,  Batch Accuracy: 98.44   [ 2560/54000]
# Batch Loss: 0.092835,  Batch Accuracy: 96.88   [ 3840/54000]
# Batch Loss: 0.120617,  Batch Accuracy: 96.88   [ 5120/54000]
# Batch Loss: 0.085259,  Batch Accuracy: 96.88   [ 6400/54000]
# Batch Loss: 0.029723,  Batch Accuracy: 99.22   [ 7680/54000]
# Batch Loss: 0.034042,  Batch Accuracy: 99.22   [ 8960/54000]
# Batch Loss: 0.057383,  Batch Accuracy: 98.44   [10240/54000]
# Batch Loss: 0.063130,  Batch Accuracy: 99.22   [11520/54000]
# Batch Loss: 0.023960,  Batch Accuracy: 100.00   [12800/54000]
# Batch Loss: 0.074452,  Batch Accuracy: 97.66   [14080/54000]
# Batch Loss: 0.152176,  Batch Accuracy: 92.97   [15360/54000]
# Batch Loss: 0.054995,  Batch Accuracy: 98.44   [16640/54000]
# Batch Loss: 0.037460,  Batch Accuracy: 99.22   [17920/54000]
# Batch Loss: 0.090764,  Batch Accuracy: 97.66   [19200/54000]
# Batch Loss: 0.157560,  Batch Accuracy: 95.31   [20480/54000]
# Batch Loss: 0.096700,  Batch Accuracy: 97.66   [21760/54000]
# Batch Loss: 0.038778,  Batch Accuracy: 99.22   [23040/54000]
# Batch Loss: 0.060314,  Batch Accuracy: 97.66   [24320/54000]
# Batch Loss: 0.098058,  Batch Accuracy: 96.88   [25600/54000]
# Batch Loss: 0.042585,  Batch Accuracy: 99.22   [26880/54000]
# Batch Loss: 0.114879,  Batch Accuracy: 97.66   [28160/54000]
# Batch Loss: 0.056993,  Batch Accuracy: 98.44   [29440/54000]
# Batch Loss: 0.079998,  Batch Accuracy: 97.66   [30720/54000]
# Batch Loss: 0.067565,  Batch Accuracy: 97.66   [32000/54000]
# Batch Loss: 0.079335,  Batch Accuracy: 97.66   [33280/54000]
# Batch Loss: 0.046451,  Batch Accuracy: 99.22   [34560/54000]
# Batch Loss: 0.021811,  Batch Accuracy: 100.00   [35840/54000]
# Batch Loss: 0.048624,  Batch Accuracy: 98.44   [37120/54000]
# Batch Loss: 0.096842,  Batch Accuracy: 96.09   [38400/54000]
# Batch Loss: 0.069133,  Batch Accuracy: 97.66   [39680/54000]
# Batch Loss: 0.230268,  Batch Accuracy: 95.31   [40960/54000]
# Batch Loss: 0.089955,  Batch Accuracy: 97.66   [42240/54000]
# Batch Loss: 0.060429,  Batch Accuracy: 97.66   [43520/54000]
# Batch Loss: 0.056149,  Batch Accuracy: 99.22   [44800/54000]
# Batch Loss: 0.164002,  Batch Accuracy: 96.09   [46080/54000]
# Batch Loss: 0.056153,  Batch Accuracy: 99.22   [47360/54000]
# Batch Loss: 0.063989,  Batch Accuracy: 97.66   [48640/54000]
# Batch Loss: 0.060701,  Batch Accuracy: 97.66   [49920/54000]
# Batch Loss: 0.068251,  Batch Accuracy: 97.66   [51200/54000]
# Batch Loss: 0.081994,  Batch Accuracy: 96.88   [52480/54000]
# Batch Loss: 0.070143,  Batch Accuracy: 97.66   [53760/54000]
# Training performance:
#  Accuracy: 98.2%, Loss: 0.066339
# Validation performance:
#  Accuracy: 96.8%, Loss: 0.104605
# Test performance:
#  Accuracy: 96.7%, Loss: 0.104839
#
# Epoch 57
# -------------------------------
# Batch Loss: 0.029976,  Batch Accuracy: 100.00   [ 1280/54000]
# Batch Loss: 0.040011,  Batch Accuracy: 99.22   [ 2560/54000]
# Batch Loss: 0.024756,  Batch Accuracy: 100.00   [ 3840/54000]
# Batch Loss: 0.043098,  Batch Accuracy: 99.22   [ 5120/54000]
# Batch Loss: 0.036637,  Batch Accuracy: 100.00   [ 6400/54000]
# Batch Loss: 0.050746,  Batch Accuracy: 99.22   [ 7680/54000]
# Batch Loss: 0.046579,  Batch Accuracy: 100.00   [ 8960/54000]
# Batch Loss: 0.068192,  Batch Accuracy: 98.44   [10240/54000]
# Batch Loss: 0.054042,  Batch Accuracy: 98.44   [11520/54000]
# Batch Loss: 0.049472,  Batch Accuracy: 100.00   [12800/54000]
# Batch Loss: 0.042765,  Batch Accuracy: 98.44   [14080/54000]
# Batch Loss: 0.077205,  Batch Accuracy: 99.22   [15360/54000]
# Batch Loss: 0.059079,  Batch Accuracy: 98.44   [16640/54000]
# Batch Loss: 0.028387,  Batch Accuracy: 99.22   [17920/54000]
# Batch Loss: 0.118565,  Batch Accuracy: 96.09   [19200/54000]
# Batch Loss: 0.037285,  Batch Accuracy: 99.22   [20480/54000]
# Batch Loss: 0.017794,  Batch Accuracy: 100.00   [21760/54000]
# Batch Loss: 0.083412,  Batch Accuracy: 96.09   [23040/54000]
# Batch Loss: 0.036295,  Batch Accuracy: 99.22   [24320/54000]
# Batch Loss: 0.045858,  Batch Accuracy: 98.44   [25600/54000]
# Batch Loss: 0.043902,  Batch Accuracy: 99.22   [26880/54000]
# Batch Loss: 0.088235,  Batch Accuracy: 98.44   [28160/54000]
# Batch Loss: 0.070481,  Batch Accuracy: 99.22   [29440/54000]
# Batch Loss: 0.103599,  Batch Accuracy: 96.09   [30720/54000]
# Batch Loss: 0.084695,  Batch Accuracy: 97.66   [32000/54000]
# Batch Loss: 0.126584,  Batch Accuracy: 96.09   [33280/54000]
# Batch Loss: 0.035310,  Batch Accuracy: 99.22   [34560/54000]
# Batch Loss: 0.037772,  Batch Accuracy: 100.00   [35840/54000]
# Batch Loss: 0.039143,  Batch Accuracy: 100.00   [37120/54000]
# Batch Loss: 0.034223,  Batch Accuracy: 100.00   [38400/54000]
# Batch Loss: 0.061303,  Batch Accuracy: 98.44   [39680/54000]
# Batch Loss: 0.039384,  Batch Accuracy: 99.22   [40960/54000]
# Batch Loss: 0.047304,  Batch Accuracy: 97.66   [42240/54000]
# Batch Loss: 0.042146,  Batch Accuracy: 99.22   [43520/54000]
# Batch Loss: 0.039963,  Batch Accuracy: 98.44   [44800/54000]
# Batch Loss: 0.069624,  Batch Accuracy: 97.66   [46080/54000]
# Batch Loss: 0.076223,  Batch Accuracy: 97.66   [47360/54000]
# Batch Loss: 0.029767,  Batch Accuracy: 99.22   [48640/54000]
# Batch Loss: 0.053107,  Batch Accuracy: 98.44   [49920/54000]
# Batch Loss: 0.051851,  Batch Accuracy: 97.66   [51200/54000]
# Batch Loss: 0.038496,  Batch Accuracy: 99.22   [52480/54000]
# Batch Loss: 0.051047,  Batch Accuracy: 99.22   [53760/54000]
# Training performance:
#  Accuracy: 98.2%, Loss: 0.065163
# Validation performance:
#  Accuracy: 97.0%, Loss: 0.104172
# Test performance:
#  Accuracy: 96.8%, Loss: 0.104836
#
# Epoch 58
# -------------------------------
# Batch Loss: 0.047317,  Batch Accuracy: 98.44   [ 1280/54000]
# Batch Loss: 0.035984,  Batch Accuracy: 100.00   [ 2560/54000]
# Batch Loss: 0.049427,  Batch Accuracy: 98.44   [ 3840/54000]
# Batch Loss: 0.051577,  Batch Accuracy: 99.22   [ 5120/54000]
# Batch Loss: 0.059983,  Batch Accuracy: 99.22   [ 6400/54000]
# Batch Loss: 0.035823,  Batch Accuracy: 99.22   [ 7680/54000]
# Batch Loss: 0.093932,  Batch Accuracy: 94.53   [ 8960/54000]
# Batch Loss: 0.045181,  Batch Accuracy: 99.22   [10240/54000]
# Batch Loss: 0.081153,  Batch Accuracy: 97.66   [11520/54000]
# Batch Loss: 0.062631,  Batch Accuracy: 99.22   [12800/54000]
# Batch Loss: 0.052419,  Batch Accuracy: 98.44   [14080/54000]
# Batch Loss: 0.074766,  Batch Accuracy: 97.66   [15360/54000]
# Batch Loss: 0.039106,  Batch Accuracy: 98.44   [16640/54000]
# Batch Loss: 0.037872,  Batch Accuracy: 100.00   [17920/54000]
# Batch Loss: 0.150003,  Batch Accuracy: 96.88   [19200/54000]
# Batch Loss: 0.061003,  Batch Accuracy: 97.66   [20480/54000]
# Batch Loss: 0.074325,  Batch Accuracy: 98.44   [21760/54000]
# Batch Loss: 0.049160,  Batch Accuracy: 98.44   [23040/54000]
# Batch Loss: 0.105459,  Batch Accuracy: 96.88   [24320/54000]
# Batch Loss: 0.151716,  Batch Accuracy: 97.66   [25600/54000]
# Batch Loss: 0.039351,  Batch Accuracy: 99.22   [26880/54000]
# Batch Loss: 0.086992,  Batch Accuracy: 98.44   [28160/54000]
# Batch Loss: 0.038497,  Batch Accuracy: 99.22   [29440/54000]
# Batch Loss: 0.023614,  Batch Accuracy: 100.00   [30720/54000]
# Batch Loss: 0.083997,  Batch Accuracy: 96.88   [32000/54000]
# Batch Loss: 0.042810,  Batch Accuracy: 99.22   [33280/54000]
# Batch Loss: 0.049105,  Batch Accuracy: 97.66   [34560/54000]
# Batch Loss: 0.024753,  Batch Accuracy: 100.00   [35840/54000]
# Batch Loss: 0.036070,  Batch Accuracy: 99.22   [37120/54000]
# Batch Loss: 0.028624,  Batch Accuracy: 100.00   [38400/54000]
# Batch Loss: 0.055337,  Batch Accuracy: 98.44   [39680/54000]
# Batch Loss: 0.037701,  Batch Accuracy: 100.00   [40960/54000]
# Batch Loss: 0.106450,  Batch Accuracy: 96.88   [42240/54000]
# Batch Loss: 0.063546,  Batch Accuracy: 97.66   [43520/54000]
# Batch Loss: 0.036833,  Batch Accuracy: 99.22   [44800/54000]
# Batch Loss: 0.062755,  Batch Accuracy: 97.66   [46080/54000]
# Batch Loss: 0.044454,  Batch Accuracy: 99.22   [47360/54000]
# Batch Loss: 0.041808,  Batch Accuracy: 99.22   [48640/54000]
# Batch Loss: 0.025842,  Batch Accuracy: 99.22   [49920/54000]
# Batch Loss: 0.049918,  Batch Accuracy: 99.22   [51200/54000]
# Batch Loss: 0.145134,  Batch Accuracy: 96.09   [52480/54000]
# Batch Loss: 0.115024,  Batch Accuracy: 96.09   [53760/54000]
# Training performance:
#  Accuracy: 98.3%, Loss: 0.063859
# Validation performance:
#  Accuracy: 96.9%, Loss: 0.104419
# Test performance:
#  Accuracy: 96.8%, Loss: 0.103517
#
# Epoch 59
# -------------------------------
# Batch Loss: 0.067605,  Batch Accuracy: 97.66   [ 1280/54000]
# Batch Loss: 0.081301,  Batch Accuracy: 96.88   [ 2560/54000]
# Batch Loss: 0.059115,  Batch Accuracy: 96.88   [ 3840/54000]
# Batch Loss: 0.041308,  Batch Accuracy: 99.22   [ 5120/54000]
# Batch Loss: 0.044985,  Batch Accuracy: 99.22   [ 6400/54000]
# Batch Loss: 0.046125,  Batch Accuracy: 100.00   [ 7680/54000]
# Batch Loss: 0.070432,  Batch Accuracy: 98.44   [ 8960/54000]
# Batch Loss: 0.053787,  Batch Accuracy: 97.66   [10240/54000]
# Batch Loss: 0.059037,  Batch Accuracy: 97.66   [11520/54000]
# Batch Loss: 0.140489,  Batch Accuracy: 95.31   [12800/54000]
# Batch Loss: 0.078218,  Batch Accuracy: 97.66   [14080/54000]
# Batch Loss: 0.064874,  Batch Accuracy: 98.44   [15360/54000]
# Batch Loss: 0.074997,  Batch Accuracy: 98.44   [16640/54000]
# Batch Loss: 0.030233,  Batch Accuracy: 99.22   [17920/54000]
# Batch Loss: 0.088130,  Batch Accuracy: 95.31   [19200/54000]
# Batch Loss: 0.077269,  Batch Accuracy: 97.66   [20480/54000]
# Batch Loss: 0.052957,  Batch Accuracy: 98.44   [21760/54000]
# Batch Loss: 0.117465,  Batch Accuracy: 94.53   [23040/54000]
# Batch Loss: 0.072316,  Batch Accuracy: 98.44   [24320/54000]
# Batch Loss: 0.041710,  Batch Accuracy: 98.44   [25600/54000]
# Batch Loss: 0.038060,  Batch Accuracy: 100.00   [26880/54000]
# Batch Loss: 0.038462,  Batch Accuracy: 99.22   [28160/54000]
# Batch Loss: 0.066259,  Batch Accuracy: 96.88   [29440/54000]
# Batch Loss: 0.058965,  Batch Accuracy: 97.66   [30720/54000]
# Batch Loss: 0.033561,  Batch Accuracy: 99.22   [32000/54000]
# Batch Loss: 0.032833,  Batch Accuracy: 99.22   [33280/54000]
# Batch Loss: 0.060276,  Batch Accuracy: 97.66   [34560/54000]
# Batch Loss: 0.056280,  Batch Accuracy: 97.66   [35840/54000]
# Batch Loss: 0.042134,  Batch Accuracy: 98.44   [37120/54000]
# Batch Loss: 0.043963,  Batch Accuracy: 99.22   [38400/54000]
# Batch Loss: 0.094667,  Batch Accuracy: 97.66   [39680/54000]
# Batch Loss: 0.104984,  Batch Accuracy: 96.88   [40960/54000]
# Batch Loss: 0.078751,  Batch Accuracy: 97.66   [42240/54000]
# Batch Loss: 0.046087,  Batch Accuracy: 99.22   [43520/54000]
# Batch Loss: 0.036904,  Batch Accuracy: 98.44   [44800/54000]
# Batch Loss: 0.082455,  Batch Accuracy: 98.44   [46080/54000]
# Batch Loss: 0.060737,  Batch Accuracy: 98.44   [47360/54000]
# Batch Loss: 0.044054,  Batch Accuracy: 98.44   [48640/54000]
# Batch Loss: 0.094102,  Batch Accuracy: 96.88   [49920/54000]
# Batch Loss: 0.075156,  Batch Accuracy: 97.66   [51200/54000]
# Batch Loss: 0.041798,  Batch Accuracy: 98.44   [52480/54000]
# Batch Loss: 0.058013,  Batch Accuracy: 98.44   [53760/54000]
# Training performance:
#  Accuracy: 98.3%, Loss: 0.062646
# Validation performance:
#  Accuracy: 97.0%, Loss: 0.102871
# Test performance:
#  Accuracy: 96.8%, Loss: 0.103623
#
# Epoch 60
# -------------------------------
# Batch Loss: 0.065621,  Batch Accuracy: 97.66   [ 1280/54000]
# Batch Loss: 0.030302,  Batch Accuracy: 100.00   [ 2560/54000]
# Batch Loss: 0.081773,  Batch Accuracy: 96.88   [ 3840/54000]
# Batch Loss: 0.048697,  Batch Accuracy: 97.66   [ 5120/54000]
# Batch Loss: 0.042643,  Batch Accuracy: 98.44   [ 6400/54000]
# Batch Loss: 0.062998,  Batch Accuracy: 98.44   [ 7680/54000]
# Batch Loss: 0.052498,  Batch Accuracy: 99.22   [ 8960/54000]
# Batch Loss: 0.082886,  Batch Accuracy: 97.66   [10240/54000]
# Batch Loss: 0.043480,  Batch Accuracy: 99.22   [11520/54000]
# Batch Loss: 0.057872,  Batch Accuracy: 97.66   [12800/54000]
# Batch Loss: 0.030830,  Batch Accuracy: 100.00   [14080/54000]
# Batch Loss: 0.125868,  Batch Accuracy: 96.88   [15360/54000]
# Batch Loss: 0.052029,  Batch Accuracy: 99.22   [16640/54000]
# Batch Loss: 0.029922,  Batch Accuracy: 100.00   [17920/54000]
# Batch Loss: 0.057077,  Batch Accuracy: 98.44   [19200/54000]
# Batch Loss: 0.086114,  Batch Accuracy: 97.66   [20480/54000]
# Batch Loss: 0.120474,  Batch Accuracy: 98.44   [21760/54000]
# Batch Loss: 0.035478,  Batch Accuracy: 100.00   [23040/54000]
# Batch Loss: 0.068659,  Batch Accuracy: 98.44   [24320/54000]
# Batch Loss: 0.084014,  Batch Accuracy: 97.66   [25600/54000]
# Batch Loss: 0.095379,  Batch Accuracy: 95.31   [26880/54000]
# Batch Loss: 0.057578,  Batch Accuracy: 97.66   [28160/54000]
# Batch Loss: 0.140421,  Batch Accuracy: 98.44   [29440/54000]
# Batch Loss: 0.056208,  Batch Accuracy: 98.44   [30720/54000]
# Batch Loss: 0.019837,  Batch Accuracy: 100.00   [32000/54000]
# Batch Loss: 0.062247,  Batch Accuracy: 98.44   [33280/54000]
# Batch Loss: 0.036511,  Batch Accuracy: 99.22   [34560/54000]
# Batch Loss: 0.056896,  Batch Accuracy: 99.22   [35840/54000]
# Batch Loss: 0.096187,  Batch Accuracy: 98.44   [37120/54000]
# Batch Loss: 0.132950,  Batch Accuracy: 94.53   [38400/54000]
# Batch Loss: 0.063522,  Batch Accuracy: 99.22   [39680/54000]
# Batch Loss: 0.043633,  Batch Accuracy: 98.44   [40960/54000]
# Batch Loss: 0.097328,  Batch Accuracy: 96.88   [42240/54000]
# Batch Loss: 0.019802,  Batch Accuracy: 100.00   [43520/54000]
# Batch Loss: 0.094005,  Batch Accuracy: 96.88   [44800/54000]
# Batch Loss: 0.064389,  Batch Accuracy: 97.66   [46080/54000]
# Batch Loss: 0.078991,  Batch Accuracy: 98.44   [47360/54000]
# Batch Loss: 0.107656,  Batch Accuracy: 96.88   [48640/54000]
# Batch Loss: 0.075114,  Batch Accuracy: 97.66   [49920/54000]
# Batch Loss: 0.096105,  Batch Accuracy: 96.88   [51200/54000]
# Batch Loss: 0.036876,  Batch Accuracy: 99.22   [52480/54000]
# Batch Loss: 0.045380,  Batch Accuracy: 98.44   [53760/54000]
# Training performance:
#  Accuracy: 98.4%, Loss: 0.061473
# Validation performance:
#  Accuracy: 96.9%, Loss: 0.102340
# Test performance:
#  Accuracy: 96.8%, Loss: 0.103325
#
# Time taken to train the model: 1.9281665325164794 minutes

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), train_losses, label='Train')
plt.plot(range(num_epochs), val_losses, label='Validation')
plt.plot(range(num_epochs), test_losses, label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), train_accuracies, label='Train')
plt.plot(range(num_epochs), val_accuracies, label='Validation')
plt.plot(range(num_epochs), test_accuracies, label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Epoch')
plt.legend()
plt.tight_layout()
plt.show()

# %%
torch.save({
    'hidden_layers_sizes' : [512, 256, 128, 64],
    'epoch': num_epochs,
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict(),
    'loss': criterion,
    'model': model,
    'metrics':{
        'train_acc' : train_accuracies[-1], 'test_acc' : test_accuracies[-1], 'val_acc' : val_accuracies[-1],
        'train_loss': train_losses[-1], 'val_loss': val_losses[-1], 'test_loss' : test_losses[-1]
      }
    }, 'mlp_512_256_128_64.pth')

# %%
chkpt = torch.load('mlp_512_256_128_64.pth')
chkpt['metrics'], chkpt['hidden_layers_sizes']
# Out:
# ({'train_acc': 98.4,
#   'test_acc': 96.77,
#   'val_acc': 96.88333333333334,
#   'train_loss': 0.06147335503930094,
#   'val_loss': 0.10233966705012829,
#   'test_loss': 0.10332527601003906},
#  [512, 256, 128, 64])

# %% [markdown]
# # Question-3

# %%
import torch
import math
import time
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
from typing import List

# %% [markdown]
# ### Classes for Activation Functions

# %%
class SoftMax:
    def __init__(self, nodes:int):
        self.nodes = nodes
        self.activation = torch.zeros((nodes, 1))

    def forward(self, x:torch.Tensor) -> torch.Tensor:
        self.activation = torch.exp(x) / torch.sum(torch.exp(x))
        return self.activation

    def backward(self, x):
        # x = self.forward(x)
        # return torch.diag(x.flatten()) - torch.outer(x, x)
        return torch.diag(self.activation.squeeze()) - torch.outer(self.activation.squeeze(), self.activation.squeeze())

class ReLU:
    def __init__(self, nodes:int):
        self.nodes = nodes
        self.activation = torch.zeros((nodes, 1))

    def forward(self, x:torch.Tensor) -> torch.Tensor:
        self.activation = torch.max(torch.zeros_like(x), x)
        return self.activation

    def backward(self, x):
        return torch.where(x >= 0, torch.ones_like(x), torch.zeros_like(x))

class LinearActivation:
    def __init__(self, nodes:int):
        self.nodes = nodes
        self.activation = torch.zeros((nodes, 1))

    def forward(self, x:torch.Tensor) -> torch.Tensor:
        self.activation = x.clone()
        return self.activation

    def backward(self, x):
        return torch.ones_like(x)

class TanH:
    def __init__(self, nodes:int):
        self.nodes = nodes
        self.activation = torch.zeros((nodes, 1))

    def forward(self, x:torch.Tensor) -> torch.Tensor:
        self.activation = torch.tanh(x)
        return self.activation

    def backward(self, x):
        # return 1 - torch.tanh(x) ** 2
        return 1 - self.activation ** 2

# %% [markdown]
# ### Class for Linear Layers

# %%
class Linear:
	def __init__(self, in_features:int, out_features:int, bias:bool=True, device:str='cpu'):
		self.in_features = in_features
		self.out_features = out_features
		self.weights = torch.randn((out_features, in_features), device=device).div_(math.sqrt(in_features + out_features))
		self.bias = torch.randn((out_features, 1), device=device).div_(math.sqrt(in_features + out_features)) if bias else None
		self.grad_weights = torch.zeros_like(self.weights, device=device)
		self.grad_bias = torch.zeros_like(self.bias, device=device) if bias else None
		self.z = torch.zeros((out_features, 1), device=device)
		self.error_output = torch.zeros((out_features, 1), device=device)


	def forward(self, x:torch.Tensor) -> torch.Tensor:
		self.z = torch.matmul(self.weights, x)
		if self.bias is not None:
			self.z += self.bias
		return self.z


	def backward(self, activation_value_prevlayer:torch.Tensor):
		self.grad_weights += torch.matmul(self.error_output, activation_value_prevlayer.T)
		if self.bias is not None:
			self.grad_bias += self.error_output

# %% [markdown]
# ### Class for Cross-Entropy Loss & SGD Optimizer

# %%
class CrossEntropyLoss:
    def __init__(self, device:str='cpu'):
        self.device = device
        self.loss = torch.tensor(0.0, device=device)

    def forward(self, output:torch.Tensor, labels:torch.Tensor, use_softmax:bool=False) -> torch.Tensor:
        if use_softmax:
            output = SoftMax(output.shape[1]).forward(output)
        self.loss += -torch.sum(torch.log(output[:, labels.long()]))  #/ labels.shape[0]
        return self.item()

    def backward(self, model, true_labels:torch.Tensor):
        model.backward(true_labels)

    def item(self):
        return self.loss.item()

    def reset(self):
        self.loss = torch.tensor(0.0, device=self.device)

class SGD:
    def __init__(self, model_parameters:List[Linear], lr:float=0.01):
        self.model_parameters = model_parameters
        self.lr = lr

    def step(self):
        for layer in self.model_parameters:
            layer.weights += self.lr * layer.grad_weights
            if layer.bias is not None:
                layer.bias += self.lr * layer.grad_bias

    def zero_grad(self):
        for layer in self.model_parameters:
            layer.grad_weights.zero_()
            if layer.bias is not None:
                layer.grad_bias.zero_()

# %% [markdown]
# ### Class for Neural Network

# %%
class NeuralNetwork:
    def __init__(self, in_features:int = 28*28, out_features:int = 10, device:str='cpu'):
        '''
        in_features: Number of input features
        out_features: Number of output features
        '''
        self.in_features = in_features
        self.out_features = out_features
        self.device = device
        self.fc1 = Linear(in_features, 512, bias=True, device=device)
        self.relu1 = ReLU(512)
        self.fc2 = Linear(512, 256, bias=True, device=device)
        self.relu2 = ReLU(256)
        self.fc3 = Linear(256, 128, bias=True, device=device)
        self.relu3 = ReLU(128)
        self.fc4 = Linear(128, 64, bias=True, device=device)
        self.relu4 = ReLU(64)
        self.fc5 = Linear(64, out_features, bias=True, device=device)
        self.softmax = SoftMax(out_features)
        self.parameters = [self.fc1, self.fc2, self.fc3, self.fc4, self.fc5]
        self.activations = [self.relu1, self.relu2, self.relu3, self.relu4, self.softmax]
        self.input_feature = None


    def forward(self, x:torch.Tensor) -> torch.Tensor:
        self.input_feature = x.clone()
        x = self.fc1.forward(x)
        x = self.relu1.forward(x)
        x = self.fc2.forward(x)
        x = self.relu2.forward(x)
        x = self.fc3.forward(x)
        x = self.relu3.forward(x)
        x = self.fc4.forward(x)
        x = self.relu4.forward(x)
        x = self.fc5.forward(x)
        x = self.softmax.forward(x)
        return x

    def backward(self, true_labels:torch.Tensor):
        true_labels = torch.zeros((self.out_features, 1), device=device).scatter_(0, true_labels.view(-1, 1), 1)
        self.fc5.error_output = torch.matmul(self.softmax.backward(self.fc5.z), true_labels - self.softmax.activation)
        # self.fc5.error_output = true_labels - self.fc5.z
        self.fc5.backward(self.relu4.activation)
        self.fc4.error_output = self.relu4.backward(self.fc4.z) * torch.matmul(self.fc5.weights.T, self.fc5.error_output)
        self.fc4.backward(self.relu3.activation)
        self.fc3.error_output = self.relu3.backward(self.fc3.z) * torch.matmul(self.fc4.weights.T, self.fc4.error_output)
        self.fc3.backward(self.relu2.activation)
        self.fc2.error_output = self.relu2.backward(self.fc2.z) * torch.matmul(self.fc3.weights.T, self.fc3.error_output)
        self.fc2.backward(self.relu1.activation)
        self.fc1.error_output = self.relu1.backward(self.fc1.z) * torch.matmul(self.fc2.weights.T, self.fc2.error_output)
        self.fc1.backward(self.input_feature)

# %% [markdown]
# ### Initialize Dataset and DataLoaders

# %%
# Creating training and test datasets
root = './data/MNIST/raw/'
train_dataset = MNISTCustomDataset(root=root, train=True, transform=None)
test_dataset = MNISTCustomDataset(root=root, train=False, transform=None)

# splitting of training and validation set
batch_size = 128
valid_size = 0.1
num_train = len(train_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_index, valid_index = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_index)
valid_sampler = SubsetRandomSampler(valid_index)

# Create data loaders
train_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, shuffle=False)
valid_loader = DataLoader(train_dataset, batch_size=batch_size, sampler=valid_sampler, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

print('Train Dataset Length: {}'.format(len(train_sampler)))
print('Validation Dataset Length: {}'.format(len(valid_sampler)))
print('Test Dataset Length: {}\n'.format(len(test_dataset)))

for images, labels in train_loader:
    print(images.shape, labels.shape)
    print(type(images), type(labels))
    print(images.dtype, labels.dtype)
    break
# Out:
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 60000
# Dataset image shape: torch.Size([60000, 1, 28, 28])
# Dataset label shape: torch.Size([60000])
#
# MNIST Custom Dataset Initialized...
# MNIST Custom Dataset length: 10000
# Dataset image shape: torch.Size([10000, 1, 28, 28])
# Dataset label shape: torch.Size([10000])
#
# Train Dataset Length: 54000
# Validation Dataset Length: 6000
# Test Dataset Length: 10000
#
# torch.Size([128, 1, 28, 28]) torch.Size([128])
# <class 'torch.Tensor'> <class 'torch.Tensor'>
# torch.float32 torch.int64

# %% [markdown]
# ### Intialize Custom Model, Loss and Optimizer

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

model_custom = NeuralNetwork(in_features=28*28, out_features=10, device=device)
sgd_optimizer = SGD(model_custom.parameters, lr=0.0003)
ce_loss = CrossEntropyLoss(device=device)
# Out:
# cuda:0

# %%
# Training loop
def train_Q3(model_custom:NeuralNetwork, train_loader:DataLoader, sgd_optimizer:SGD, ce_loss:CrossEntropyLoss):
    train_loss = 0.0
    correct = 0
    total = 0
    batch = 0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        sgd_optimizer.zero_grad()
        ce_loss.reset()
        batch_loss = 0
        batch_correct = 0

        for i in range(len(images)):
            image = images[i, 0].view(28*28, -1)
            image = image / 255.0
            label = labels[i]
            output = model_custom.forward(image)
            batch_loss += ce_loss.forward(output.T, label)
            ce_loss.backward(model_custom, label)
            # print(model_custom.fc4.grad_weights)
            _, predicted = torch.max(output.data.T, 1)
            batch_correct += (predicted == label).sum().item()

        sgd_optimizer.step()
        batch_loss = batch_loss / len(images)
        train_loss += batch_loss
        batch_accuracy = 100 * batch_correct / len(images)
        correct += batch_correct
        total += labels.size(0)
        if (batch + 1) % 10 == 0:
            loss_item, current = ce_loss.item(), (batch + 1) * len(images)
            print(f"Batch loss: {batch_loss:>7f},  Batch Accuracy: {batch_accuracy:>0.2f}  [{current:>5d}/{len(train_sampler):>5d}]")
        batch += 1

    accuracy = 100 * correct / total
    train_loss = train_loss / len(train_loader)
    print(f"Training performance: \n Accuracy: {accuracy:>0.1f}%, Loss: {train_loss:>8f}")
    return train_loss, accuracy


# Validation loop
def validate_Q3(model_custom:NeuralNetwork, valid_loader:DataLoader, ce_loss:CrossEntropyLoss):
    val_loss = 0.0
    correct = 0
    total = 0
    for images, labels in valid_loader:
        images, labels = images.to(device), labels.to(device)
        ce_loss.reset()
        batch_loss = 0
        batch_correct = 0

        for i in range(len(images)):
            image = images[i, 0].view(28*28, -1)
            label = labels[i]
            image = image / 255.0
            output = model_custom.forward(image)
            batch_loss += ce_loss.forward(output.T, label)
            _, predicted = torch.max(output.data.T, 1)
            batch_correct += (predicted == label).sum().item()
        batch_loss = batch_loss / len(images)
        val_loss += batch_loss
        correct += batch_correct
        total += labels.size(0)

    accuracy = 100 * correct / total
    val_loss = val_loss / len(valid_loader)
    print(f"Validation performance: \n Accuracy: {accuracy:>0.1f}%, Loss: {val_loss:>8f}")
    return val_loss, accuracy


# Testing loop
def test_Q3(model_custom:NeuralNetwork, test_loader:DataLoader, ce_loss:CrossEntropyLoss):
    test_loss = 0.0
    correct = 0
    total = 0
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        ce_loss.reset()
        batch_loss = 0
        batch_correct = 0

        for i in range(len(images)):
            image = images[i, 0].view(28*28, -1)
            label = labels[i]
            image = image / 255.0
            output = model_custom.forward(image)
            batch_loss += ce_loss.forward(output.T, label)
            _, predicted = torch.max(output.data.T, 1)
            batch_correct += (predicted == label).sum().item()

        batch_loss = batch_loss / len(images)
        test_loss += batch_loss
        correct += batch_correct
        total += labels.size(0)

    accuracy = 100 * correct / total
    test_loss = test_loss / len(test_loader)
    print(f"Test performance: \n Accuracy: {accuracy:>0.1f}%, Loss: {test_loss:>8f} \n")
    return test_loss, accuracy


# Training, Validation and Testing of the model_custom
num_epochs = 60
train_losses_q3, train_accuracies_q3 = [], []
val_losses_q3, val_accuracies_q3 = [], []
test_losses_q3, test_accuracies_q3 = [], []
start_time = time.time()

for epoch in range(num_epochs):
    print(f"Epoch {epoch + 1}\n-------------------------------")
    train_loss, train_accuracy = train_Q3(model_custom, train_loader, sgd_optimizer, ce_loss)
    val_loss, val_accuracy = validate_Q3(model_custom, valid_loader, ce_loss)
    test_loss, test_accuracy = test_Q3(model_custom, test_loader, ce_loss)

    train_losses_q3.append(train_loss)
    train_accuracies_q3.append(train_accuracy)
    val_losses_q3.append(val_loss)
    val_accuracies_q3.append(val_accuracy)
    test_losses_q3.append(test_loss)
    test_accuracies_q3.append(test_accuracy)

end_time = time.time()
print(f'Total time taken to Train: {(end_time - start_time) / 60} mins')
# Out:
# Epoch 1
# -------------------------------
# Batch loss: 148.785860,  Batch Accuracy: 11.72  [ 1280/54000]
# Batch loss: 147.971559,  Batch Accuracy: 11.72  [ 2560/54000]
# Batch loss: 148.854513,  Batch Accuracy: 6.25  [ 3840/54000]
# Batch loss: 149.056869,  Batch Accuracy: 8.59  [ 5120/54000]
# Batch loss: 148.962250,  Batch Accuracy: 12.50  [ 6400/54000]
# Batch loss: 147.963199,  Batch Accuracy: 9.38  [ 7680/54000]
# Batch loss: 147.685888,  Batch Accuracy: 9.38  [ 8960/54000]
# Batch loss: 147.831626,  Batch Accuracy: 14.06  [10240/54000]
# Batch loss: 147.903942,  Batch Accuracy: 14.06  [11520/54000]
# Batch loss: 149.105106,  Batch Accuracy: 7.81  [12800/54000]
# Batch loss: 148.630409,  Batch Accuracy: 10.94  [14080/54000]
# Batch loss: 147.471713,  Batch Accuracy: 10.16  [15360/54000]
# Batch loss: 149.072320,  Batch Accuracy: 9.38  [16640/54000]
# Batch loss: 149.584361,  Batch Accuracy: 10.16  [17920/54000]
# Batch loss: 148.451697,  Batch Accuracy: 8.59  [19200/54000]
# Batch loss: 148.771618,  Batch Accuracy: 10.94  [20480/54000]
# Batch loss: 149.443472,  Batch Accuracy: 7.03  [21760/54000]
# Batch loss: 148.339919,  Batch Accuracy: 11.72  [23040/54000]
# Batch loss: 149.352363,  Batch Accuracy: 11.72  [24320/54000]
# Batch loss: 148.629102,  Batch Accuracy: 3.91  [25600/54000]
# Batch loss: 147.671376,  Batch Accuracy: 15.62  [26880/54000]
# Batch loss: 147.738453,  Batch Accuracy: 7.81  [28160/54000]
# Batch loss: 147.423264,  Batch Accuracy: 12.50  [29440/54000]
# Batch loss: 147.985776,  Batch Accuracy: 7.03  [30720/54000]
# Batch loss: 148.266849,  Batch Accuracy: 9.38  [32000/54000]
# Batch loss: 147.094831,  Batch Accuracy: 17.19  [33280/54000]
# Batch loss: 146.417803,  Batch Accuracy: 13.28  [34560/54000]
# Batch loss: 147.474004,  Batch Accuracy: 10.94  [35840/54000]
# Batch loss: 148.387469,  Batch Accuracy: 8.59  [37120/54000]
# Batch loss: 147.500882,  Batch Accuracy: 13.28  [38400/54000]
# Batch loss: 148.180015,  Batch Accuracy: 11.72  [39680/54000]
# Batch loss: 147.906846,  Batch Accuracy: 11.72  [40960/54000]
# Batch loss: 147.396537,  Batch Accuracy: 13.28  [42240/54000]
# Batch loss: 147.163758,  Batch Accuracy: 15.62  [43520/54000]
# Batch loss: 147.705253,  Batch Accuracy: 11.72  [44800/54000]
# Batch loss: 146.943434,  Batch Accuracy: 18.75  [46080/54000]
# Batch loss: 146.443796,  Batch Accuracy: 17.19  [47360/54000]
# Batch loss: 146.364071,  Batch Accuracy: 18.75  [48640/54000]
# Batch loss: 147.644405,  Batch Accuracy: 10.16  [49920/54000]
# Batch loss: 146.872070,  Batch Accuracy: 17.97  [51200/54000]
# Batch loss: 147.283430,  Batch Accuracy: 17.19  [52480/54000]
# Batch loss: 147.540501,  Batch Accuracy: 10.94  [53760/54000]
# Training performance:
#  Accuracy: 12.0%, Loss: 147.972753
# Validation performance:
#  Accuracy: 16.9%, Loss: 146.484107
# Test performance:
#  Accuracy: 17.0%, Loss: 145.241387
#
# Epoch 2
# -------------------------------
# Batch loss: 146.698254,  Batch Accuracy: 14.84  [ 1280/54000]
# Batch loss: 146.327773,  Batch Accuracy: 14.84  [ 2560/54000]
# Batch loss: 146.261864,  Batch Accuracy: 19.53  [ 3840/54000]
# Batch loss: 146.424158,  Batch Accuracy: 17.19  [ 5120/54000]
# Batch loss: 146.707985,  Batch Accuracy: 14.06  [ 6400/54000]
# Batch loss: 146.657457,  Batch Accuracy: 18.75  [ 7680/54000]
# Batch loss: 146.397777,  Batch Accuracy: 19.53  [ 8960/54000]
# Batch loss: 146.047991,  Batch Accuracy: 20.31  [10240/54000]
# Batch loss: 146.576364,  Batch Accuracy: 14.06  [11520/54000]
# Batch loss: 146.238044,  Batch Accuracy: 19.53  [12800/54000]
# Batch loss: 145.837919,  Batch Accuracy: 19.53  [14080/54000]
# Batch loss: 145.928292,  Batch Accuracy: 17.97  [15360/54000]
# Batch loss: 146.012171,  Batch Accuracy: 20.31  [16640/54000]
# Batch loss: 145.733213,  Batch Accuracy: 18.75  [17920/54000]
# Batch loss: 145.601766,  Batch Accuracy: 27.34  [19200/54000]
# Batch loss: 145.516442,  Batch Accuracy: 22.66  [20480/54000]
# Batch loss: 144.540028,  Batch Accuracy: 27.34  [21760/54000]
# Batch loss: 145.584652,  Batch Accuracy: 25.00  [23040/54000]
# Batch loss: 144.664632,  Batch Accuracy: 28.91  [24320/54000]
# Batch loss: 146.039468,  Batch Accuracy: 22.66  [25600/54000]
# Batch loss: 145.732533,  Batch Accuracy: 20.31  [26880/54000]
# Batch loss: 145.227231,  Batch Accuracy: 25.00  [28160/54000]
# Batch loss: 145.898439,  Batch Accuracy: 21.09  [29440/54000]
# Batch loss: 146.615195,  Batch Accuracy: 14.84  [30720/54000]
# Batch loss: 144.877105,  Batch Accuracy: 25.00  [32000/54000]
# Batch loss: 144.912713,  Batch Accuracy: 27.34  [33280/54000]
# Batch loss: 145.830823,  Batch Accuracy: 25.00  [34560/54000]
# Batch loss: 144.567379,  Batch Accuracy: 22.66  [35840/54000]
# Batch loss: 145.056713,  Batch Accuracy: 24.22  [37120/54000]
# Batch loss: 145.113751,  Batch Accuracy: 23.44  [38400/54000]
# Batch loss: 144.234173,  Batch Accuracy: 28.91  [39680/54000]
# Batch loss: 144.875704,  Batch Accuracy: 28.12  [40960/54000]
# Batch loss: 144.295828,  Batch Accuracy: 28.91  [42240/54000]
# Batch loss: 144.397613,  Batch Accuracy: 28.91  [43520/54000]
# Batch loss: 145.263582,  Batch Accuracy: 26.56  [44800/54000]
# Batch loss: 144.694903,  Batch Accuracy: 26.56  [46080/54000]
# Batch loss: 143.628356,  Batch Accuracy: 25.78  [47360/54000]
# Batch loss: 143.571989,  Batch Accuracy: 25.00  [48640/54000]
# Batch loss: 143.641941,  Batch Accuracy: 26.56  [49920/54000]
# Batch loss: 143.702765,  Batch Accuracy: 32.81  [51200/54000]
# Batch loss: 144.838097,  Batch Accuracy: 25.00  [52480/54000]
# Batch loss: 143.622114,  Batch Accuracy: 28.91  [53760/54000]
# Training performance:
#  Accuracy: 23.4%, Loss: 145.266440
# Validation performance:
#  Accuracy: 33.5%, Loss: 142.818896
# Test performance:
#  Accuracy: 34.8%, Loss: 141.534099
#
# Epoch 3
# -------------------------------
# Batch loss: 142.727223,  Batch Accuracy: 36.72  [ 1280/54000]
# Batch loss: 143.133105,  Batch Accuracy: 39.06  [ 2560/54000]
# Batch loss: 143.322753,  Batch Accuracy: 39.06  [ 3840/54000]
# Batch loss: 142.551872,  Batch Accuracy: 37.50  [ 5120/54000]
# Batch loss: 143.428179,  Batch Accuracy: 32.03  [ 6400/54000]
# Batch loss: 141.507461,  Batch Accuracy: 41.41  [ 7680/54000]
# Batch loss: 142.484074,  Batch Accuracy: 42.19  [ 8960/54000]
# Batch loss: 142.517139,  Batch Accuracy: 42.19  [10240/54000]
# Batch loss: 142.770727,  Batch Accuracy: 37.50  [11520/54000]
# Batch loss: 142.455597,  Batch Accuracy: 33.59  [12800/54000]
# Batch loss: 140.703023,  Batch Accuracy: 44.53  [14080/54000]
# Batch loss: 140.304337,  Batch Accuracy: 47.66  [15360/54000]
# Batch loss: 141.133314,  Batch Accuracy: 41.41  [16640/54000]
# Batch loss: 141.913486,  Batch Accuracy: 42.19  [17920/54000]
# Batch loss: 140.424835,  Batch Accuracy: 44.53  [19200/54000]
# Batch loss: 140.259515,  Batch Accuracy: 50.00  [20480/54000]
# Batch loss: 140.167743,  Batch Accuracy: 51.56  [21760/54000]
# Batch loss: 141.439490,  Batch Accuracy: 42.97  [23040/54000]
# Batch loss: 141.430636,  Batch Accuracy: 41.41  [24320/54000]
# Batch loss: 139.612744,  Batch Accuracy: 39.84  [25600/54000]
# Batch loss: 139.454594,  Batch Accuracy: 44.53  [26880/54000]
# Batch loss: 137.892006,  Batch Accuracy: 51.56  [28160/54000]
# Batch loss: 138.031945,  Batch Accuracy: 47.66  [29440/54000]
# Batch loss: 138.609013,  Batch Accuracy: 45.31  [30720/54000]
# Batch loss: 135.857362,  Batch Accuracy: 53.91  [32000/54000]
# Batch loss: 138.850743,  Batch Accuracy: 40.62  [33280/54000]
# Batch loss: 136.806155,  Batch Accuracy: 46.88  [34560/54000]
# Batch loss: 138.378362,  Batch Accuracy: 50.78  [35840/54000]
# Batch loss: 137.335466,  Batch Accuracy: 46.88  [37120/54000]
# Batch loss: 136.640356,  Batch Accuracy: 46.88  [38400/54000]
# Batch loss: 138.399072,  Batch Accuracy: 40.62  [39680/54000]
# Batch loss: 135.200922,  Batch Accuracy: 48.44  [40960/54000]
# Batch loss: 137.614030,  Batch Accuracy: 42.97  [42240/54000]
# Batch loss: 136.100057,  Batch Accuracy: 44.53  [43520/54000]
# Batch loss: 133.670113,  Batch Accuracy: 50.78  [44800/54000]
# Batch loss: 134.185503,  Batch Accuracy: 54.69  [46080/54000]
# Batch loss: 134.159224,  Batch Accuracy: 46.09  [47360/54000]
# Batch loss: 136.469384,  Batch Accuracy: 46.09  [48640/54000]
# Batch loss: 134.823694,  Batch Accuracy: 50.00  [49920/54000]
# Batch loss: 134.752099,  Batch Accuracy: 40.62  [51200/54000]
# Batch loss: 130.668678,  Batch Accuracy: 42.97  [52480/54000]
# Batch loss: 131.320002,  Batch Accuracy: 44.53  [53760/54000]
# Training performance:
#  Accuracy: 44.4%, Loss: 138.681702
# Validation performance:
#  Accuracy: 46.6%, Loss: 130.386378
# Test performance:
#  Accuracy: 48.0%, Loss: 128.964838
#
# Epoch 4
# -------------------------------
# Batch loss: 130.717248,  Batch Accuracy: 53.12  [ 1280/54000]
# Batch loss: 129.748855,  Batch Accuracy: 45.31  [ 2560/54000]
# Batch loss: 124.060305,  Batch Accuracy: 53.91  [ 3840/54000]
# Batch loss: 130.392250,  Batch Accuracy: 48.44  [ 5120/54000]
# Batch loss: 126.037594,  Batch Accuracy: 52.34  [ 6400/54000]
# Batch loss: 130.263502,  Batch Accuracy: 44.53  [ 7680/54000]
# Batch loss: 117.228217,  Batch Accuracy: 53.91  [ 8960/54000]
# Batch loss: 123.201605,  Batch Accuracy: 57.03  [10240/54000]
# Batch loss: 116.907265,  Batch Accuracy: 53.91  [11520/54000]
# Batch loss: 125.505337,  Batch Accuracy: 45.31  [12800/54000]
# Batch loss: 125.087520,  Batch Accuracy: 55.47  [14080/54000]
# Batch loss: 122.617987,  Batch Accuracy: 50.00  [15360/54000]
# Batch loss: 116.462109,  Batch Accuracy: 57.81  [16640/54000]
# Batch loss: 117.060673,  Batch Accuracy: 53.91  [17920/54000]
# Batch loss: 117.997560,  Batch Accuracy: 58.59  [19200/54000]
# Batch loss: 112.239530,  Batch Accuracy: 60.94  [20480/54000]
# Batch loss: 115.550139,  Batch Accuracy: 50.00  [21760/54000]
# Batch loss: 116.543236,  Batch Accuracy: 61.72  [23040/54000]
# Batch loss: 111.126571,  Batch Accuracy: 57.81  [24320/54000]
# Batch loss: 110.135777,  Batch Accuracy: 58.59  [25600/54000]
# Batch loss: 109.953514,  Batch Accuracy: 58.59  [26880/54000]
# Batch loss: 116.174678,  Batch Accuracy: 58.59  [28160/54000]
# Batch loss: 113.657801,  Batch Accuracy: 56.25  [29440/54000]
# Batch loss: 109.079219,  Batch Accuracy: 65.62  [30720/54000]
# Batch loss: 100.552348,  Batch Accuracy: 63.28  [32000/54000]
# Batch loss: 98.708922,  Batch Accuracy: 65.62  [33280/54000]
# Batch loss: 103.899554,  Batch Accuracy: 54.69  [34560/54000]
# Batch loss: 100.960162,  Batch Accuracy: 65.62  [35840/54000]
# Batch loss: 101.424240,  Batch Accuracy: 64.06  [37120/54000]
# Batch loss: 93.570508,  Batch Accuracy: 71.88  [38400/54000]
# Batch loss: 91.445719,  Batch Accuracy: 66.41  [39680/54000]
# Batch loss: 87.217844,  Batch Accuracy: 71.09  [40960/54000]
# Batch loss: 83.521878,  Batch Accuracy: 71.88  [42240/54000]
# Batch loss: 84.762162,  Batch Accuracy: 63.28  [43520/54000]
# Batch loss: 82.201370,  Batch Accuracy: 71.09  [44800/54000]
# Batch loss: 82.269105,  Batch Accuracy: 74.22  [46080/54000]
# Batch loss: 83.297001,  Batch Accuracy: 62.50  [47360/54000]
# Batch loss: 80.114802,  Batch Accuracy: 66.41  [48640/54000]
# Batch loss: 74.196504,  Batch Accuracy: 73.44  [49920/54000]
# Batch loss: 74.365420,  Batch Accuracy: 64.06  [51200/54000]
# Batch loss: 67.688794,  Batch Accuracy: 75.78  [52480/54000]
# Batch loss: 60.385709,  Batch Accuracy: 75.00  [53760/54000]
# Training performance:
#  Accuracy: 58.5%, Loss: 107.488817
# Validation performance:
#  Accuracy: 72.0%, Loss: 70.503973
# Test performance:
#  Accuracy: 72.6%, Loss: 68.432666
#
# Epoch 5
# -------------------------------
# Batch loss: 72.744747,  Batch Accuracy: 75.00  [ 1280/54000]
# Batch loss: 63.284033,  Batch Accuracy: 72.66  [ 2560/54000]
# Batch loss: 70.704186,  Batch Accuracy: 69.53  [ 3840/54000]
# Batch loss: 56.707397,  Batch Accuracy: 70.31  [ 5120/54000]
# Batch loss: 56.398568,  Batch Accuracy: 79.69  [ 6400/54000]
# Batch loss: 54.655328,  Batch Accuracy: 77.34  [ 7680/54000]
# Batch loss: 64.911363,  Batch Accuracy: 79.69  [ 8960/54000]
# Batch loss: 53.654023,  Batch Accuracy: 79.69  [10240/54000]
# Batch loss: 55.630726,  Batch Accuracy: 77.34  [11520/54000]
# Batch loss: 54.755046,  Batch Accuracy: 78.91  [12800/54000]
# Batch loss: 56.483788,  Batch Accuracy: 78.91  [14080/54000]
# Batch loss: 53.698660,  Batch Accuracy: 78.12  [15360/54000]
# Batch loss: 54.913057,  Batch Accuracy: 80.47  [16640/54000]
# Batch loss: 46.975302,  Batch Accuracy: 82.03  [17920/54000]
# Batch loss: 41.546236,  Batch Accuracy: 84.38  [19200/54000]
# Batch loss: 47.027966,  Batch Accuracy: 81.25  [20480/54000]
# Batch loss: 52.165039,  Batch Accuracy: 77.34  [21760/54000]
# Batch loss: 48.157414,  Batch Accuracy: 82.03  [23040/54000]
# Batch loss: 39.653810,  Batch Accuracy: 88.28  [24320/54000]
# Batch loss: 43.426459,  Batch Accuracy: 84.38  [25600/54000]
# Batch loss: 51.062689,  Batch Accuracy: 79.69  [26880/54000]
# Batch loss: 45.970328,  Batch Accuracy: 85.16  [28160/54000]
# Batch loss: 35.388844,  Batch Accuracy: 86.72  [29440/54000]
# Batch loss: 36.355894,  Batch Accuracy: 86.72  [30720/54000]
# Batch loss: 39.714903,  Batch Accuracy: 82.81  [32000/54000]
# Batch loss: 39.453860,  Batch Accuracy: 87.50  [33280/54000]
# Batch loss: 35.471308,  Batch Accuracy: 82.81  [34560/54000]
# Batch loss: 38.221053,  Batch Accuracy: 82.81  [35840/54000]
# Batch loss: 38.292367,  Batch Accuracy: 85.94  [37120/54000]
# Batch loss: 32.869392,  Batch Accuracy: 84.38  [38400/54000]
# Batch loss: 41.643164,  Batch Accuracy: 84.38  [39680/54000]
# Batch loss: 31.000131,  Batch Accuracy: 89.06  [40960/54000]
# Batch loss: 43.803398,  Batch Accuracy: 80.47  [42240/54000]
# Batch loss: 38.639094,  Batch Accuracy: 81.25  [43520/54000]
# Batch loss: 35.351586,  Batch Accuracy: 85.94  [44800/54000]
# Batch loss: 30.567397,  Batch Accuracy: 93.75  [46080/54000]
# Batch loss: 37.844734,  Batch Accuracy: 85.94  [47360/54000]
# Batch loss: 45.688490,  Batch Accuracy: 82.03  [48640/54000]
# Batch loss: 30.971331,  Batch Accuracy: 85.16  [49920/54000]
# Batch loss: 28.486725,  Batch Accuracy: 89.06  [51200/54000]
# Batch loss: 42.767608,  Batch Accuracy: 82.81  [52480/54000]
# Batch loss: 37.857617,  Batch Accuracy: 80.47  [53760/54000]
# Training performance:
#  Accuracy: 82.2%, Loss: 46.179138
# Validation performance:
#  Accuracy: 86.0%, Loss: 33.265137
# Test performance:
#  Accuracy: 86.3%, Loss: 32.289450
#
# Epoch 6
# -------------------------------
# Batch loss: 39.196703,  Batch Accuracy: 82.81  [ 1280/54000]
# Batch loss: 37.249461,  Batch Accuracy: 82.03  [ 2560/54000]
# Batch loss: 42.517710,  Batch Accuracy: 82.81  [ 3840/54000]
# Batch loss: 38.001105,  Batch Accuracy: 83.59  [ 5120/54000]
# Batch loss: 28.626550,  Batch Accuracy: 90.62  [ 6400/54000]
# Batch loss: 34.055436,  Batch Accuracy: 80.47  [ 7680/54000]
# Batch loss: 37.390702,  Batch Accuracy: 85.16  [ 8960/54000]
# Batch loss: 31.825800,  Batch Accuracy: 87.50  [10240/54000]
# Batch loss: 30.079369,  Batch Accuracy: 88.28  [11520/54000]
# Batch loss: 33.638471,  Batch Accuracy: 84.38  [12800/54000]
# Batch loss: 35.602935,  Batch Accuracy: 83.59  [14080/54000]
# Batch loss: 33.695677,  Batch Accuracy: 86.72  [15360/54000]
# Batch loss: 39.167702,  Batch Accuracy: 82.03  [16640/54000]
# Batch loss: 26.667602,  Batch Accuracy: 87.50  [17920/54000]
# Batch loss: 33.451647,  Batch Accuracy: 83.59  [19200/54000]
# Batch loss: 40.193993,  Batch Accuracy: 84.38  [20480/54000]
# Batch loss: 41.346126,  Batch Accuracy: 82.81  [21760/54000]
# Batch loss: 28.923175,  Batch Accuracy: 89.84  [23040/54000]
# Batch loss: 31.652685,  Batch Accuracy: 84.38  [24320/54000]
# Batch loss: 26.518481,  Batch Accuracy: 88.28  [25600/54000]
# Batch loss: 28.355866,  Batch Accuracy: 87.50  [26880/54000]
# Batch loss: 33.003113,  Batch Accuracy: 88.28  [28160/54000]
# Batch loss: 28.968762,  Batch Accuracy: 87.50  [29440/54000]
# Batch loss: 20.801426,  Batch Accuracy: 92.97  [30720/54000]
# Batch loss: 18.881785,  Batch Accuracy: 89.84  [32000/54000]
# Batch loss: 28.049003,  Batch Accuracy: 89.06  [33280/54000]
# Batch loss: 26.462153,  Batch Accuracy: 89.06  [34560/54000]
# Batch loss: 33.040751,  Batch Accuracy: 83.59  [35840/54000]
# Batch loss: 20.786364,  Batch Accuracy: 90.62  [37120/54000]
# Batch loss: 25.736766,  Batch Accuracy: 89.84  [38400/54000]
# Batch loss: 31.320665,  Batch Accuracy: 89.06  [39680/54000]
# Batch loss: 25.279279,  Batch Accuracy: 91.41  [40960/54000]
# Batch loss: 29.518134,  Batch Accuracy: 87.50  [42240/54000]
# Batch loss: 32.843811,  Batch Accuracy: 86.72  [43520/54000]
# Batch loss: 24.424047,  Batch Accuracy: 85.16  [44800/54000]
# Batch loss: 27.742694,  Batch Accuracy: 86.72  [46080/54000]
# Batch loss: 24.834563,  Batch Accuracy: 87.50  [47360/54000]
# Batch loss: 29.634290,  Batch Accuracy: 89.06  [48640/54000]
# Batch loss: 43.377039,  Batch Accuracy: 85.94  [49920/54000]
# Batch loss: 28.908595,  Batch Accuracy: 85.16  [51200/54000]
# Batch loss: 32.146652,  Batch Accuracy: 88.28  [52480/54000]
# Batch loss: 39.018943,  Batch Accuracy: 89.84  [53760/54000]
# Training performance:
#  Accuracy: 87.5%, Loss: 30.581578
# Validation performance:
#  Accuracy: 89.0%, Loss: 26.675355
# Test performance:
#  Accuracy: 88.6%, Loss: 26.220337
#
# Epoch 7
# -------------------------------
# Batch loss: 18.192093,  Batch Accuracy: 92.97  [ 1280/54000]
# Batch loss: 16.365412,  Batch Accuracy: 93.75  [ 2560/54000]
# Batch loss: 30.838291,  Batch Accuracy: 88.28  [ 3840/54000]
# Batch loss: 22.745161,  Batch Accuracy: 89.06  [ 5120/54000]
# Batch loss: 34.166237,  Batch Accuracy: 88.28  [ 6400/54000]
# Batch loss: 26.424701,  Batch Accuracy: 89.84  [ 7680/54000]
# Batch loss: 21.525616,  Batch Accuracy: 90.62  [ 8960/54000]
# Batch loss: 27.908796,  Batch Accuracy: 83.59  [10240/54000]
# Batch loss: 29.125112,  Batch Accuracy: 87.50  [11520/54000]
# Batch loss: 33.126137,  Batch Accuracy: 87.50  [12800/54000]
# Batch loss: 29.785815,  Batch Accuracy: 85.16  [14080/54000]
# Batch loss: 23.468958,  Batch Accuracy: 82.03  [15360/54000]
# Batch loss: 29.787347,  Batch Accuracy: 86.72  [16640/54000]
# Batch loss: 19.157797,  Batch Accuracy: 92.19  [17920/54000]
# Batch loss: 38.344522,  Batch Accuracy: 85.94  [19200/54000]
# Batch loss: 30.387223,  Batch Accuracy: 85.94  [20480/54000]
# Batch loss: 44.532508,  Batch Accuracy: 85.94  [21760/54000]
# Batch loss: 24.372180,  Batch Accuracy: 91.41  [23040/54000]
# Batch loss: 18.950622,  Batch Accuracy: 92.19  [24320/54000]
# Batch loss: 37.643645,  Batch Accuracy: 82.81  [25600/54000]
# Batch loss: 23.380410,  Batch Accuracy: 87.50  [26880/54000]
# Batch loss: 24.992182,  Batch Accuracy: 85.94  [28160/54000]
# Batch loss: 27.227941,  Batch Accuracy: 91.41  [29440/54000]
# Batch loss: 23.008125,  Batch Accuracy: 89.06  [30720/54000]
# Batch loss: 20.940762,  Batch Accuracy: 89.06  [32000/54000]
# Batch loss: 17.546029,  Batch Accuracy: 93.75  [33280/54000]
# Batch loss: 18.940683,  Batch Accuracy: 89.84  [34560/54000]
# Batch loss: 20.821110,  Batch Accuracy: 91.41  [35840/54000]
# Batch loss: 23.438581,  Batch Accuracy: 89.84  [37120/54000]
# Batch loss: 39.238503,  Batch Accuracy: 87.50  [38400/54000]
# Batch loss: 30.576998,  Batch Accuracy: 89.06  [39680/54000]
# Batch loss: 36.284571,  Batch Accuracy: 82.81  [40960/54000]
# Batch loss: 19.685089,  Batch Accuracy: 92.97  [42240/54000]
# Batch loss: 27.425887,  Batch Accuracy: 85.94  [43520/54000]
# Batch loss: 38.865336,  Batch Accuracy: 82.03  [44800/54000]
# Batch loss: 17.939367,  Batch Accuracy: 93.75  [46080/54000]
# Batch loss: 23.164903,  Batch Accuracy: 87.50  [47360/54000]
# Batch loss: 21.683261,  Batch Accuracy: 87.50  [48640/54000]
# Batch loss: 22.551982,  Batch Accuracy: 89.84  [49920/54000]
# Batch loss: 20.216074,  Batch Accuracy: 92.97  [51200/54000]
# Batch loss: 20.663999,  Batch Accuracy: 87.50  [52480/54000]
# Batch loss: 25.397503,  Batch Accuracy: 92.19  [53760/54000]
# Training performance:
#  Accuracy: 89.2%, Loss: 25.991077
# Validation performance:
#  Accuracy: 89.9%, Loss: 23.756565
# Test performance:
#  Accuracy: 89.8%, Loss: 23.397635
#
# Epoch 8
# -------------------------------
# Batch loss: 17.430835,  Batch Accuracy: 92.97  [ 1280/54000]
# Batch loss: 38.418031,  Batch Accuracy: 86.72  [ 2560/54000]
# Batch loss: 17.815114,  Batch Accuracy: 91.41  [ 3840/54000]
# Batch loss: 17.980944,  Batch Accuracy: 92.97  [ 5120/54000]
# Batch loss: 19.406980,  Batch Accuracy: 87.50  [ 6400/54000]
# Batch loss: 34.846620,  Batch Accuracy: 89.84  [ 7680/54000]
# Batch loss: 21.750753,  Batch Accuracy: 87.50  [ 8960/54000]
# Batch loss: 26.156319,  Batch Accuracy: 88.28  [10240/54000]
# Batch loss: 19.837812,  Batch Accuracy: 92.19  [11520/54000]
# Batch loss: 27.143005,  Batch Accuracy: 89.84  [12800/54000]
# Batch loss: 23.119856,  Batch Accuracy: 89.06  [14080/54000]
# Batch loss: 29.521926,  Batch Accuracy: 89.06  [15360/54000]
# Batch loss: 25.895517,  Batch Accuracy: 88.28  [16640/54000]
# Batch loss: 24.314488,  Batch Accuracy: 87.50  [17920/54000]
# Batch loss: 14.960003,  Batch Accuracy: 93.75  [19200/54000]
# Batch loss: 33.140444,  Batch Accuracy: 89.84  [20480/54000]
# Batch loss: 24.931111,  Batch Accuracy: 87.50  [21760/54000]
# Batch loss: 22.232154,  Batch Accuracy: 89.84  [23040/54000]
# Batch loss: 26.077110,  Batch Accuracy: 87.50  [24320/54000]
# Batch loss: 19.944364,  Batch Accuracy: 90.62  [25600/54000]
# Batch loss: 28.348789,  Batch Accuracy: 91.41  [26880/54000]
# Batch loss: 19.071723,  Batch Accuracy: 93.75  [28160/54000]
# Batch loss: 22.945421,  Batch Accuracy: 90.62  [29440/54000]
# Batch loss: 19.600271,  Batch Accuracy: 88.28  [30720/54000]
# Batch loss: 28.496744,  Batch Accuracy: 90.62  [32000/54000]
# Batch loss: 16.302267,  Batch Accuracy: 93.75  [33280/54000]
# Batch loss: 16.915494,  Batch Accuracy: 94.53  [34560/54000]
# Batch loss: 24.794823,  Batch Accuracy: 92.19  [35840/54000]
# Batch loss: 13.925708,  Batch Accuracy: 96.09  [37120/54000]
# Batch loss: 12.350381,  Batch Accuracy: 92.97  [38400/54000]
# Batch loss: 25.161221,  Batch Accuracy: 92.19  [39680/54000]
# Batch loss: 27.837608,  Batch Accuracy: 89.06  [40960/54000]
# Batch loss: 17.232846,  Batch Accuracy: 92.97  [42240/54000]
# Batch loss: 19.174343,  Batch Accuracy: 92.97  [43520/54000]
# Batch loss: 26.369885,  Batch Accuracy: 89.84  [44800/54000]
# Batch loss: 22.685477,  Batch Accuracy: 90.62  [46080/54000]
# Batch loss: 26.925531,  Batch Accuracy: 90.62  [47360/54000]
# Batch loss: 31.966507,  Batch Accuracy: 88.28  [48640/54000]
# Batch loss: 25.064164,  Batch Accuracy: 89.06  [49920/54000]
# Batch loss: 28.744876,  Batch Accuracy: 89.06  [51200/54000]
# Batch loss: 36.050833,  Batch Accuracy: 89.06  [52480/54000]
# Batch loss: 34.492840,  Batch Accuracy: 87.50  [53760/54000]
# Training performance:
#  Accuracy: 90.2%, Loss: 23.546319
# Validation performance:
#  Accuracy: 91.0%, Loss: 21.379414
# Test performance:
#  Accuracy: 91.1%, Loss: 20.925810
#
# Epoch 9
# -------------------------------
# Batch loss: 22.819756,  Batch Accuracy: 90.62  [ 1280/54000]
# Batch loss: 16.627513,  Batch Accuracy: 90.62  [ 2560/54000]
# Batch loss: 29.139581,  Batch Accuracy: 88.28  [ 3840/54000]
# Batch loss: 21.282031,  Batch Accuracy: 89.84  [ 5120/54000]
# Batch loss: 19.617742,  Batch Accuracy: 90.62  [ 6400/54000]
# Batch loss: 31.626864,  Batch Accuracy: 87.50  [ 7680/54000]
# Batch loss: 25.066277,  Batch Accuracy: 93.75  [ 8960/54000]
# Batch loss: 22.950426,  Batch Accuracy: 91.41  [10240/54000]
# Batch loss: 15.763452,  Batch Accuracy: 92.19  [11520/54000]
# Batch loss: 22.479708,  Batch Accuracy: 89.06  [12800/54000]
# Batch loss: 27.130676,  Batch Accuracy: 92.19  [14080/54000]
# Batch loss: 25.262364,  Batch Accuracy: 86.72  [15360/54000]
# Batch loss: 18.353761,  Batch Accuracy: 92.97  [16640/54000]
# Batch loss: 11.822225,  Batch Accuracy: 92.97  [17920/54000]
# Batch loss: 19.527952,  Batch Accuracy: 91.41  [19200/54000]
# Batch loss: 18.361106,  Batch Accuracy: 92.19  [20480/54000]
# Batch loss: 26.256460,  Batch Accuracy: 91.41  [21760/54000]
# Batch loss: 12.300535,  Batch Accuracy: 95.31  [23040/54000]
# Batch loss: 30.843866,  Batch Accuracy: 87.50  [24320/54000]
# Batch loss: 30.415019,  Batch Accuracy: 89.84  [25600/54000]
# Batch loss: 24.056557,  Batch Accuracy: 89.06  [26880/54000]
# Batch loss: 28.873349,  Batch Accuracy: 89.84  [28160/54000]
# Batch loss: 19.955618,  Batch Accuracy: 93.75  [29440/54000]
# Batch loss: 29.757007,  Batch Accuracy: 87.50  [30720/54000]
# Batch loss: 16.305420,  Batch Accuracy: 89.84  [32000/54000]
# Batch loss: 22.404724,  Batch Accuracy: 92.97  [33280/54000]
# Batch loss: 19.798120,  Batch Accuracy: 90.62  [34560/54000]
# Batch loss: 27.123915,  Batch Accuracy: 92.19  [35840/54000]
# Batch loss: 33.775586,  Batch Accuracy: 89.84  [37120/54000]
# Batch loss: 15.630315,  Batch Accuracy: 92.97  [38400/54000]
# Batch loss: 20.211350,  Batch Accuracy: 90.62  [39680/54000]
# Batch loss: 28.853305,  Batch Accuracy: 92.19  [40960/54000]
# Batch loss: 29.777251,  Batch Accuracy: 88.28  [42240/54000]
# Batch loss: 28.332000,  Batch Accuracy: 89.06  [43520/54000]
# Batch loss: 17.060900,  Batch Accuracy: 89.84  [44800/54000]
# Batch loss: 17.424591,  Batch Accuracy: 92.19  [46080/54000]
# Batch loss: 18.124137,  Batch Accuracy: 89.06  [47360/54000]
# Batch loss: 19.616624,  Batch Accuracy: 93.75  [48640/54000]
# Batch loss: 14.910200,  Batch Accuracy: 95.31  [49920/54000]
# Batch loss: 19.156803,  Batch Accuracy: 90.62  [51200/54000]
# Batch loss: 17.754769,  Batch Accuracy: 93.75  [52480/54000]
# Batch loss: 21.590591,  Batch Accuracy: 91.41  [53760/54000]
# Training performance:
#  Accuracy: 91.1%, Loss: 21.805128
# Validation performance:
#  Accuracy: 91.7%, Loss: 19.768314
# Test performance:
#  Accuracy: 91.8%, Loss: 19.614942
#
# Epoch 10
# -------------------------------
# Batch loss: 19.892447,  Batch Accuracy: 89.06  [ 1280/54000]
# Batch loss: 19.700597,  Batch Accuracy: 91.41  [ 2560/54000]
# Batch loss: 20.693559,  Batch Accuracy: 91.41  [ 3840/54000]
# Batch loss: 26.926444,  Batch Accuracy: 89.84  [ 5120/54000]
# Batch loss: 23.244598,  Batch Accuracy: 92.19  [ 6400/54000]
# Batch loss: 23.992782,  Batch Accuracy: 90.62  [ 7680/54000]
# Batch loss: 17.333348,  Batch Accuracy: 89.84  [ 8960/54000]
# Batch loss: 18.021213,  Batch Accuracy: 91.41  [10240/54000]
# Batch loss: 20.705277,  Batch Accuracy: 89.84  [11520/54000]
# Batch loss: 18.854498,  Batch Accuracy: 91.41  [12800/54000]
# Batch loss: 10.407430,  Batch Accuracy: 95.31  [14080/54000]
# Batch loss: 15.746661,  Batch Accuracy: 93.75  [15360/54000]
# Batch loss: 23.103364,  Batch Accuracy: 89.06  [16640/54000]
# Batch loss: 11.500500,  Batch Accuracy: 93.75  [17920/54000]
# Batch loss: 28.934689,  Batch Accuracy: 91.41  [19200/54000]
# Batch loss: 20.017088,  Batch Accuracy: 92.97  [20480/54000]
# Batch loss: 15.870817,  Batch Accuracy: 93.75  [21760/54000]
# Batch loss: 16.336311,  Batch Accuracy: 93.75  [23040/54000]
# Batch loss: 13.063272,  Batch Accuracy: 96.09  [24320/54000]
# Batch loss: 25.339616,  Batch Accuracy: 89.84  [25600/54000]
# Batch loss: 15.977618,  Batch Accuracy: 92.97  [26880/54000]
# Batch loss: 10.347494,  Batch Accuracy: 93.75  [28160/54000]
# Batch loss: 26.055797,  Batch Accuracy: 90.62  [29440/54000]
# Batch loss: 29.919697,  Batch Accuracy: 90.62  [30720/54000]
# Batch loss: 23.807416,  Batch Accuracy: 89.06  [32000/54000]
# Batch loss: 19.343638,  Batch Accuracy: 91.41  [33280/54000]
# Batch loss: 28.491020,  Batch Accuracy: 90.62  [34560/54000]
# Batch loss: 13.048253,  Batch Accuracy: 97.66  [35840/54000]
# Batch loss: 21.112076,  Batch Accuracy: 92.19  [37120/54000]
# Batch loss: 17.803705,  Batch Accuracy: 93.75  [38400/54000]
# Batch loss: 28.271582,  Batch Accuracy: 90.62  [39680/54000]
# Batch loss: 17.974238,  Batch Accuracy: 89.84  [40960/54000]
# Batch loss: 28.655025,  Batch Accuracy: 89.06  [42240/54000]
# Batch loss: 20.014179,  Batch Accuracy: 92.19  [43520/54000]
# Batch loss: 13.833920,  Batch Accuracy: 92.97  [44800/54000]
# Batch loss: 34.885078,  Batch Accuracy: 92.19  [46080/54000]
# Batch loss: 16.994951,  Batch Accuracy: 93.75  [47360/54000]
# Batch loss: 31.015676,  Batch Accuracy: 89.06  [48640/54000]
# Batch loss: 26.636617,  Batch Accuracy: 90.62  [49920/54000]
# Batch loss: 31.329315,  Batch Accuracy: 87.50  [51200/54000]
# Batch loss: 28.686758,  Batch Accuracy: 86.72  [52480/54000]
# Batch loss: 16.469007,  Batch Accuracy: 92.97  [53760/54000]
# Training performance:
#  Accuracy: 91.8%, Loss: 20.713326
# Validation performance:
#  Accuracy: 91.9%, Loss: 19.011435
# Test performance:
#  Accuracy: 92.0%, Loss: 18.267785
#
# Epoch 11
# -------------------------------
# Batch loss: 17.746268,  Batch Accuracy: 89.06  [ 1280/54000]
# Batch loss: 22.968004,  Batch Accuracy: 90.62  [ 2560/54000]
# Batch loss: 33.547280,  Batch Accuracy: 90.62  [ 3840/54000]
# Batch loss: 19.842928,  Batch Accuracy: 91.41  [ 5120/54000]
# Batch loss: 22.175805,  Batch Accuracy: 89.84  [ 6400/54000]
# Batch loss: 11.800860,  Batch Accuracy: 92.97  [ 7680/54000]
# Batch loss: 24.020831,  Batch Accuracy: 89.06  [ 8960/54000]
# Batch loss: 11.902025,  Batch Accuracy: 94.53  [10240/54000]
# Batch loss: 18.253839,  Batch Accuracy: 93.75  [11520/54000]
# Batch loss: 22.962483,  Batch Accuracy: 89.06  [12800/54000]
# Batch loss: 26.311786,  Batch Accuracy: 89.06  [14080/54000]
# Batch loss: 19.134490,  Batch Accuracy: 92.19  [15360/54000]
# Batch loss: 26.468028,  Batch Accuracy: 90.62  [16640/54000]
# Batch loss: 35.227676,  Batch Accuracy: 88.28  [17920/54000]
# Batch loss: 16.572565,  Batch Accuracy: 94.53  [19200/54000]
# Batch loss: 21.319677,  Batch Accuracy: 96.88  [20480/54000]
# Batch loss: 24.979775,  Batch Accuracy: 90.62  [21760/54000]
# Batch loss: 21.327295,  Batch Accuracy: 91.41  [23040/54000]
# Batch loss: 15.259826,  Batch Accuracy: 92.97  [24320/54000]
# Batch loss: 18.217331,  Batch Accuracy: 93.75  [25600/54000]
# Batch loss: 20.173726,  Batch Accuracy: 91.41  [26880/54000]
# Batch loss: 19.253334,  Batch Accuracy: 89.84  [28160/54000]
# Batch loss: 20.533397,  Batch Accuracy: 89.06  [29440/54000]
# Batch loss: 20.381488,  Batch Accuracy: 92.19  [30720/54000]
# Batch loss: 21.883604,  Batch Accuracy: 92.19  [32000/54000]
# Batch loss: 29.940345,  Batch Accuracy: 86.72  [33280/54000]
# Batch loss: 14.243107,  Batch Accuracy: 93.75  [34560/54000]
# Batch loss: 16.505012,  Batch Accuracy: 92.19  [35840/54000]
# Batch loss: 19.498378,  Batch Accuracy: 90.62  [37120/54000]
# Batch loss: 27.260991,  Batch Accuracy: 91.41  [38400/54000]
# Batch loss: 30.099947,  Batch Accuracy: 92.19  [39680/54000]
# Batch loss: 13.714656,  Batch Accuracy: 93.75  [40960/54000]
# Batch loss: 30.769025,  Batch Accuracy: 90.62  [42240/54000]
# Batch loss: 18.445766,  Batch Accuracy: 93.75  [43520/54000]
# Batch loss: 13.350907,  Batch Accuracy: 96.88  [44800/54000]
# Batch loss: 11.820991,  Batch Accuracy: 94.53  [46080/54000]
# Batch loss: 25.340353,  Batch Accuracy: 90.62  [47360/54000]
# Batch loss: 19.832783,  Batch Accuracy: 93.75  [48640/54000]
# Batch loss: 15.710095,  Batch Accuracy: 92.97  [49920/54000]
# Batch loss: 12.611717,  Batch Accuracy: 96.09  [51200/54000]
# Batch loss: 19.569142,  Batch Accuracy: 89.06  [52480/54000]
# Batch loss: 24.706834,  Batch Accuracy: 90.62  [53760/54000]
# Training performance:
#  Accuracy: 92.2%, Loss: 19.124478
# Validation performance:
#  Accuracy: 92.5%, Loss: 17.161333
# Test performance:
#  Accuracy: 92.7%, Loss: 17.253324
#
# Epoch 12
# -------------------------------
# Batch loss: 18.550811,  Batch Accuracy: 94.53  [ 1280/54000]
# Batch loss: 17.604615,  Batch Accuracy: 94.53  [ 2560/54000]
# Batch loss: 12.475910,  Batch Accuracy: 93.75  [ 3840/54000]
# Batch loss: 14.369692,  Batch Accuracy: 93.75  [ 5120/54000]
# Batch loss: 15.119955,  Batch Accuracy: 92.97  [ 6400/54000]
# Batch loss: 19.244700,  Batch Accuracy: 91.41  [ 7680/54000]
# Batch loss: 16.079990,  Batch Accuracy: 95.31  [ 8960/54000]
# Batch loss: 13.138811,  Batch Accuracy: 93.75  [10240/54000]
# Batch loss: 21.485415,  Batch Accuracy: 89.84  [11520/54000]
# Batch loss: 28.395056,  Batch Accuracy: 85.94  [12800/54000]
# Batch loss: 35.010708,  Batch Accuracy: 85.94  [14080/54000]
# Batch loss: 19.483785,  Batch Accuracy: 91.41  [15360/54000]
# Batch loss: 15.848755,  Batch Accuracy: 94.53  [16640/54000]
# Batch loss: 15.482468,  Batch Accuracy: 95.31  [17920/54000]
# Batch loss: 26.372456,  Batch Accuracy: 88.28  [19200/54000]
# Batch loss: 22.227017,  Batch Accuracy: 92.97  [20480/54000]
# Batch loss: 12.173946,  Batch Accuracy: 92.97  [21760/54000]
# Batch loss: 13.129579,  Batch Accuracy: 92.97  [23040/54000]
# Batch loss: 22.904015,  Batch Accuracy: 92.19  [24320/54000]
# Batch loss: 12.233374,  Batch Accuracy: 92.97  [25600/54000]
# Batch loss: 17.926195,  Batch Accuracy: 94.53  [26880/54000]
# Batch loss: 14.072509,  Batch Accuracy: 93.75  [28160/54000]
# Batch loss: 16.332195,  Batch Accuracy: 93.75  [29440/54000]
# Batch loss: 27.823777,  Batch Accuracy: 91.41  [30720/54000]
# Batch loss: 12.693710,  Batch Accuracy: 92.97  [32000/54000]
# Batch loss: 20.520137,  Batch Accuracy: 91.41  [33280/54000]
# Batch loss: 13.723879,  Batch Accuracy: 92.97  [34560/54000]
# Batch loss: 13.684377,  Batch Accuracy: 95.31  [35840/54000]
# Batch loss: 15.247725,  Batch Accuracy: 95.31  [37120/54000]
# Batch loss: 25.905453,  Batch Accuracy: 92.97  [38400/54000]
# Batch loss: 11.691773,  Batch Accuracy: 91.41  [39680/54000]
# Batch loss: 19.851404,  Batch Accuracy: 91.41  [40960/54000]
# Batch loss: 16.625607,  Batch Accuracy: 93.75  [42240/54000]
# Batch loss: 19.090243,  Batch Accuracy: 92.97  [43520/54000]
# Batch loss: 14.679106,  Batch Accuracy: 95.31  [44800/54000]
# Batch loss: 15.470224,  Batch Accuracy: 92.19  [46080/54000]
# Batch loss: 19.855576,  Batch Accuracy: 89.84  [47360/54000]
# Batch loss: 13.420623,  Batch Accuracy: 93.75  [48640/54000]
# Batch loss: 15.323893,  Batch Accuracy: 94.53  [49920/54000]
# Batch loss: 26.276266,  Batch Accuracy: 92.97  [51200/54000]
# Batch loss: 12.509970,  Batch Accuracy: 94.53  [52480/54000]
# Batch loss: 12.461755,  Batch Accuracy: 96.09  [53760/54000]
# Training performance:
#  Accuracy: 92.7%, Loss: 18.188623
# Validation performance:
#  Accuracy: 92.8%, Loss: 16.902599
# Test performance:
#  Accuracy: 93.1%, Loss: 16.842612
#
# Epoch 13
# -------------------------------
# Batch loss: 21.819411,  Batch Accuracy: 88.28  [ 1280/54000]
# Batch loss: 12.952733,  Batch Accuracy: 96.09  [ 2560/54000]
# Batch loss: 15.199095,  Batch Accuracy: 94.53  [ 3840/54000]
# Batch loss: 15.482777,  Batch Accuracy: 96.09  [ 5120/54000]
# Batch loss: 42.456762,  Batch Accuracy: 89.84  [ 6400/54000]
# Batch loss: 15.444193,  Batch Accuracy: 90.62  [ 7680/54000]
# Batch loss: 16.202362,  Batch Accuracy: 93.75  [ 8960/54000]
# Batch loss: 19.009609,  Batch Accuracy: 94.53  [10240/54000]
# Batch loss: 12.164456,  Batch Accuracy: 95.31  [11520/54000]
# Batch loss: 11.434606,  Batch Accuracy: 94.53  [12800/54000]
# Batch loss: 35.042294,  Batch Accuracy: 89.06  [14080/54000]
# Batch loss: 12.056380,  Batch Accuracy: 96.88  [15360/54000]
# Batch loss: 17.992684,  Batch Accuracy: 92.97  [16640/54000]
# Batch loss: 12.022292,  Batch Accuracy: 94.53  [17920/54000]
# Batch loss: 14.968744,  Batch Accuracy: 93.75  [19200/54000]
# Batch loss: 18.367236,  Batch Accuracy: 89.84  [20480/54000]
# Batch loss: 24.848421,  Batch Accuracy: 95.31  [21760/54000]
# Batch loss: 14.658023,  Batch Accuracy: 92.19  [23040/54000]
# Batch loss: 20.734388,  Batch Accuracy: 91.41  [24320/54000]
# Batch loss: 19.579991,  Batch Accuracy: 96.09  [25600/54000]
# Batch loss: 18.736108,  Batch Accuracy: 93.75  [26880/54000]
# Batch loss: 21.508090,  Batch Accuracy: 92.97  [28160/54000]
# Batch loss: 21.467780,  Batch Accuracy: 92.97  [29440/54000]
# Batch loss: 17.953890,  Batch Accuracy: 94.53  [30720/54000]
# Batch loss: 12.374556,  Batch Accuracy: 95.31  [32000/54000]
# Batch loss: 25.661220,  Batch Accuracy: 91.41  [33280/54000]
# Batch loss: 16.127292,  Batch Accuracy: 94.53  [34560/54000]
# Batch loss: 18.392593,  Batch Accuracy: 90.62  [35840/54000]
# Batch loss: 26.595982,  Batch Accuracy: 92.19  [37120/54000]
# Batch loss: 25.097540,  Batch Accuracy: 90.62  [38400/54000]
# Batch loss: 17.843260,  Batch Accuracy: 91.41  [39680/54000]
# Batch loss: 16.943783,  Batch Accuracy: 92.19  [40960/54000]
# Batch loss: 11.960643,  Batch Accuracy: 94.53  [42240/54000]
# Batch loss: 29.860390,  Batch Accuracy: 91.41  [43520/54000]
# Batch loss: 15.012039,  Batch Accuracy: 91.41  [44800/54000]
# Batch loss: 16.984192,  Batch Accuracy: 93.75  [46080/54000]
# Batch loss: 16.521970,  Batch Accuracy: 93.75  [47360/54000]
# Batch loss: 24.042775,  Batch Accuracy: 91.41  [48640/54000]
# Batch loss: 12.402776,  Batch Accuracy: 94.53  [49920/54000]
# Batch loss: 15.407512,  Batch Accuracy: 92.19  [51200/54000]
# Batch loss: 10.127122,  Batch Accuracy: 95.31  [52480/54000]
# Batch loss: 12.214635,  Batch Accuracy: 95.31  [53760/54000]
# Training performance:
#  Accuracy: 93.1%, Loss: 17.489482
# Validation performance:
#  Accuracy: 93.1%, Loss: 15.707546
# Test performance:
#  Accuracy: 93.2%, Loss: 16.044001
#
# Epoch 14
# -------------------------------
# Batch loss: 19.003325,  Batch Accuracy: 92.19  [ 1280/54000]
# Batch loss: 17.348743,  Batch Accuracy: 92.97  [ 2560/54000]
# Batch loss: 13.184568,  Batch Accuracy: 93.75  [ 3840/54000]
# Batch loss: 28.510881,  Batch Accuracy: 95.31  [ 5120/54000]
# Batch loss: 8.789480,  Batch Accuracy: 96.09  [ 6400/54000]
# Batch loss: 19.640059,  Batch Accuracy: 92.97  [ 7680/54000]
# Batch loss: 14.408227,  Batch Accuracy: 94.53  [ 8960/54000]
# Batch loss: 19.166856,  Batch Accuracy: 92.19  [10240/54000]
# Batch loss: 36.076848,  Batch Accuracy: 83.59  [11520/54000]
# Batch loss: 15.462930,  Batch Accuracy: 93.75  [12800/54000]
# Batch loss: 16.844561,  Batch Accuracy: 92.19  [14080/54000]
# Batch loss: 19.752302,  Batch Accuracy: 94.53  [15360/54000]
# Batch loss: 12.202356,  Batch Accuracy: 93.75  [16640/54000]
# Batch loss: 15.496237,  Batch Accuracy: 91.41  [17920/54000]
# Batch loss: 9.571470,  Batch Accuracy: 96.09  [19200/54000]
# Batch loss: 19.857985,  Batch Accuracy: 96.09  [20480/54000]
# Batch loss: 12.621405,  Batch Accuracy: 93.75  [21760/54000]
# Batch loss: 16.239714,  Batch Accuracy: 93.75  [23040/54000]
# Batch loss: 16.812860,  Batch Accuracy: 92.97  [24320/54000]
# Batch loss: 26.566567,  Batch Accuracy: 89.06  [25600/54000]
# Batch loss: 11.584093,  Batch Accuracy: 94.53  [26880/54000]
# Batch loss: 10.020349,  Batch Accuracy: 97.66  [28160/54000]
# Batch loss: 15.615658,  Batch Accuracy: 93.75  [29440/54000]
# Batch loss: 13.742786,  Batch Accuracy: 95.31  [30720/54000]
# Batch loss: 9.991678,  Batch Accuracy: 94.53  [32000/54000]
# Batch loss: 12.268664,  Batch Accuracy: 92.19  [33280/54000]
# Batch loss: 14.603447,  Batch Accuracy: 95.31  [34560/54000]
# Batch loss: 25.668166,  Batch Accuracy: 88.28  [35840/54000]
# Batch loss: 24.427395,  Batch Accuracy: 89.84  [37120/54000]
# Batch loss: 9.869000,  Batch Accuracy: 94.53  [38400/54000]
# Batch loss: 26.851934,  Batch Accuracy: 92.19  [39680/54000]
# Batch loss: 12.214516,  Batch Accuracy: 92.97  [40960/54000]
# Batch loss: 15.457426,  Batch Accuracy: 94.53  [42240/54000]
# Batch loss: 12.919158,  Batch Accuracy: 95.31  [43520/54000]
# Batch loss: 23.732817,  Batch Accuracy: 89.06  [44800/54000]
# Batch loss: 12.789962,  Batch Accuracy: 95.31  [46080/54000]
# Batch loss: 32.002401,  Batch Accuracy: 88.28  [47360/54000]
# Batch loss: 12.871537,  Batch Accuracy: 92.97  [48640/54000]
# Batch loss: 8.374938,  Batch Accuracy: 95.31  [49920/54000]
# Batch loss: 9.603061,  Batch Accuracy: 94.53  [51200/54000]
# Batch loss: 15.828187,  Batch Accuracy: 96.88  [52480/54000]
# Batch loss: 10.794856,  Batch Accuracy: 96.09  [53760/54000]
# Training performance:
#  Accuracy: 93.5%, Loss: 16.626533
# Validation performance:
#  Accuracy: 93.4%, Loss: 14.898286
# Test performance:
#  Accuracy: 93.5%, Loss: 15.407622
#
# Epoch 15
# -------------------------------
# Batch loss: 15.152938,  Batch Accuracy: 94.53  [ 1280/54000]
# Batch loss: 17.464115,  Batch Accuracy: 95.31  [ 2560/54000]
# Batch loss: 16.698329,  Batch Accuracy: 91.41  [ 3840/54000]
# Batch loss: 15.451112,  Batch Accuracy: 95.31  [ 5120/54000]
# Batch loss: 9.501905,  Batch Accuracy: 96.09  [ 6400/54000]
# Batch loss: 22.497234,  Batch Accuracy: 91.41  [ 7680/54000]
# Batch loss: 15.879677,  Batch Accuracy: 92.97  [ 8960/54000]
# Batch loss: 9.465736,  Batch Accuracy: 94.53  [10240/54000]
# Batch loss: 13.323959,  Batch Accuracy: 95.31  [11520/54000]
# Batch loss: 16.470063,  Batch Accuracy: 89.06  [12800/54000]
# Batch loss: 12.056247,  Batch Accuracy: 96.88  [14080/54000]
# Batch loss: 11.269602,  Batch Accuracy: 94.53  [15360/54000]
# Batch loss: 21.130793,  Batch Accuracy: 90.62  [16640/54000]
# Batch loss: 19.133957,  Batch Accuracy: 92.97  [17920/54000]
# Batch loss: 26.457094,  Batch Accuracy: 92.19  [19200/54000]
# Batch loss: 10.602783,  Batch Accuracy: 96.09  [20480/54000]
# Batch loss: 18.001558,  Batch Accuracy: 94.53  [21760/54000]
# Batch loss: 14.918067,  Batch Accuracy: 92.19  [23040/54000]
# Batch loss: 18.336454,  Batch Accuracy: 89.84  [24320/54000]
# Batch loss: 11.796289,  Batch Accuracy: 96.88  [25600/54000]
# Batch loss: 7.859019,  Batch Accuracy: 96.09  [26880/54000]
# Batch loss: 8.956215,  Batch Accuracy: 95.31  [28160/54000]
# Batch loss: 16.732679,  Batch Accuracy: 92.19  [29440/54000]
# Batch loss: 13.905995,  Batch Accuracy: 92.97  [30720/54000]
# Batch loss: 14.700786,  Batch Accuracy: 95.31  [32000/54000]
# Batch loss: 10.589730,  Batch Accuracy: 93.75  [33280/54000]
# Batch loss: 19.368070,  Batch Accuracy: 92.97  [34560/54000]
# Batch loss: 15.021321,  Batch Accuracy: 94.53  [35840/54000]
# Batch loss: 13.560806,  Batch Accuracy: 93.75  [37120/54000]
# Batch loss: 9.721007,  Batch Accuracy: 94.53  [38400/54000]
# Batch loss: 18.563210,  Batch Accuracy: 94.53  [39680/54000]
# Batch loss: 11.718292,  Batch Accuracy: 93.75  [40960/54000]
# Batch loss: 13.675879,  Batch Accuracy: 90.62  [42240/54000]
# Batch loss: 29.135477,  Batch Accuracy: 92.97  [43520/54000]
# Batch loss: 15.208230,  Batch Accuracy: 91.41  [44800/54000]
# Batch loss: 13.658174,  Batch Accuracy: 93.75  [46080/54000]
# Batch loss: 9.600051,  Batch Accuracy: 96.09  [47360/54000]
# Batch loss: 12.859633,  Batch Accuracy: 92.97  [48640/54000]
# Batch loss: 22.824930,  Batch Accuracy: 90.62  [49920/54000]
# Batch loss: 14.189228,  Batch Accuracy: 94.53  [51200/54000]
# Batch loss: 18.235683,  Batch Accuracy: 95.31  [52480/54000]
# Batch loss: 8.563414,  Batch Accuracy: 96.09  [53760/54000]
# Training performance:
#  Accuracy: 93.8%, Loss: 15.750434
# Validation performance:
#  Accuracy: 93.4%, Loss: 15.378890
# Test performance:
#  Accuracy: 93.4%, Loss: 14.976045
#
# Epoch 16
# -------------------------------
# Batch loss: 12.284928,  Batch Accuracy: 93.75  [ 1280/54000]
# Batch loss: 12.726991,  Batch Accuracy: 95.31  [ 2560/54000]
# Batch loss: 14.913780,  Batch Accuracy: 96.88  [ 3840/54000]
# Batch loss: 17.342607,  Batch Accuracy: 94.53  [ 5120/54000]
# Batch loss: 27.453071,  Batch Accuracy: 93.75  [ 6400/54000]
# Batch loss: 15.925052,  Batch Accuracy: 92.97  [ 7680/54000]
# Batch loss: 13.370753,  Batch Accuracy: 94.53  [ 8960/54000]
# Batch loss: 20.463008,  Batch Accuracy: 89.06  [10240/54000]
# Batch loss: 6.250289,  Batch Accuracy: 98.44  [11520/54000]
# Batch loss: 9.859686,  Batch Accuracy: 94.53  [12800/54000]
# Batch loss: 6.935700,  Batch Accuracy: 96.09  [14080/54000]
# Batch loss: 19.367032,  Batch Accuracy: 93.75  [15360/54000]
# Batch loss: 35.837786,  Batch Accuracy: 91.41  [16640/54000]
# Batch loss: 21.088753,  Batch Accuracy: 92.97  [17920/54000]
# Batch loss: 19.875313,  Batch Accuracy: 89.84  [19200/54000]
# Batch loss: 24.371441,  Batch Accuracy: 92.19  [20480/54000]
# Batch loss: 14.099517,  Batch Accuracy: 93.75  [21760/54000]
# Batch loss: 10.487946,  Batch Accuracy: 95.31  [23040/54000]
# Batch loss: 12.782055,  Batch Accuracy: 96.88  [24320/54000]
# Batch loss: 17.045300,  Batch Accuracy: 92.97  [25600/54000]
# Batch loss: 15.844491,  Batch Accuracy: 92.19  [26880/54000]
# Batch loss: 11.103013,  Batch Accuracy: 94.53  [28160/54000]
# Batch loss: 17.649846,  Batch Accuracy: 93.75  [29440/54000]
# Batch loss: 8.901549,  Batch Accuracy: 96.88  [30720/54000]
# Batch loss: 16.898647,  Batch Accuracy: 92.97  [32000/54000]
# Batch loss: 18.464892,  Batch Accuracy: 96.09  [33280/54000]
# Batch loss: 16.026289,  Batch Accuracy: 93.75  [34560/54000]
# Batch loss: 15.472069,  Batch Accuracy: 93.75  [35840/54000]
# Batch loss: 13.870216,  Batch Accuracy: 96.88  [37120/54000]
# Batch loss: 29.492043,  Batch Accuracy: 92.97  [38400/54000]
# Batch loss: 9.442112,  Batch Accuracy: 96.09  [39680/54000]
# Batch loss: 8.711034,  Batch Accuracy: 96.09  [40960/54000]
# Batch loss: 8.948232,  Batch Accuracy: 96.09  [42240/54000]
# Batch loss: 15.061231,  Batch Accuracy: 92.19  [43520/54000]
# Batch loss: 14.108873,  Batch Accuracy: 95.31  [44800/54000]
# Batch loss: 8.633201,  Batch Accuracy: 97.66  [46080/54000]
# Batch loss: 12.270698,  Batch Accuracy: 95.31  [47360/54000]
# Batch loss: 18.157422,  Batch Accuracy: 93.75  [48640/54000]
# Batch loss: 8.908774,  Batch Accuracy: 97.66  [49920/54000]
# Batch loss: 13.209268,  Batch Accuracy: 95.31  [51200/54000]
# Batch loss: 17.663692,  Batch Accuracy: 92.97  [52480/54000]
# Batch loss: 10.812021,  Batch Accuracy: 95.31  [53760/54000]
# Training performance:
#  Accuracy: 94.2%, Loss: 15.219590
# Validation performance:
#  Accuracy: 93.8%, Loss: 14.150718
# Test performance:
#  Accuracy: 94.0%, Loss: 14.106357
#
# Epoch 17
# -------------------------------
# Batch loss: 9.385751,  Batch Accuracy: 94.53  [ 1280/54000]
# Batch loss: 25.316132,  Batch Accuracy: 89.06  [ 2560/54000]
# Batch loss: 14.776432,  Batch Accuracy: 95.31  [ 3840/54000]
# Batch loss: 10.450700,  Batch Accuracy: 94.53  [ 5120/54000]
# Batch loss: 10.912301,  Batch Accuracy: 95.31  [ 6400/54000]
# Batch loss: 12.209699,  Batch Accuracy: 96.88  [ 7680/54000]
# Batch loss: 15.690541,  Batch Accuracy: 93.75  [ 8960/54000]
# Batch loss: 15.719266,  Batch Accuracy: 95.31  [10240/54000]
# Batch loss: 14.427540,  Batch Accuracy: 92.19  [11520/54000]
# Batch loss: 9.911030,  Batch Accuracy: 94.53  [12800/54000]
# Batch loss: 10.293596,  Batch Accuracy: 94.53  [14080/54000]
# Batch loss: 25.046519,  Batch Accuracy: 92.19  [15360/54000]
# Batch loss: 13.061710,  Batch Accuracy: 96.09  [16640/54000]
# Batch loss: 16.726942,  Batch Accuracy: 92.19  [17920/54000]
# Batch loss: 11.867961,  Batch Accuracy: 95.31  [19200/54000]
# Batch loss: 8.255215,  Batch Accuracy: 96.88  [20480/54000]
# Batch loss: 14.727259,  Batch Accuracy: 94.53  [21760/54000]
# Batch loss: 18.482909,  Batch Accuracy: 96.09  [23040/54000]
# Batch loss: 9.869251,  Batch Accuracy: 96.88  [24320/54000]
# Batch loss: 11.944846,  Batch Accuracy: 94.53  [25600/54000]
# Batch loss: 8.303648,  Batch Accuracy: 95.31  [26880/54000]
# Batch loss: 11.868677,  Batch Accuracy: 93.75  [28160/54000]
# Batch loss: 16.554929,  Batch Accuracy: 93.75  [29440/54000]
# Batch loss: 9.121271,  Batch Accuracy: 96.88  [30720/54000]
# Batch loss: 17.153042,  Batch Accuracy: 93.75  [32000/54000]
# Batch loss: 14.307327,  Batch Accuracy: 92.97  [33280/54000]
# Batch loss: 13.942523,  Batch Accuracy: 92.97  [34560/54000]
# Batch loss: 12.992139,  Batch Accuracy: 93.75  [35840/54000]
# Batch loss: 5.083886,  Batch Accuracy: 97.66  [37120/54000]
# Batch loss: 18.869016,  Batch Accuracy: 92.19  [38400/54000]
# Batch loss: 6.389081,  Batch Accuracy: 99.22  [39680/54000]
# Batch loss: 15.156003,  Batch Accuracy: 88.28  [40960/54000]
# Batch loss: 10.670278,  Batch Accuracy: 96.09  [42240/54000]
# Batch loss: 7.180995,  Batch Accuracy: 97.66  [43520/54000]
# Batch loss: 9.729215,  Batch Accuracy: 97.66  [44800/54000]
# Batch loss: 11.287782,  Batch Accuracy: 92.97  [46080/54000]
# Batch loss: 15.993964,  Batch Accuracy: 93.75  [47360/54000]
# Batch loss: 15.310438,  Batch Accuracy: 93.75  [48640/54000]
# Batch loss: 11.563850,  Batch Accuracy: 94.53  [49920/54000]
# Batch loss: 8.980496,  Batch Accuracy: 96.09  [51200/54000]
# Batch loss: 10.828258,  Batch Accuracy: 92.97  [52480/54000]
# Batch loss: 15.386941,  Batch Accuracy: 92.97  [53760/54000]
# Training performance:
#  Accuracy: 94.3%, Loss: 14.452872
# Validation performance:
#  Accuracy: 94.2%, Loss: 13.781495
# Test performance:
#  Accuracy: 94.2%, Loss: 13.712693
#
# Epoch 18
# -------------------------------
# Batch loss: 5.692245,  Batch Accuracy: 98.44  [ 1280/54000]
# Batch loss: 27.250819,  Batch Accuracy: 93.75  [ 2560/54000]
# Batch loss: 8.496451,  Batch Accuracy: 97.66  [ 3840/54000]
# Batch loss: 17.260988,  Batch Accuracy: 91.41  [ 5120/54000]
# Batch loss: 13.311918,  Batch Accuracy: 95.31  [ 6400/54000]
# Batch loss: 11.638527,  Batch Accuracy: 96.09  [ 7680/54000]
# Batch loss: 10.461591,  Batch Accuracy: 95.31  [ 8960/54000]
# Batch loss: 6.701679,  Batch Accuracy: 98.44  [10240/54000]
# Batch loss: 20.334973,  Batch Accuracy: 92.97  [11520/54000]
# Batch loss: 15.291705,  Batch Accuracy: 94.53  [12800/54000]
# Batch loss: 13.512363,  Batch Accuracy: 94.53  [14080/54000]
# ...
# Batch loss: 1.625640,  Batch Accuracy: 100.00  [11520/54000]
# Batch loss: 3.248875,  Batch Accuracy: 97.66  [12800/54000]
# Batch loss: 1.445388,  Batch Accuracy: 100.00  [14080/54000]
# Batch loss: 3.195922,  Batch Accuracy: 98.44  [15360/54000]
# Batch loss: 12.334524,  Batch Accuracy: 97.66  [16640/54000]
# Batch loss: 6.268434,  Batch Accuracy: 99.22  [17920/54000]
# Batch loss: 13.070684,  Batch Accuracy: 98.44  [19200/54000]
# Batch loss: 4.900272,  Batch Accuracy: 99.22  [20480/54000]
# Batch loss: 1.622725,  Batch Accuracy: 99.22  [21760/54000]
# Batch loss: 9.663179,  Batch Accuracy: 97.66  [23040/54000]
# Batch loss: 5.250548,  Batch Accuracy: 98.44  [24320/54000]
# Batch loss: 15.768545,  Batch Accuracy: 96.88  [25600/54000]
# Batch loss: 1.340232,  Batch Accuracy: 100.00  [26880/54000]
# Batch loss: 6.450816,  Batch Accuracy: 98.44  [28160/54000]
# Batch loss: 3.723345,  Batch Accuracy: 98.44  [29440/54000]
# Batch loss: 9.499233,  Batch Accuracy: 99.22  [30720/54000]
# Batch loss: 0.906527,  Batch Accuracy: 99.22  [32000/54000]
# Batch loss: 11.762418,  Batch Accuracy: 97.66  [33280/54000]
# Batch loss: 3.249654,  Batch Accuracy: 99.22  [34560/54000]
# Batch loss: 5.038677,  Batch Accuracy: 99.22  [35840/54000]
# Batch loss: 6.826846,  Batch Accuracy: 97.66  [37120/54000]
# Batch loss: 7.223618,  Batch Accuracy: 99.22  [38400/54000]
# Batch loss: 4.849983,  Batch Accuracy: 99.22  [39680/54000]
# Batch loss: 0.965260,  Batch Accuracy: 100.00  [40960/54000]
# Batch loss: 3.849577,  Batch Accuracy: 97.66  [42240/54000]
# Batch loss: 16.943439,  Batch Accuracy: 96.88  [43520/54000]
# Batch loss: 2.969190,  Batch Accuracy: 99.22  [44800/54000]
# Batch loss: 9.215199,  Batch Accuracy: 97.66  [46080/54000]
# Batch loss: 1.768840,  Batch Accuracy: 100.00  [47360/54000]
# Batch loss: 2.788648,  Batch Accuracy: 99.22  [48640/54000]
# Batch loss: 3.237373,  Batch Accuracy: 97.66  [49920/54000]
# Batch loss: 3.924894,  Batch Accuracy: 97.66  [51200/54000]
# Batch loss: 4.137136,  Batch Accuracy: 98.44  [52480/54000]
# Batch loss: 10.750341,  Batch Accuracy: 98.44  [53760/54000]
# Training performance:
#  Accuracy: 98.8%, Loss: 4.615496
# Validation performance:
#  Accuracy: 97.3%, Loss: 5.796393
# Test performance:
#  Accuracy: 97.3%, Loss: 5.939318
#
# Epoch 56
# -------------------------------
# Batch loss: 10.068087,  Batch Accuracy: 97.66  [ 1280/54000]
# Batch loss: 3.255226,  Batch Accuracy: 98.44  [ 2560/54000]
# Batch loss: 4.993836,  Batch Accuracy: 97.66  [ 3840/54000]
# Batch loss: 3.211419,  Batch Accuracy: 98.44  [ 5120/54000]
# Batch loss: 2.346517,  Batch Accuracy: 97.66  [ 6400/54000]
# Batch loss: 5.274832,  Batch Accuracy: 99.22  [ 7680/54000]
# Batch loss: 5.752822,  Batch Accuracy: 98.44  [ 8960/54000]
# Batch loss: 9.251638,  Batch Accuracy: 98.44  [10240/54000]
# Batch loss: 3.404965,  Batch Accuracy: 99.22  [11520/54000]
# Batch loss: 3.134574,  Batch Accuracy: 99.22  [12800/54000]
# Batch loss: 3.363074,  Batch Accuracy: 99.22  [14080/54000]
# Batch loss: 3.635565,  Batch Accuracy: 98.44  [15360/54000]
# Batch loss: 1.039151,  Batch Accuracy: 99.22  [16640/54000]
# Batch loss: 1.880667,  Batch Accuracy: 100.00  [17920/54000]
# Batch loss: 3.141576,  Batch Accuracy: 99.22  [19200/54000]
# Batch loss: 1.045952,  Batch Accuracy: 100.00  [20480/54000]
# Batch loss: 3.185172,  Batch Accuracy: 98.44  [21760/54000]
# Batch loss: 8.878521,  Batch Accuracy: 97.66  [23040/54000]
# Batch loss: 11.446400,  Batch Accuracy: 98.44  [24320/54000]
# Batch loss: 1.722027,  Batch Accuracy: 100.00  [25600/54000]
# Batch loss: 3.981314,  Batch Accuracy: 98.44  [26880/54000]
# Batch loss: 4.208481,  Batch Accuracy: 98.44  [28160/54000]
# Batch loss: 6.059653,  Batch Accuracy: 97.66  [29440/54000]
# Batch loss: 9.925914,  Batch Accuracy: 98.44  [30720/54000]
# Batch loss: 2.680398,  Batch Accuracy: 99.22  [32000/54000]
# Batch loss: 1.460627,  Batch Accuracy: 100.00  [33280/54000]
# Batch loss: 2.656119,  Batch Accuracy: 99.22  [34560/54000]
# Batch loss: 3.145585,  Batch Accuracy: 99.22  [35840/54000]
# Batch loss: 5.192345,  Batch Accuracy: 98.44  [37120/54000]
# Batch loss: 1.547535,  Batch Accuracy: 100.00  [38400/54000]
# Batch loss: 3.138418,  Batch Accuracy: 99.22  [39680/54000]
# Batch loss: 7.335332,  Batch Accuracy: 96.09  [40960/54000]
# Batch loss: 11.452298,  Batch Accuracy: 99.22  [42240/54000]
# Batch loss: 2.595492,  Batch Accuracy: 99.22  [43520/54000]
# Batch loss: 10.842815,  Batch Accuracy: 99.22  [44800/54000]
# Batch loss: 3.857934,  Batch Accuracy: 98.44  [46080/54000]
# Batch loss: 1.712448,  Batch Accuracy: 99.22  [47360/54000]
# Batch loss: 2.639067,  Batch Accuracy: 99.22  [48640/54000]
# Batch loss: 1.935668,  Batch Accuracy: 100.00  [49920/54000]
# Batch loss: 6.933997,  Batch Accuracy: 97.66  [51200/54000]
# Batch loss: 1.908271,  Batch Accuracy: 100.00  [52480/54000]
# Batch loss: 4.552010,  Batch Accuracy: 98.44  [53760/54000]
# Training performance:
#  Accuracy: 98.8%, Loss: 4.590971
# Validation performance:
#  Accuracy: 97.2%, Loss: 6.490592
# Test performance:
#  Accuracy: 97.3%, Loss: 6.256662
#
# Epoch 57
# -------------------------------
# Batch loss: 1.555008,  Batch Accuracy: 100.00  [ 1280/54000]
# Batch loss: 5.961507,  Batch Accuracy: 98.44  [ 2560/54000]
# Batch loss: 2.528922,  Batch Accuracy: 99.22  [ 3840/54000]
# Batch loss: 2.357746,  Batch Accuracy: 100.00  [ 5120/54000]
# Batch loss: 6.564553,  Batch Accuracy: 98.44  [ 6400/54000]
# Batch loss: 2.882682,  Batch Accuracy: 98.44  [ 7680/54000]
# Batch loss: 2.662862,  Batch Accuracy: 99.22  [ 8960/54000]
# Batch loss: 16.407346,  Batch Accuracy: 98.44  [10240/54000]
# Batch loss: 4.184546,  Batch Accuracy: 99.22  [11520/54000]
# Batch loss: 2.895714,  Batch Accuracy: 99.22  [12800/54000]
# Batch loss: 2.019453,  Batch Accuracy: 100.00  [14080/54000]
# Batch loss: 8.188033,  Batch Accuracy: 99.22  [15360/54000]
# Batch loss: 7.382115,  Batch Accuracy: 96.88  [16640/54000]
# Batch loss: 4.915438,  Batch Accuracy: 99.22  [17920/54000]
# Batch loss: 0.565262,  Batch Accuracy: 100.00  [19200/54000]
# Batch loss: 8.440963,  Batch Accuracy: 98.44  [20480/54000]
# Batch loss: 0.842372,  Batch Accuracy: 100.00  [21760/54000]
# Batch loss: 6.543174,  Batch Accuracy: 98.44  [23040/54000]
# Batch loss: 2.206483,  Batch Accuracy: 100.00  [24320/54000]
# Batch loss: 19.518840,  Batch Accuracy: 96.09  [25600/54000]
# Batch loss: 4.584687,  Batch Accuracy: 98.44  [26880/54000]
# Batch loss: 1.285724,  Batch Accuracy: 100.00  [28160/54000]
# Batch loss: 1.077229,  Batch Accuracy: 100.00  [29440/54000]
# Batch loss: 2.826792,  Batch Accuracy: 98.44  [30720/54000]
# Batch loss: 4.375627,  Batch Accuracy: 99.22  [32000/54000]
# Batch loss: 3.100486,  Batch Accuracy: 97.66  [33280/54000]
# Batch loss: 1.618120,  Batch Accuracy: 100.00  [34560/54000]
# Batch loss: 1.036596,  Batch Accuracy: 99.22  [35840/54000]
# Batch loss: 3.961298,  Batch Accuracy: 98.44  [37120/54000]
# Batch loss: 10.065276,  Batch Accuracy: 98.44  [38400/54000]
# Batch loss: 2.029803,  Batch Accuracy: 100.00  [39680/54000]
# Batch loss: 2.410576,  Batch Accuracy: 99.22  [40960/54000]
# Batch loss: 3.619507,  Batch Accuracy: 99.22  [42240/54000]
# Batch loss: 2.659408,  Batch Accuracy: 99.22  [43520/54000]
# Batch loss: 4.813632,  Batch Accuracy: 96.88  [44800/54000]
# Batch loss: 2.751440,  Batch Accuracy: 98.44  [46080/54000]
# Batch loss: 5.715938,  Batch Accuracy: 99.22  [47360/54000]
# Batch loss: 11.386545,  Batch Accuracy: 99.22  [48640/54000]
# Batch loss: 0.756971,  Batch Accuracy: 100.00  [49920/54000]
# Batch loss: 1.153403,  Batch Accuracy: 100.00  [51200/54000]
# Batch loss: 5.048169,  Batch Accuracy: 98.44  [52480/54000]
# Batch loss: 7.769369,  Batch Accuracy: 97.66  [53760/54000]
# Training performance:
#  Accuracy: 98.9%, Loss: 4.687523
# Validation performance:
#  Accuracy: 97.4%, Loss: 5.680328
# Test performance:
#  Accuracy: 97.3%, Loss: 5.859680
#
# Epoch 58
# -------------------------------
# Batch loss: 1.818695,  Batch Accuracy: 99.22  [ 1280/54000]
# Batch loss: 2.757703,  Batch Accuracy: 99.22  [ 2560/54000]
# Batch loss: 2.333609,  Batch Accuracy: 99.22  [ 3840/54000]
# Batch loss: 0.931077,  Batch Accuracy: 100.00  [ 5120/54000]
# Batch loss: 1.285451,  Batch Accuracy: 100.00  [ 6400/54000]
# Batch loss: 2.411155,  Batch Accuracy: 99.22  [ 7680/54000]
# Batch loss: 4.876062,  Batch Accuracy: 98.44  [ 8960/54000]
# Batch loss: 7.729844,  Batch Accuracy: 97.66  [10240/54000]
# Batch loss: 1.698919,  Batch Accuracy: 98.44  [11520/54000]
# Batch loss: 6.113269,  Batch Accuracy: 98.44  [12800/54000]
# Batch loss: 4.008132,  Batch Accuracy: 98.44  [14080/54000]
# Batch loss: 2.160653,  Batch Accuracy: 99.22  [15360/54000]
# Batch loss: 1.556949,  Batch Accuracy: 100.00  [16640/54000]
# Batch loss: 1.055602,  Batch Accuracy: 100.00  [17920/54000]
# Batch loss: 6.556874,  Batch Accuracy: 98.44  [19200/54000]
# Batch loss: 1.578539,  Batch Accuracy: 100.00  [20480/54000]
# Batch loss: 3.434168,  Batch Accuracy: 99.22  [21760/54000]
# Batch loss: 0.758382,  Batch Accuracy: 100.00  [23040/54000]
# Batch loss: 4.744208,  Batch Accuracy: 98.44  [24320/54000]
# Batch loss: 5.443605,  Batch Accuracy: 99.22  [25600/54000]
# Batch loss: 5.392468,  Batch Accuracy: 99.22  [26880/54000]
# Batch loss: 6.488845,  Batch Accuracy: 96.88  [28160/54000]
# Batch loss: 1.198711,  Batch Accuracy: 100.00  [29440/54000]
# Batch loss: 3.706207,  Batch Accuracy: 97.66  [30720/54000]
# Batch loss: 1.775973,  Batch Accuracy: 99.22  [32000/54000]
# Batch loss: 5.626250,  Batch Accuracy: 99.22  [33280/54000]
# Batch loss: 4.701753,  Batch Accuracy: 98.44  [34560/54000]
# Batch loss: 3.585415,  Batch Accuracy: 99.22  [35840/54000]
# Batch loss: 10.586120,  Batch Accuracy: 97.66  [37120/54000]
# Batch loss: 7.307753,  Batch Accuracy: 98.44  [38400/54000]
# Batch loss: 6.615078,  Batch Accuracy: 99.22  [39680/54000]
# Batch loss: 1.314851,  Batch Accuracy: 100.00  [40960/54000]
# Batch loss: 11.810222,  Batch Accuracy: 98.44  [42240/54000]
# Batch loss: 4.911546,  Batch Accuracy: 99.22  [43520/54000]
# Batch loss: 3.605442,  Batch Accuracy: 98.44  [44800/54000]
# Batch loss: 5.322017,  Batch Accuracy: 98.44  [46080/54000]
# Batch loss: 5.594265,  Batch Accuracy: 99.22  [47360/54000]
# Batch loss: 0.504425,  Batch Accuracy: 100.00  [48640/54000]
# Batch loss: 1.570125,  Batch Accuracy: 99.22  [49920/54000]
# Batch loss: 2.501052,  Batch Accuracy: 100.00  [51200/54000]
# Batch loss: 6.662742,  Batch Accuracy: 97.66  [52480/54000]
# Batch loss: 0.510659,  Batch Accuracy: 100.00  [53760/54000]
# Training performance:
#  Accuracy: 98.9%, Loss: 4.457926
# Validation performance:
#  Accuracy: 97.4%, Loss: 6.236138
# Test performance:
#  Accuracy: 97.4%, Loss: 6.110255
#
# Epoch 59
# -------------------------------
# Batch loss: 6.062977,  Batch Accuracy: 99.22  [ 1280/54000]
# Batch loss: 1.530888,  Batch Accuracy: 100.00  [ 2560/54000]
# Batch loss: 5.616002,  Batch Accuracy: 99.22  [ 3840/54000]
# Batch loss: 1.823207,  Batch Accuracy: 100.00  [ 5120/54000]
# Batch loss: 4.866437,  Batch Accuracy: 99.22  [ 6400/54000]
# Batch loss: 7.974985,  Batch Accuracy: 97.66  [ 7680/54000]
# Batch loss: 9.083643,  Batch Accuracy: 98.44  [ 8960/54000]
# Batch loss: 4.867329,  Batch Accuracy: 97.66  [10240/54000]
# Batch loss: 7.207680,  Batch Accuracy: 97.66  [11520/54000]
# Batch loss: 1.581944,  Batch Accuracy: 100.00  [12800/54000]
# Batch loss: 0.695568,  Batch Accuracy: 99.22  [14080/54000]
# Batch loss: 4.506676,  Batch Accuracy: 98.44  [15360/54000]
# Batch loss: 1.168251,  Batch Accuracy: 100.00  [16640/54000]
# Batch loss: 12.647253,  Batch Accuracy: 97.66  [17920/54000]
# Batch loss: 2.050171,  Batch Accuracy: 97.66  [19200/54000]
# Batch loss: 2.987980,  Batch Accuracy: 98.44  [20480/54000]
# Batch loss: 2.365416,  Batch Accuracy: 99.22  [21760/54000]
# Batch loss: 4.057689,  Batch Accuracy: 99.22  [23040/54000]
# Batch loss: 1.954929,  Batch Accuracy: 98.44  [24320/54000]
# Batch loss: 2.130469,  Batch Accuracy: 98.44  [25600/54000]
# Batch loss: 1.927273,  Batch Accuracy: 99.22  [26880/54000]
# Batch loss: 7.274001,  Batch Accuracy: 98.44  [28160/54000]
# Batch loss: 1.336734,  Batch Accuracy: 99.22  [29440/54000]
# Batch loss: 4.395743,  Batch Accuracy: 99.22  [30720/54000]
# Batch loss: 1.465428,  Batch Accuracy: 100.00  [32000/54000]
# Batch loss: 10.337326,  Batch Accuracy: 97.66  [33280/54000]
# Batch loss: 10.570352,  Batch Accuracy: 99.22  [34560/54000]
# Batch loss: 1.413651,  Batch Accuracy: 100.00  [35840/54000]
# Batch loss: 5.745077,  Batch Accuracy: 98.44  [37120/54000]
# Batch loss: 1.620638,  Batch Accuracy: 100.00  [38400/54000]
# Batch loss: 1.196922,  Batch Accuracy: 100.00  [39680/54000]
# Batch loss: 2.705984,  Batch Accuracy: 99.22  [40960/54000]
# Batch loss: 1.760281,  Batch Accuracy: 100.00  [42240/54000]
# Batch loss: 2.372333,  Batch Accuracy: 99.22  [43520/54000]
# Batch loss: 2.196321,  Batch Accuracy: 99.22  [44800/54000]
# Batch loss: 3.438757,  Batch Accuracy: 98.44  [46080/54000]
# Batch loss: 9.044553,  Batch Accuracy: 96.88  [47360/54000]
# Batch loss: 7.937324,  Batch Accuracy: 94.53  [48640/54000]
# Batch loss: 8.104088,  Batch Accuracy: 97.66  [49920/54000]
# Batch loss: 1.717194,  Batch Accuracy: 100.00  [51200/54000]
# Batch loss: 4.800820,  Batch Accuracy: 98.44  [52480/54000]
# Batch loss: 8.601722,  Batch Accuracy: 98.44  [53760/54000]
# Training performance:
#  Accuracy: 99.0%, Loss: 4.301785
# Validation performance:
#  Accuracy: 97.4%, Loss: 6.013791
# Test performance:
#  Accuracy: 97.4%, Loss: 5.965097
#
# Epoch 60
# -------------------------------
# Batch loss: 14.744363,  Batch Accuracy: 98.44  [ 1280/54000]
# Batch loss: 6.388518,  Batch Accuracy: 98.44  [ 2560/54000]
# Batch loss: 11.705706,  Batch Accuracy: 98.44  [ 3840/54000]
# Batch loss: 4.132708,  Batch Accuracy: 98.44  [ 5120/54000]
# Batch loss: 1.994602,  Batch Accuracy: 100.00  [ 6400/54000]
# Batch loss: 9.668745,  Batch Accuracy: 98.44  [ 7680/54000]
# Batch loss: 2.091369,  Batch Accuracy: 100.00  [ 8960/54000]
# Batch loss: 3.681391,  Batch Accuracy: 99.22  [10240/54000]
# Batch loss: 2.957827,  Batch Accuracy: 97.66  [11520/54000]
# Batch loss: 4.471442,  Batch Accuracy: 98.44  [12800/54000]
# Batch loss: 10.302839,  Batch Accuracy: 98.44  [14080/54000]
# Batch loss: 2.639502,  Batch Accuracy: 99.22  [15360/54000]
# Batch loss: 3.208697,  Batch Accuracy: 99.22  [16640/54000]
# Batch loss: 1.591859,  Batch Accuracy: 99.22  [17920/54000]
# Batch loss: 0.711416,  Batch Accuracy: 100.00  [19200/54000]
# Batch loss: 2.099938,  Batch Accuracy: 99.22  [20480/54000]
# Batch loss: 3.615093,  Batch Accuracy: 99.22  [21760/54000]
# Batch loss: 7.487174,  Batch Accuracy: 98.44  [23040/54000]
# Batch loss: 2.685005,  Batch Accuracy: 98.44  [24320/54000]
# Batch loss: 0.722357,  Batch Accuracy: 100.00  [25600/54000]
# Batch loss: 1.096586,  Batch Accuracy: 100.00  [26880/54000]
# Batch loss: 7.234767,  Batch Accuracy: 98.44  [28160/54000]
# Batch loss: 6.091766,  Batch Accuracy: 98.44  [29440/54000]
# Batch loss: 2.319792,  Batch Accuracy: 99.22  [30720/54000]
# Batch loss: 0.983621,  Batch Accuracy: 100.00  [32000/54000]
# Batch loss: 2.653846,  Batch Accuracy: 99.22  [33280/54000]
# Batch loss: 17.537388,  Batch Accuracy: 96.88  [34560/54000]
# Batch loss: 3.675724,  Batch Accuracy: 99.22  [35840/54000]
# Batch loss: 3.068700,  Batch Accuracy: 98.44  [37120/54000]
# Batch loss: 6.208185,  Batch Accuracy: 98.44  [38400/54000]
# Batch loss: 14.898946,  Batch Accuracy: 97.66  [39680/54000]
# Batch loss: 12.878395,  Batch Accuracy: 96.88  [40960/54000]
# Batch loss: 3.200269,  Batch Accuracy: 99.22  [42240/54000]
# Batch loss: 7.782031,  Batch Accuracy: 99.22  [43520/54000]
# Batch loss: 1.444090,  Batch Accuracy: 100.00  [44800/54000]
# Batch loss: 5.490542,  Batch Accuracy: 97.66  [46080/54000]
# Batch loss: 0.872511,  Batch Accuracy: 100.00  [47360/54000]
# Batch loss: 1.855680,  Batch Accuracy: 100.00  [48640/54000]
# Batch loss: 5.766370,  Batch Accuracy: 98.44  [49920/54000]
# Batch loss: 0.969912,  Batch Accuracy: 100.00  [51200/54000]
# Batch loss: 1.237196,  Batch Accuracy: 100.00  [52480/54000]
# Batch loss: 1.696269,  Batch Accuracy: 99.22  [53760/54000]
# Training performance:
#  Accuracy: 99.0%, Loss: 4.197791
# Validation performance:
#  Accuracy: 97.4%, Loss: 6.601588
# Test performance:
#  Accuracy: 97.5%, Loss: 5.729154
#
# Total time taken to Train: 78.79949858983358 mins

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(range(num_epochs), train_losses_q3, label='Train')
plt.plot(range(num_epochs), val_losses_q3, label='Validation')
plt.plot(range(num_epochs), test_losses_q3, label='Test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs. Epoch')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(range(num_epochs), train_accuracies_q3, label='Train')
plt.plot(range(num_epochs), val_accuracies_q3, label='Validation')
plt.plot(range(num_epochs), test_accuracies_q3, label='Test')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Accuracy vs. Epoch')
plt.legend()
plt.tight_layout()
plt.show()
